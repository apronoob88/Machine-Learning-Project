# %%
import pandas as pd
import numpy as np

# %%
def load_train(train_path):
    f = open(train_path, encoding="utf8")
    lines = []
    for line in f:
        if line != '\n':
            line = line.strip('\n').split(' ')
            lines.append(line)
    df= pd.DataFrame(lines, columns = ['word', 'state'])
    return df
ans= load_train('SG/train')

# %%
def load_test(test_path):
    f = open(test_path, encoding='utf8')
    lines = []
    for line in f:
        if line != '\n':       
            line = line.strip('\n')
            lines.append(line)
    df= pd.DataFrame(lines, columns = ['word'])
    return df

# %%
def gen_emission_param_table(file_path):
    #input_data = load_train('EN/train')
    input_data = load_train(file_path)
    input_data.columns = ['word', 'state']
    unique_word_list = input_data.word.unique()
    unique_state_list = input_data.state.unique()
    data = {word:(np.zeros(len(unique_state_list))) for word in unique_word_list}  # each word as a column, each column length is the number of unique y state, all entry are 0
                                                                                   # https://chrisalbon.com/python/data_wrangling/pandas_list_unique_values_in_column/
    emission_count_table = pd.DataFrame(data, index = unique_state_list)           # transform the dictionary into colums with index as name of each state(y),  
                                                                                   # columns as each word of x, all entries are 0
    
    y_count_dic = {state:0 for state in unique_state_list}                         # y_count_dic stores Count(y) in a dictionary
    emission_param_table = pd.DataFrame(data, index = unique_state_list)           # emission_count_table stores all Count(y -> x) in a dataframe
                                                                                   # emission_param_table stores all the emission parameters in a dataframe
    print("updating emission_count_table and y_count_dic")
    for index, row in input_data.iterrows():
        word = row['word']
        state = row['state']
        #print(index, word, state)
        #print(index)
        emission_count_table[word][state] += 1
        y_count_dic[state]+=1
    
    print("updating emission_param_table")
    for index, row in input_data.iterrows():
        word = row['word']
        state = row['state']
        #print(index)
        emission_param_table[word][state] = emission_count_table[word][state] / y_count_dic[state]
    # emission_param_table: a 2D table consisting emmision parameter for each y and x
    # emission_count_table: a 2D table consisting all Count(y->x)
    # a dictionary storing all Count(y)
    return emission_param_table, emission_count_table, y_count_dic

# %%
def get_emission_parameter(emission_param_table,x, y):
    if x not in emission_param_table.columns:
        print(f"word {x} is not found in the data set")
        return 
    result = emission_param_table[x][y]
    return result

# %%
emission_param_table, emission_count_table, y_count_dic = gen_emission_param_table('EN/train')
emission_param_table
# Out:
# updating emission_count_table and y_count_dic
# updating emission_param_table
#          Municipal     bonds       are  generally         a       bit  \
# B-NP      0.000021  0.000444  0.000021   0.000042  0.075869  0.000000
# I-NP      0.000018  0.001813  0.000000   0.000000  0.001612  0.000201
# B-VP      0.000000  0.000000  0.037074   0.000110  0.000000  0.000000
# B-ADVP    0.000000  0.000000  0.000000   0.003366  0.000000  0.000000
# B-ADJP    0.000000  0.000000  0.000000   0.000000  0.001713  0.000000
# I-ADJP    0.000000  0.000000  0.000000   0.000000  0.000000  0.003484
# B-PP      0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# O         0.000000  0.000000  0.000084   0.000000  0.000586  0.000000
# B-SBAR    0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-VP      0.000000  0.000000  0.000098   0.000197  0.000000  0.000000
# I-ADVP    0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# B-PRT     0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-PP      0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# B-CONJP   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-CONJP   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# B-INTJ    0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-INTJ    0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-SBAR    0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# B-UCP     0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-UCP     0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# B-LST     0.000000  0.000000  0.000000   0.000000  0.090909  0.000000
#
#             safer      than  corporate        in    ...     Gradison  \
# B-NP     0.000000  0.000000   0.000592  0.000021    ...     0.000000
# I-NP     0.000000  0.001905   0.000385  0.000037    ...     0.000018
# B-VP     0.000000  0.000000   0.000000  0.000000    ...     0.000000
# B-ADVP   0.000000  0.000000   0.000000  0.004769    ...     0.000000
# B-ADJP   0.000000  0.000000   0.000000  0.000000    ...     0.000000
# I-ADJP   0.001742  0.003484   0.000000  0.000000    ...     0.000000
# B-PP     0.000000  0.006961   0.000000  0.155653    ...     0.000000
# O        0.000000  0.000126   0.000000  0.000000    ...     0.000000
# B-SBAR   0.000000  0.022117   0.000000  0.004739    ...     0.000000
# I-VP     0.000000  0.000492   0.000000  0.000000    ...     0.000000
# I-ADVP   0.000000  0.013774   0.000000  0.000000    ...     0.000000
# B-PRT    0.000000  0.000000   0.000000  0.061966    ...     0.000000
# I-PP     0.000000  0.031390   0.000000  0.026906    ...     0.000000
# B-CONJP  0.000000  0.000000   0.000000  0.000000    ...     0.000000
# I-CONJP  0.000000  0.125000   0.000000  0.000000    ...     0.000000
# B-INTJ   0.000000  0.000000   0.000000  0.000000    ...     0.000000
# I-INTJ   0.000000  0.000000   0.000000  0.000000    ...     0.000000
# I-SBAR   0.000000  0.000000   0.000000  0.000000    ...     0.000000
# B-UCP    0.000000  0.000000   0.000000  0.000000    ...     0.000000
# I-UCP    0.000000  0.000000   0.000000  0.000000    ...     0.000000
# B-LST    0.000000  0.000000   0.000000  0.000000    ...     0.000000
#
#           Through   customs  gunslinging   agility  enriching     Suits  \
# B-NP     0.000000  0.000021     0.000000  0.000021   0.000000  0.000021
# I-NP     0.000000  0.000000     0.000018  0.000000   0.000000  0.000000
# B-VP     0.000000  0.000000     0.000000  0.000000   0.000055  0.000000
# B-ADVP   0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# B-ADJP   0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# I-ADJP   0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# B-PP     0.000054  0.000000     0.000000  0.000000   0.000000  0.000000
# O        0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# B-SBAR   0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# I-VP     0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# I-ADVP   0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# B-PRT    0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# I-PP     0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# B-CONJP  0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# I-CONJP  0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# B-INTJ   0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# I-INTJ   0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# I-SBAR   0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# B-UCP    0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# I-UCP    0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
# B-LST    0.000000  0.000000     0.000000  0.000000   0.000000  0.000000
#
#          local-government   peering     essay
# B-NP             0.000021  0.000000  0.000000
# I-NP             0.000000  0.000000  0.000018
# B-VP             0.000000  0.000055  0.000000
# B-ADVP           0.000000  0.000000  0.000000
# B-ADJP           0.000000  0.000000  0.000000
# I-ADJP           0.000000  0.000000  0.000000
# B-PP             0.000000  0.000000  0.000000
# O                0.000000  0.000000  0.000000
# B-SBAR           0.000000  0.000000  0.000000
# I-VP             0.000000  0.000000  0.000000
# I-ADVP           0.000000  0.000000  0.000000
# B-PRT            0.000000  0.000000  0.000000
# I-PP             0.000000  0.000000  0.000000
# B-CONJP          0.000000  0.000000  0.000000
# I-CONJP          0.000000  0.000000  0.000000
# B-INTJ           0.000000  0.000000  0.000000
# I-INTJ           0.000000  0.000000  0.000000
# I-SBAR           0.000000  0.000000  0.000000
# B-UCP            0.000000  0.000000  0.000000
# I-UCP            0.000000  0.000000  0.000000
# B-LST            0.000000  0.000000  0.000000
#
# [21 rows x 18212 columns]

# %%
# test the function
emission = get_emission_parameter(emission_param_table, "bit", "I-ADJP")
print(emission)
# Out:
# 0.003484320557491289

# %% [markdown]
# ### Introducing #UNK# to the function

# %%
def gen_emission_param_table_UNK(training_data_path, test_data_path):
    training_data = load_train(training_data_path)
    unique_word_list_training = training_data.word.unique()
    unique_state_list_training = training_data.state.unique()
    
    
    
    test_data = load_test(test_data_path)
    unique_word_list_test = test_data.word.unique()
    
    unk_list = np.setdiff1d(unique_word_list_test, unique_word_list_training) # return the list of words in test data but not in training data
    #non_unk_list_test = np.setdiff1d(unique_word_list_test, unk_list) # return the list of non UNK words in test data
    
    data = {word:(np.zeros(len(unique_state_list_training))) for word in unique_word_list_training}
    data["UNK"] = np.zeros(len(unique_state_list_training))    # add a UNK column to the table
    
    emission_count_table = pd.DataFrame(data, index = unique_state_list_training)           # transform the dictionary into colums with index as name of each state(y),  
                                                                                   # columns as each word of x, all entries are 0
    
    y_count_dic = {state:0 for state in unique_state_list_training}                         # y_count_dic stores Count(y) in a dictionary
    emission_param_table = pd.DataFrame(data, index = unique_state_list_training)           # emission_count_table stores all Count(y -> x) in a dataframe
                                                                                   # emission_param_table stores all the emission parameters in a dataframe
    
    print("updating emission_count_table and y_count_dic")
    for index, row in training_data.iterrows():
        word = row['word']
        state = row['state']
        #print(index, word, state)
        #print(index)
        y_count_dic[state]+=1
        if word not in unk_list:
            emission_count_table[word][state] += 1
        
    
    print("updating emission_param_table")
    k = 0.5
    for index, row in training_data.iterrows():
        word = row['word']
        state = row['state']
        #print(index)
        if word not in unk_list:
            emission_param_table[word][state] = emission_count_table[word][state] / (y_count_dic[state] + k)    
    for state in unique_state_list_training:
        emission_param_table['UNK'][state] = k/(y_count_dic[state] + k)    # compute the UNK value for each state y

    
    print("unl_list is: ",unk_list)
    print("y_count_dic is: ", y_count_dic)
    return emission_param_table, unk_list

# %%
def get_emission_parameter_UNK(emission_param_table, unk_list, x, y):

    if x in unk_list:
        result = emission_param_table['UNK'][y]
        print(f"{x} is tagged as UNK and the this e('UNK'|{y}) is {result}" )
        return result
    elif x not in emission_param_table.columns:
        print(f"word {x} is not found in the test set")
        return 
    result = emission_param_table[x][y]
    return result

# %%
def get_argmax_y(emission_param_table, unk_list, x):
    if x in unk_list:
        arg_max_y = emission_param_table['UNK'].idxmax()
        print(f"{x} is tagged as UNK and the this arg_max_y e({x}|y) is {arg_max_y}" )
        return arg_max_y
    
    arg_max_y = emission_param_table[x].idxmax()
    return arg_max_y

# %%
def gen_state(input_path, output_path, emission_param_table, unk_list ):
    with open(input_path, "r", encoding="utf8") as f1, open(output_path, 'w', encoding="utf8") as f2:
        test_list = f1.readlines()
        #print(test_list)
        for word in test_list:
            if word == '\n':
                print("new sentence")
                f2.write(word)
                continue
            word = word.strip()
            #print(word)
            arg_max_y =  get_argmax_y(emission_param_table, unk_list, word)
            output = f'{word} {arg_max_y}\n'
            #f2.write(word + " " + arg_max_y + "\n")
            print(output)
            f2.write(output)

# %%
emission_param_table_UNK_test , unk_list = gen_emission_param_table_UNK('EN/train', 'EN/dev.in')
emission_param_table_UNK_test
# Out:
# updating emission_count_table and y_count_dic
# updating emission_param_table
# unl_list is:  ["'71" '.50' '0.75' ... 'worthwhile' 'wraps' 'wrongly']
# y_count_dic is:  {'B-NP': 47305, 'I-NP': 54591, 'B-VP': 18261, 'B-ADVP': 3565, 'B-ADJP': 1751, 'I-ADJP': 574, 'B-PP': 18387, 'O': 23872, 'B-SBAR': 1899, 'I-VP': 10159, 'I-ADVP': 363, 'B-PRT': 468, 'I-PP': 223, 'B-CONJP': 49, 'I-CONJP': 64, 'B-INTJ': 26, 'I-INTJ': 7, 'I-SBAR': 48, 'B-UCP': 1, 'I-UCP': 4, 'B-LST': 11}
#          Municipal     bonds       are  generally         a       bit  \
# B-NP      0.000021  0.000444  0.000021   0.000042  0.075869  0.000000
# I-NP      0.000018  0.001813  0.000000   0.000000  0.001612  0.000201
# B-VP      0.000000  0.000000  0.037073   0.000110  0.000000  0.000000
# B-ADVP    0.000000  0.000000  0.000000   0.003366  0.000000  0.000000
# B-ADJP    0.000000  0.000000  0.000000   0.000000  0.001713  0.000000
# I-ADJP    0.000000  0.000000  0.000000   0.000000  0.000000  0.003481
# B-PP      0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# O         0.000000  0.000000  0.000084   0.000000  0.000586  0.000000
# B-SBAR    0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-VP      0.000000  0.000000  0.000098   0.000197  0.000000  0.000000
# I-ADVP    0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# B-PRT     0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-PP      0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# B-CONJP   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-CONJP   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# B-INTJ    0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-INTJ    0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-SBAR    0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# B-UCP     0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# I-UCP     0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# B-LST     0.000000  0.000000  0.000000   0.000000  0.086957  0.000000
#
#             safer      than  corporate        in    ...      Through  \
# B-NP     0.000000  0.000000   0.000592  0.000021    ...     0.000000
# I-NP     0.000000  0.001905   0.000385  0.000037    ...     0.000000
# B-VP     0.000000  0.000000   0.000000  0.000000    ...     0.000000
# B-ADVP   0.000000  0.000000   0.000000  0.004768    ...     0.000000
# B-ADJP   0.000000  0.000000   0.000000  0.000000    ...     0.000000
# I-ADJP   0.001741  0.003481   0.000000  0.000000    ...     0.000000
# B-PP     0.000000  0.006961   0.000000  0.155649    ...     0.000054
# O        0.000000  0.000126   0.000000  0.000000    ...     0.000000
# B-SBAR   0.000000  0.022111   0.000000  0.004738    ...     0.000000
# I-VP     0.000000  0.000492   0.000000  0.000000    ...     0.000000
# I-ADVP   0.000000  0.013755   0.000000  0.000000    ...     0.000000
# B-PRT    0.000000  0.000000   0.000000  0.061900    ...     0.000000
# I-PP     0.000000  0.031320   0.000000  0.026846    ...     0.000000
# B-CONJP  0.000000  0.000000   0.000000  0.000000    ...     0.000000
# I-CONJP  0.000000  0.124031   0.000000  0.000000    ...     0.000000
# B-INTJ   0.000000  0.000000   0.000000  0.000000    ...     0.000000
# I-INTJ   0.000000  0.000000   0.000000  0.000000    ...     0.000000
# I-SBAR   0.000000  0.000000   0.000000  0.000000    ...     0.000000
# B-UCP    0.000000  0.000000   0.000000  0.000000    ...     0.000000
# I-UCP    0.000000  0.000000   0.000000  0.000000    ...     0.000000
# B-LST    0.000000  0.000000   0.000000  0.000000    ...     0.000000
#
#           customs  gunslinging   agility  enriching     Suits  \
# B-NP     0.000021     0.000000  0.000021   0.000000  0.000021
# I-NP     0.000000     0.000018  0.000000   0.000000  0.000000
# B-VP     0.000000     0.000000  0.000000   0.000055  0.000000
# B-ADVP   0.000000     0.000000  0.000000   0.000000  0.000000
# B-ADJP   0.000000     0.000000  0.000000   0.000000  0.000000
# I-ADJP   0.000000     0.000000  0.000000   0.000000  0.000000
# B-PP     0.000000     0.000000  0.000000   0.000000  0.000000
# O        0.000000     0.000000  0.000000   0.000000  0.000000
# B-SBAR   0.000000     0.000000  0.000000   0.000000  0.000000
# I-VP     0.000000     0.000000  0.000000   0.000000  0.000000
# I-ADVP   0.000000     0.000000  0.000000   0.000000  0.000000
# B-PRT    0.000000     0.000000  0.000000   0.000000  0.000000
# I-PP     0.000000     0.000000  0.000000   0.000000  0.000000
# B-CONJP  0.000000     0.000000  0.000000   0.000000  0.000000
# I-CONJP  0.000000     0.000000  0.000000   0.000000  0.000000
# B-INTJ   0.000000     0.000000  0.000000   0.000000  0.000000
# I-INTJ   0.000000     0.000000  0.000000   0.000000  0.000000
# I-SBAR   0.000000     0.000000  0.000000   0.000000  0.000000
# B-UCP    0.000000     0.000000  0.000000   0.000000  0.000000
# I-UCP    0.000000     0.000000  0.000000   0.000000  0.000000
# B-LST    0.000000     0.000000  0.000000   0.000000  0.000000
#
#          local-government   peering     essay       UNK
# B-NP             0.000021  0.000000  0.000000  0.000011
# I-NP             0.000000  0.000000  0.000018  0.000009
# B-VP             0.000000  0.000055  0.000000  0.000027
# B-ADVP           0.000000  0.000000  0.000000  0.000140
# B-ADJP           0.000000  0.000000  0.000000  0.000285
# I-ADJP           0.000000  0.000000  0.000000  0.000870
# B-PP             0.000000  0.000000  0.000000  0.000027
# O                0.000000  0.000000  0.000000  0.000021
# B-SBAR           0.000000  0.000000  0.000000  0.000263
# I-VP             0.000000  0.000000  0.000000  0.000049
# I-ADVP           0.000000  0.000000  0.000000  0.001376
# B-PRT            0.000000  0.000000  0.000000  0.001067
# I-PP             0.000000  0.000000  0.000000  0.002237
# B-CONJP          0.000000  0.000000  0.000000  0.010101
# I-CONJP          0.000000  0.000000  0.000000  0.007752
# B-INTJ           0.000000  0.000000  0.000000  0.018868
# I-INTJ           0.000000  0.000000  0.000000  0.066667
# I-SBAR           0.000000  0.000000  0.000000  0.010309
# B-UCP            0.000000  0.000000  0.000000  0.333333
# I-UCP            0.000000  0.000000  0.000000  0.111111
# B-LST            0.000000  0.000000  0.000000  0.043478
#
# [21 rows x 18213 columns]

# %%
emission = get_emission_parameter_UNK(emission_param_table_UNK_test,unk_list, "bit", "I-NP")
print(emission)
# Out:
# 0.00020149656997884286

# %%
arg_max = get_argmax_y(emission_param_table_UNK_test, unk_list, '.')
print(arg_max)
# Out:
# O

# %%
# uncomment below code to generate output, make sure the previous output has been removed before running this
gen_state('EN/dev.in','EN/dev.p2.out', emission_param_table_UNK_test, unk_list)
# Out:
# HBO B-NP
#
# has B-VP
#
# close B-ADJP
#
# to B-PP
#
# 24 I-NP
#
# million I-NP
#
# subscribers I-NP
#
# to B-PP
#
# its B-NP
#
# HBO B-NP
#
# and I-UCP
#
# Cinemax is tagged as UNK and the this arg_max_y e(Cinemax|y) is B-UCP
# Cinemax B-UCP
#
# networks I-NP
#
# , O
#
# while B-SBAR
#
# Showtime B-NP
#
# and I-UCP
#
# its B-NP
#
# sister I-NP
#
# service I-NP
#
# , O
#
# The B-NP
#
# Movie is tagged as UNK and the this arg_max_y e(Movie|y) is B-UCP
# Movie B-UCP
#
# Channel I-NP
#
# , O
#
# have I-VP
#
# only I-CONJP
#
# about B-PP
#
# 10 I-ADVP
#
# million I-NP
#
# , O
#
# according B-PP
#
# to B-PP
#
# Paul B-NP
#
# Kagan is tagged as UNK and the this arg_max_y e(Kagan|y) is B-UCP
# Kagan B-UCP
#
# Associates I-NP
#
# , O
#
# a B-LST
#
# Carmel is tagged as UNK and the this arg_max_y e(Carmel|y) is B-UCP
# Carmel B-UCP
#
# , O
#
# Calif. B-NP
#
# , O
#
# research I-NP
#
# firm I-NP
#
# . O
#
# new sentence
# WASHINGTON is tagged as UNK and the this arg_max_y e(WASHINGTON|y) is B-UCP
# WASHINGTON B-UCP
#
# LIES is tagged as UNK and the this arg_max_y e(LIES|y) is B-UCP
# LIES B-UCP
#
# LOW is tagged as UNK and the this arg_max_y e(LOW|y) is B-UCP
# LOW B-UCP
#
# after B-SBAR
#
# the B-NP
#
# stock I-NP
#
# market I-NP
#
# 's B-NP
#
# roller-coaster I-NP
#
# ride I-VP
#
# . O
#
# new sentence
# This B-NP
#
# may B-VP
#
# seem B-VP
#
# to B-PP
#
# be I-VP
#
# a B-LST
#
# preposterous is tagged as UNK and the this arg_max_y e(preposterous|y) is B-UCP
# preposterous B-UCP
#
# and I-UCP
#
# utterly is tagged as UNK and the this arg_max_y e(utterly|y) is B-UCP
# utterly B-UCP
#
# futile I-NP
#
# effort I-NP
#
# in B-PP
#
# Africa I-NP
#
# . O
#
# new sentence
# American B-NP
#
# Express I-NP
#
# Bank I-NP
#
# earnings I-NP
#
# fell B-VP
#
# 50 I-NP
#
# % I-ADJP
#
# to B-PP
#
# $ B-NP
#
# 21.3 I-NP
#
# million I-NP
#
# from B-PP
#
# $ B-NP
#
# 42.5 I-NP
#
# million I-NP
#
# despite B-PP
#
# a B-LST
#
# 29 I-NP
#
# % I-ADJP
#
# revenue I-NP
#
# gain I-NP
#
# . O
#
# new sentence
# Californians B-NP
#
# , O
#
# meanwhile B-ADVP
#
# , O
#
# tried B-VP
#
# to B-PP
#
# cope I-VP
#
# with B-PP
#
# still-limited is tagged as UNK and the this arg_max_y e(still-limited|y) is B-UCP
# still-limited B-UCP
#
# services I-NP
#
# , O
#
# blocked I-VP
#
# roadways I-NP
#
# and I-UCP
#
# water I-NP
#
# shortages I-NP
#
# in B-PP
#
# the B-NP
#
# aftermath I-NP
#
# of I-PP
#
# the B-NP
#
# tremor I-NP
#
# that B-SBAR
#
# left I-VP
#
# scores I-NP
#
# dead B-ADJP
#
# and I-UCP
#
# injured I-VP
#
# . O
#
# new sentence
# This B-NP
#
# year I-NP
#
# , O
#
# a B-LST
#
# number I-NP
#
# of I-PP
#
# retail B-NP
#
# leveraged I-ADJP
#
# buyouts is tagged as UNK and the this arg_max_y e(buyouts|y) is B-UCP
# buyouts B-UCP
#
# have I-VP
#
# failed B-VP
#
# , O
#
# causing I-VP
#
# jitters B-NP
#
# among I-PP
#
# suppliers I-NP
#
# , O
#
# and I-UCP
#
# Mr. B-NP
#
# Merksamer I-NP
#
# apparently B-ADVP
#
# wanted B-VP
#
# assurances B-NP
#
# that B-SBAR
#
# he B-NP
#
# wo B-VP
#
# n't I-VP
#
# have I-VP
#
# delivery I-NP
#
# problems I-NP
#
# . O
#
# new sentence
# Mr. B-NP
#
# Juliano I-NP
#
# thinks B-VP
#
# so B-ADJP
#
# . O
#
# new sentence
# Assistant O
#
# U.S. I-NP
#
# Attorney I-NP
#
# Terry B-NP
#
# Hart I-NP
#
# of I-PP
#
# Dallas B-NP
#
# says B-VP
#
# the B-NP
#
# government I-NP
#
# will B-VP
#
# oppose B-VP
#
# any B-NP
#
# efforts I-NP
#
# to B-PP
#
# bring I-VP
#
# in B-PP
#
# a B-LST
#
# new I-NP
#
# defense I-NP
#
# team I-NP
#
# because B-SBAR
#
# it B-NP
#
# would B-VP
#
# delay I-VP
#
# a B-LST
#
# retrial B-NP
#
# . O
#
# new sentence
# Galveston-Houston is tagged as UNK and the this arg_max_y e(Galveston-Houston|y) is B-UCP
# Galveston-Houston B-UCP
#
# Co. I-NP
#
# said B-VP
#
# it B-NP
#
# will B-VP
#
# redeem is tagged as UNK and the this arg_max_y e(redeem|y) is B-UCP
# redeem B-UCP
#
# all I-ADVP
#
# 3,950 is tagged as UNK and the this arg_max_y e(3,950|y) is B-UCP
# 3,950 B-UCP
#
# shares I-NP
#
# of I-PP
#
# its B-NP
#
# privately B-ADVP
#
# held I-VP
#
# 6.5 I-NP
#
# % I-ADJP
#
# convertible B-ADJP
#
# Series I-NP
#
# C I-NP
#
# preferred I-NP
#
# stock I-NP
#
# Nov. B-NP
#
# 8 B-NP
#
# . O
#
# new sentence
# On B-PP
#
# a B-LST
#
# $ B-NP
#
# 10,000 I-NP
#
# investment I-NP
#
# , O
#
# that B-SBAR
#
# 's B-NP
#
# a B-LST
#
# difference I-NP
#
# of I-PP
#
# only I-CONJP
#
# $ B-NP
#
# 50 I-NP
#
# a B-LST
#
# year I-NP
#
# . O
#
# new sentence
# Neither B-NP
#
# the B-NP
#
# Amoco B-NP
#
# agreement I-NP
#
# nor O
#
# the B-NP
#
# wells I-NP
#
# existed B-VP
#
# , O
#
# the B-NP
#
# suit I-NP
#
# alleged B-VP
#
# . O
#
# new sentence
# But O
#
# for B-PP
#
# individuals B-NP
#
# who B-NP
#
# buy I-VP
#
# much I-ADVP
#
# smaller B-ADJP
#
# amounts I-NP
#
# and I-UCP
#
# care I-NP
#
# less B-ADJP
#
# about B-PP
#
# relative B-ADJP
#
# performance I-NP
#
# than I-CONJP
#
# in B-PP
#
# preserving B-VP
#
# what B-NP
#
# they B-NP
#
# have I-VP
#
# , O
#
# that B-SBAR
#
# margin I-NP
#
# is I-INTJ
#
# meaningless is tagged as UNK and the this arg_max_y e(meaningless|y) is B-UCP
# meaningless B-UCP
#
# . O
#
# new sentence
# The B-NP
#
# authorities I-NP
#
# have I-VP
#
# steered is tagged as UNK and the this arg_max_y e(steered|y) is B-UCP
# steered B-UCP
#
# foreign B-NP
#
# reporters B-NP
#
# to B-PP
#
# her B-NP
#
# office I-NP
#
# to B-PP
#
# see I-VP
#
# an B-NP
#
# example B-NP
#
# of I-PP
#
# `` O
#
# the B-NP
#
# new I-NP
#
# way I-NP
#
# of I-PP
#
# thinking I-VP
#
# . O
#
# '' O
#
# new sentence
# That B-NP
#
# 's B-NP
#
# because B-SBAR
#
# computers I-NP
#
# do B-VP
#
# most B-ADJP
#
# of I-PP
#
# the B-NP
#
# work I-VP
#
# , O
#
# and I-UCP
#
# low I-ADJP
#
# trading I-NP
#
# activity I-NP
#
# keeps B-VP
#
# a B-LST
#
# lid I-NP
#
# on B-PP
#
# commission I-NP
#
# costs I-NP
#
# . O
#
# new sentence
# Mr. B-NP
#
# Pinola I-NP
#
# is I-INTJ
#
# president I-NP
#
# and I-UCP
#
# chief B-NP
#
# operating I-VP
#
# officer I-NP
#
# of I-PP
#
# Penn is tagged as UNK and the this arg_max_y e(Penn|y) is B-UCP
# Penn B-UCP
#
# Mutual I-NP
#
# Life I-NP
#
# Insurance I-NP
#
# Co I-NP
#
# . O
#
# new sentence
# John B-NP
#
# Uphoff is tagged as UNK and the this arg_max_y e(Uphoff|y) is B-UCP
# Uphoff B-UCP
#
# , O
#
# an B-NP
#
# analyst I-NP
#
# with B-PP
#
# Raymond B-NP
#
# James B-NP
#
# & I-NP
#
# Associates I-NP
#
# , O
#
# said B-VP
#
# the B-NP
#
# results I-NP
#
# were B-VP
#
# n't I-VP
#
# surprising I-ADJP
#
# , O
#
# and I-UCP
#
# attributed B-VP
#
# the B-NP
#
# buy-back I-NP
#
# to B-PP
#
# management I-NP
#
# 's B-NP
#
# confidence B-NP
#
# in B-PP
#
# the B-NP
#
# Mirage I-NP
#
# 's B-NP
#
# ability I-NP
#
# to B-PP
#
# generate I-VP
#
# strong I-ADJP
#
# cash B-NP
#
# flow I-NP
#
# in B-PP
#
# 1990 B-NP
#
# . O
#
# new sentence
# Raymond B-NP
#
# James B-NP
#
# & I-NP
#
# Associates I-NP
#
# in B-PP
#
# St. B-NP
#
# Petersburg is tagged as UNK and the this arg_max_y e(Petersburg|y) is B-UCP
# Petersburg B-UCP
#
# , O
#
# Fla. B-NP
#
# , O
#
# lowered B-VP
#
# its B-NP
#
# third-quarter B-NP
#
# earnings I-NP
#
# estimate I-NP
#
# for B-PP
#
# the B-NP
#
# company I-NP
#
# , O
#
# according B-PP
#
# to B-PP
#
# Dow I-NP
#
# Jones I-NP
#
# Professional I-NP
#
# Investor I-NP
#
# Report I-NP
#
# . O
#
# new sentence
# Osborn is tagged as UNK and the this arg_max_y e(Osborn|y) is B-UCP
# Osborn B-UCP
#
# also I-CONJP
#
# operates B-VP
#
# Muzak is tagged as UNK and the this arg_max_y e(Muzak|y) is B-UCP
# Muzak B-UCP
#
# franchises is tagged as UNK and the this arg_max_y e(franchises|y) is B-UCP
# franchises B-UCP
#
# , O
#
# entertainment I-NP
#
# properties I-NP
#
# and I-UCP
#
# small I-ADJP
#
# cable-television is tagged as UNK and the this arg_max_y e(cable-television|y) is B-UCP
# cable-television B-UCP
#
# systems I-NP
#
# . O
#
# new sentence
# Digital B-NP
#
# , O
#
# based B-VP
#
# in B-PP
#
# Maynard I-NP
#
# , O
#
# Mass. B-NP
#
# , O
#
# hopes B-VP
#
# to B-PP
#
# stage I-NP
#
# a B-LST
#
# repeat I-VP
#
# performance I-NP
#
# in B-PP
#
# mainframes I-NP
#
# , O
#
# and I-UCP
#
# it B-NP
#
# has B-VP
#
# spent B-VP
#
# almost B-ADJP
#
# $ B-NP
#
# 1 B-LST
#
# billion I-NP
#
# developing I-VP
#
# the B-NP
#
# new I-NP
#
# technology I-NP
#
# . O
#
# new sentence
# He B-NP
#
# also I-CONJP
#
# says B-VP
#
# CompuServe B-NP
#
# 's B-NP
#
# earnings I-NP
#
# continue I-VP
#
# to B-PP
#
# grow I-VP
#
# `` O
#
# 20 I-NP
#
# % I-ADJP
#
# to B-PP
#
# 30 I-NP
#
# % I-ADJP
#
# a B-LST
#
# year I-NP
#
# '' O
#
# in B-PP
#
# spite B-NP
#
# of I-PP
#
# tough I-ADJP
#
# competition I-NP
#
# from B-PP
#
# giants I-NP
#
# like B-PP
#
# Sears B-NP
#
# and I-UCP
#
# IBM B-NP
#
# . O
#
# new sentence
# The B-NP
#
# Treasury I-NP
#
# plans B-VP
#
# to B-PP
#
# raise I-VP
#
# $ B-NP
#
# 1.55 is tagged as UNK and the this arg_max_y e(1.55|y) is B-UCP
# 1.55 B-UCP
#
# billion I-NP
#
# in B-PP
#
# new I-NP
#
# cash B-NP
#
# with B-PP
#
# the B-NP
#
# sale I-NP
#
# Monday B-NP
#
# of I-PP
#
# about B-PP
#
# $ B-NP
#
# 15.6 I-NP
#
# billion I-NP
#
# in B-PP
#
# short-term I-NP
#
# bills I-NP
#
# to B-PP
#
# redeem is tagged as UNK and the this arg_max_y e(redeem|y) is B-UCP
# redeem B-UCP
#
# $ B-NP
#
# 14.1 is tagged as UNK and the this arg_max_y e(14.1|y) is B-UCP
# 14.1 B-UCP
#
# billion I-NP
#
# in B-PP
#
# maturing is tagged as UNK and the this arg_max_y e(maturing|y) is B-UCP
# maturing B-UCP
#
# bills I-NP
#
# . O
#
# new sentence
# Stocks B-NP
#
# retreated B-VP
#
# to B-PP
#
# session I-NP
#
# lows B-NP
#
# just I-CONJP
#
# after B-SBAR
#
# the B-NP
#
# opening I-VP
#
# amid B-PP
#
# worries B-NP
#
# about B-PP
#
# the B-NP
#
# market I-NP
#
# impact I-NP
#
# of I-PP
#
# the B-NP
#
# quake I-NP
#
# , O
#
# but B-CONJP
#
# quickly I-ADVP
#
# snapped B-VP
#
# back B-PRT
#
# to B-PP
#
# higher I-ADJP
#
# levels I-NP
#
# with B-PP
#
# the B-NP
#
# help I-VP
#
# of I-PP
#
# futures-related B-NP
#
# program I-NP
#
# buying I-VP
#
# . O
#
# new sentence
# There B-NP
#
# is I-INTJ
#
# no I-INTJ
#
# small I-ADJP
#
# irony I-NP
#
# in B-PP
#
# the B-NP
#
# fact I-ADVP
#
# that B-SBAR
#
# some B-NP
#
# of I-PP
#
# the B-NP
#
# most-jingoistic is tagged as UNK and the this arg_max_y e(most-jingoistic|y) is B-UCP
# most-jingoistic B-UCP
#
# advertising I-NP
#
# comes B-VP
#
# courtesy is tagged as UNK and the this arg_max_y e(courtesy|y) is B-UCP
# courtesy B-UCP
#
# of I-PP
#
# -- O
#
# you B-NP
#
# guessed is tagged as UNK and the this arg_max_y e(guessed|y) is B-UCP
# guessed B-UCP
#
# it B-NP
#
# -- O
#
# outsiders B-NP
#
# . O
#
# new sentence
# The B-NP
#
# Federal I-NP
#
# Election is tagged as UNK and the this arg_max_y e(Election|y) is B-UCP
# Election B-UCP
#
# Commission I-NP
#
# clears B-VP
#
# corporate B-NP
#
# plans B-VP
#
# to B-PP
#
# donate is tagged as UNK and the this arg_max_y e(donate|y) is B-UCP
# donate B-UCP
#
# to B-PP
#
# an B-NP
#
# employee B-NP
#
# 's B-NP
#
# chosen I-VP
#
# charity I-NP
#
# in B-PP
#
# exchange I-NP
#
# for B-PP
#
# the B-NP
#
# worker I-NP
#
# 's B-NP
#
# gift I-NP
#
# to B-PP
#
# the B-NP
#
# company I-NP
#
# political I-NP
#
# action I-NP
#
# committee I-NP
#
# . O
#
# new sentence
# The B-NP
#
# method I-NP
#
# of I-PP
#
# calculating is tagged as UNK and the this arg_max_y e(calculating|y) is B-UCP
# calculating B-UCP
#
# the B-NP
#
# 20 I-NP
#
# % I-ADJP
#
# tax I-NP
#
# , O
#
# paid I-VP
#
# if I-SBAR
#
# it B-NP
#
# exceeds B-VP
#
# tax I-NP
#
# figured B-VP
#
# the B-NP
#
# regular I-NP
#
# way I-NP
#
# , O
#
# is I-INTJ
#
# due B-ADJP
#
# for B-PP
#
# a B-LST
#
# change I-VP
#
# in B-PP
#
# 1990 B-NP
#
# , O
#
# thanks is tagged as UNK and the this arg_max_y e(thanks|y) is B-UCP
# thanks B-UCP
#
# to B-PP
#
# 1986 B-NP
#
# 's B-NP
#
# tax I-NP
#
# act I-VP
#
# . O
#
# new sentence
# I B-NP
#
# expected I-VP
#
# him B-NP
#
# to B-PP
#
# say B-INTJ
#
# , O
#
# `` O
#
# I B-NP
#
# told I-VP
#
# you B-NP
#
# so B-ADJP
#
# , O
#
# '' O
#
# but B-CONJP
#
# he B-NP
#
# already B-ADVP
#
# was B-VP
#
# snoring is tagged as UNK and the this arg_max_y e(snoring|y) is B-UCP
# snoring B-UCP
#
# . O
#
# new sentence
# Although B-SBAR
#
# the B-NP
#
# East B-NP
#
# German I-NP
#
# news I-NP
#
# agency I-NP
#
# ADN I-NP
#
# claimed B-VP
#
# Mr. B-NP
#
# Honecker I-NP
#
# had B-VP
#
# asked B-VP
#
# to B-PP
#
# be I-VP
#
# relieved B-ADJP
#
# of I-PP
#
# his B-NP
#
# duties I-NP
#
# for B-PP
#
# `` O
#
# health I-NP
#
# reasons I-NP
#
# , O
#
# '' O
#
# West I-NP
#
# German I-NP
#
# government I-NP
#
# sources I-NP
#
# said B-VP
#
# the B-NP
#
# 26-man is tagged as UNK and the this arg_max_y e(26-man|y) is B-UCP
# 26-man B-UCP
#
# Politburo I-NP
#
# had B-VP
#
# asked B-VP
#
# for B-PP
#
# his B-NP
#
# resignation I-NP
#
# at B-PP
#
# a B-LST
#
# separate I-NP
#
# meeting I-NP
#
# late I-ADVP
#
# Tuesday B-NP
#
# . O
#
# new sentence
# During B-PP
#
# the B-NP
#
# quarter I-NP
#
# , O
#
# Pfizer B-NP
#
# received I-VP
#
# federal I-NP
#
# approval I-NP
#
# of I-PP
#
# Procardia is tagged as UNK and the this arg_max_y e(Procardia|y) is B-UCP
# Procardia B-UCP
#
# XL is tagged as UNK and the this arg_max_y e(XL|y) is B-UCP
# XL B-UCP
#
# , O
#
# a B-LST
#
# calcium I-NP
#
# channel B-VP
#
# blocker I-NP
# approved I-VP
#
# for B-PP
#
# both B-NP
#
# angina is tagged as UNK and the this arg_max_y e(angina|y) is B-UCP
# angina B-UCP
#
# and I-UCP
#
# hypertension is tagged as UNK and the this arg_max_y e(hypertension|y) is B-UCP
# hypertension B-UCP
#
# , O
#
# and I-UCP
#
# Monorail is tagged as UNK and the this arg_max_y e(Monorail|y) is B-UCP
# Monorail B-UCP
#
# Piccolino is tagged as UNK and the this arg_max_y e(Piccolino|y) is B-UCP
# Piccolino B-UCP
#
# , O
#
# used I-VP
#
# to B-PP
#
# open B-ADJP
#
# obstructed I-VP
#
# coronary is tagged as UNK and the this arg_max_y e(coronary|y) is B-UCP
# coronary B-UCP
#
# arteries I-NP
#
# . O
#
# new sentence
# We B-NP
#
# do B-VP
#
# n't I-VP
#
# want I-VP
#
# to B-PP
#
# be I-VP
#
# party I-NP
#
# to B-PP
#
# a B-LST
#
# second I-NP
#
# rejection I-NP
#
# , O
#
# '' O
#
# he B-NP
#
# said B-VP
#
# , O
#
# adding B-VP
#
# that B-SBAR
#
# coming I-VP
#
# up B-PRT
#
# with B-PP
#
# a B-LST
#
# revised I-NP
#
# offer I-VP
#
# could B-VP
#
# easily I-ADVP
#
# take I-VP
#
# several B-NP
#
# weeks I-NP
#
# . O
#
# new sentence
# Law-enforcement is tagged as UNK and the this arg_max_y e(Law-enforcement|y) is B-UCP
# Law-enforcement B-UCP
#
# authorities I-NP
#
# say B-INTJ
#
# that B-SBAR
#
# at B-PP
#
# any B-NP
#
# given I-VP
#
# time I-NP
#
# , O
#
# a B-LST
#
# host I-NP
#
# of I-PP
#
# fraudulent B-NP
#
# telemarketing B-NP
#
# operations I-NP
#
# mingle is tagged as UNK and the this arg_max_y e(mingle|y) is B-UCP
# mingle B-UCP
#
# with B-PP
#
# the B-NP
#
# many B-NP
#
# legitimate B-NP
#
# businesses I-NP
#
# here B-ADVP
#
# . O
#
# new sentence
# The B-NP
#
# percentage I-ADVP
#
# rates I-NP
#
# are B-VP
#
# calculated B-VP
#
# on B-PP
#
# a B-LST
#
# 360-day is tagged as UNK and the this arg_max_y e(360-day|y) is B-UCP
# 360-day B-UCP
#
# year I-NP
#
# , O
#
# while B-SBAR
#
# the B-NP
#
# coupon-equivalent is tagged as UNK and the this arg_max_y e(coupon-equivalent|y) is B-UCP
# coupon-equivalent B-UCP
#
# yield I-VP
#
# is I-INTJ
#
# based B-VP
#
# on B-PP
#
# a B-LST
#
# 365-day is tagged as UNK and the this arg_max_y e(365-day|y) is B-UCP
# 365-day B-UCP
#
# year I-NP
#
# . O
#
# new sentence
# Neither B-NP
#
# was B-VP
#
# among I-PP
#
# the B-NP
#
# 46 B-NP
#
# traders B-NP
#
# indicted I-VP
#
# last I-ADVP
#
# August B-NP
#
# in B-PP
#
# a B-LST
#
# federal I-NP
#
# investigation I-NP
#
# of I-PP
#
# traders B-NP
#
# at B-PP
#
# both B-NP
#
# the B-NP
#
# Merc I-NP
#
# and I-UCP
#
# the B-NP
#
# Chicago B-NP
#
# Board I-NP
#
# of I-PP
#
# Trade B-NP
#
# . O
#
# new sentence
# A B-NP
#
# spokesman I-NP
#
# for B-PP
#
# Dean B-NP
#
# Witter I-NP
#
# , O
#
# a B-LST
#
# unit I-NP
#
# of I-PP
#
# Sears B-NP
#
# , O
#
# Roebuck I-NP
#
# & I-NP
#
# Co. I-NP
#
# , O
#
# declined B-VP
#
# to B-PP
#
# comment I-VP
#
# . O
#
# new sentence
# `` O
#
# By B-PP
#
# populating is tagged as UNK and the this arg_max_y e(populating|y) is B-UCP
# populating B-UCP
#
# a B-LST
#
# place I-VP
#
# now B-ADVP
#
# , O
#
# we B-NP
#
# make I-VP
#
# ourselves B-NP
#
# a B-LST
#
# power I-NP
#
# any B-NP
#
# new I-NP
#
# government I-NP
#
# will B-VP
#
# have I-VP
#
# to B-PP
#
# take I-VP
#
# into B-PP
#
# account B-VP
#
# . O
#
# '' O
#
# new sentence
# Also B-ADVP
#
# , O
#
# profit I-NP
#
# rose B-VP
#
# 19 B-NP
#
# % I-ADJP
#
# in B-PP
#
# the B-NP
#
# third I-NP
#
# quarter I-NP
#
# . O
#
# new sentence
# Two B-NP
#
# election I-NP
#
# commission I-NP
#
# members I-NP
#
# opposed B-VP
#
# the B-NP
#
# matching B-VP
#
# plans B-VP
#
# . O
#
# new sentence
# An B-NP
#
# accelerating is tagged as UNK and the this arg_max_y e(accelerating|y) is B-UCP
# accelerating B-UCP
#
# move I-VP
#
# by B-PP
#
# personal I-NP
#
# computer I-NP
#
# manufacturers B-NP
#
# ' B-NP
#
# to B-PP
#
# include I-VP
#
# advanced B-VP
#
# graphics B-NP
#
# capabilities I-NP
#
# as B-CONJP
#
# standard I-NP
#
# equipment I-NP
#
# further I-ADVP
#
# dampened is tagged as UNK and the this arg_max_y e(dampened|y) is B-UCP
# dampened B-UCP
#
# reseller B-NP
#
# purchases I-NP
#
# of I-PP
#
# Western B-NP
#
# Digital B-NP
#
# 's B-NP
#
# equipment I-NP
#
# . O
#
# new sentence
# When B-ADVP
#
# the B-NP
#
# IAFP I-NP
#
# recently I-ADVP
#
# assembled I-VP
#
# other B-NP
#
# industry I-NP
#
# groups I-NP
#
# to B-PP
#
# discuss I-VP
#
# common I-ADJP
#
# standards I-NP
#
# that B-SBAR
#
# might B-VP
#
# be I-VP
#
# applied B-VP
#
# to B-PP
#
# planners I-NP
#
# , O
#
# Mr. B-NP
#
# Gargan I-NP
#
# 's B-NP
#
# group I-NP
#
# was B-VP
#
# excluded I-VP
#
# . O
#
# new sentence
# Mr. B-NP
#
# Peake is tagged as UNK and the this arg_max_y e(Peake|y) is B-UCP
# Peake B-UCP
#
# is I-INTJ
#
# chairman B-NP
#
# of I-PP
#
# his B-NP
#
# own I-NP
#
# consulting I-NP
#
# company I-NP
#
# in B-PP
#
# Englewood B-NP
#
# , O
#
# N.J B-NP
#
# . O
#
# new sentence
# CALL B-NP
#
# MONEY I-NP
#
# : O
#
# 9 I-NP
#
# 3\/4 I-NP
#
# % I-ADJP
#
# to B-PP
#
# 10 I-ADVP
#
# % I-ADJP
#
# . O
#
# new sentence
# The B-NP
#
# forces I-NP
#
# at B-PP
#
# work I-VP
#
# included B-VP
#
# computer-guided B-NP
#
# trading I-NP
#
# , O
#
# as B-CONJP
#
# well I-CONJP
#
# as B-CONJP
#
# profit-driven is tagged as UNK and the this arg_max_y e(profit-driven|y) is B-UCP
# profit-driven B-UCP
#
# market I-NP
#
# makers I-NP
#
# and I-UCP
#
# institutional I-NP
#
# investors B-NP
#
# who B-NP
#
# had B-VP
#
# bought B-VP
#
# stock I-NP
#
# on B-PP
#
# the B-NP
#
# cheap I-ADJP
#
# during B-PP
#
# the B-NP
#
# recent I-ADJP
#
# correction I-NP
#
# . O
#
# new sentence
# `` O
#
# The B-NP
#
# thing I-NP
#
# is I-INTJ
#
# so B-ADJP
#
# fluid is tagged as UNK and the this arg_max_y e(fluid|y) is B-UCP
# fluid B-UCP
#
# right I-ADJP
#
# now B-ADVP
#
# that B-SBAR
#
# there B-ADVP
#
# 's B-NP
#
# really B-ADVP
#
# no I-INTJ
#
# way I-NP
#
# to B-PP
#
# say B-INTJ
#
# what B-NP
#
# will B-VP
#
# happen I-VP
#
# , O
#
# '' O
#
# says B-VP
#
# Justice I-NP
#
# Department I-NP
#
# attorney I-NP
#
# Grover is tagged as UNK and the this arg_max_y e(Grover|y) is B-UCP
# Grover B-UCP
#
# Hartt is tagged as UNK and the this arg_max_y e(Hartt|y) is B-UCP
# Hartt B-UCP
#
# III I-NP
#
# , O
#
# who B-NP
#
# represents B-VP
#
# the B-NP
#
# IRS I-NP
#
# in B-PP
#
# the B-NP
#
# case I-NP
#
# . O
#
# new sentence
# That B-NP
#
# rose B-VP
#
# to B-PP
#
# nearly B-ADJP
#
# 18 B-NP
#
# % I-ADJP
#
# during B-PP
#
# the B-NP
#
# Depression is tagged as UNK and the this arg_max_y e(Depression|y) is B-UCP
# Depression B-UCP
#
# , O
#
# and I-UCP
#
# has B-VP
#
# n't I-VP
#
# changed I-ADJP
#
# much I-ADVP
#
# since B-SBAR
#
# . O
#
# new sentence
# Mr. B-NP
#
# Maynard I-NP
#
# initially B-ADVP
#
# won B-VP
#
# approval I-NP
#
# for B-PP
#
# his B-NP
#
# machine I-NP
#
# to B-PP
#
# be I-VP
#
# used I-VP
#
# at B-PP
#
# egg-processing is tagged as UNK and the this arg_max_y e(egg-processing|y) is B-UCP
# egg-processing B-UCP
#
# facilities I-NP
#
# regulated I-VP
#
# by B-PP
#
# the B-NP
#
# USDA I-NP
#
# 's B-NP
#
# Food I-NP
#
# Safety is tagged as UNK and the this arg_max_y e(Safety|y) is B-UCP
# Safety B-UCP
#
# Inspection is tagged as UNK and the this arg_max_y e(Inspection|y) is B-UCP
# Inspection B-UCP
#
# Service I-NP
#
# . O
#
# new sentence
# Fanuc is tagged as UNK and the this arg_max_y e(Fanuc|y) is B-UCP
# Fanuc B-UCP
#
# gained B-VP
#
# 100 I-NP
#
# to B-PP
#
# 7,580 is tagged as UNK and the this arg_max_y e(7,580|y) is B-UCP
# 7,580 B-UCP
#
# . O
#
# new sentence
# Forecasts is tagged as UNK and the this arg_max_y e(Forecasts|y) is B-UCP
# Forecasts B-UCP
#
# for B-PP
#
# the B-NP
#
# trade I-NP
#
# figures I-NP
#
# range I-ADJP
#
# widely I-ADVP
#
# , O
#
# but B-CONJP
#
# few I-NP
#
# economists I-NP
#
# expect B-VP
#
# the B-NP
#
# data I-NP
#
# to B-PP
#
# show I-VP
#
# a B-LST
#
# very B-ADJP
#
# marked B-VP
#
# improvement I-NP
#
# from B-PP
#
# the B-NP
#
# # B-ADJP
#
# 2 B-LST
#
# billion I-NP
#
# -LRB- O
#
# $ B-NP
#
# 3.2 is tagged as UNK and the this arg_max_y e(3.2|y) is B-UCP
# 3.2 B-UCP
#
# billion I-NP
#
# -RRB- O
#
# deficit I-NP
#
# in B-PP
#
# the B-NP
#
# current I-ADJP
#
# account B-VP
#
# reported B-VP
#
# for B-PP
#
# August B-NP
#
# . O
#
# new sentence
# Fox B-NP
#
# said B-VP
#
# it B-NP
#
# plans B-VP
#
# to B-PP
#
# offer I-VP
#
# its B-NP
#
# stations I-NP
#
# movies I-NP
#
# , O
#
# theatrical B-NP
#
# and I-UCP
#
# made-for-TV is tagged as UNK and the this arg_max_y e(made-for-TV|y) is B-UCP
# made-for-TV B-UCP
#
# ventures I-NP
#
# , O
#
# probably B-ADVP
#
# on B-PP
#
# Wednesdays B-NP
#
# , O
#
# sometime B-NP
#
# next B-ADVP
#
# year I-NP
#
# . O
#
# new sentence
# The B-NP
#
# most-strident is tagged as UNK and the this arg_max_y e(most-strident|y) is B-UCP
# most-strident B-UCP
#
# anti-outsider is tagged as UNK and the this arg_max_y e(anti-outsider|y) is B-UCP
# anti-outsider B-UCP
#
# sentiment I-NP
#
# among I-PP
#
# bankers I-NP
#
# comes B-VP
#
# from B-PP
#
# the B-NP
#
# Independent B-NP
#
# Bankers B-NP
#
# Association I-NP
#
# of I-PP
#
# Texas B-ADJP
#
# , O
#
# although B-SBAR
#
# it B-NP
#
# 's B-NP
#
# hard I-ADJP
#
# to B-PP
#
# tell I-VP
#
# from B-PP
#
# previews is tagged as UNK and the this arg_max_y e(previews|y) is B-UCP
# previews B-UCP
#
# of I-PP
#
# the B-NP
#
# $ B-NP
#
# 5 I-NP
#
# million I-NP
#
# `` O
#
# The B-NP
#
# I B-NP
#
# 's B-NP
#
# of I-PP
#
# Texas B-ADJP
#
# '' O
#
# TV I-NP
#
# campaign I-NP
#
# . O
#
# new sentence
# So-called B-NP
#
# living-benefits is tagged as UNK and the this arg_max_y e(living-benefits|y) is B-UCP
# living-benefits B-UCP
#
# provisions I-NP
#
# also I-CONJP
#
# merit B-NP
#
# a B-LST
#
# close B-ADJP
#
# inspection I-NP
#
# . O
#
# new sentence
# It B-NP
#
# would B-VP
#
# go I-VP
#
# along B-PRT
#
# doing I-VP
#
# nothing B-NP
#
# but B-CONJP
#
# dissociating is tagged as UNK and the this arg_max_y e(dissociating|y) is B-UCP
# dissociating B-UCP
#
# the B-NP
#
# heavy B-NP
#
# water I-NP
#
# and I-UCP
#
# then B-ADVP
#
# at B-PP
#
# totally B-ADJP
#
# unpredictable I-NP
#
# times I-ADVP
#
# , O
#
# it B-NP
#
# would B-VP
#
# begin I-ADVP
#
# producing I-VP
#
# excess I-NP
#
# heat I-NP
#
# for B-PP
#
# as B-CONJP
#
# long I-ADVP
#
# as B-CONJP
#
# 10 I-ADVP
#
# or I-PP
#
# 11 B-NP
#
# hours I-NP
#
# before I-SBAR
#
# quieting is tagged as UNK and the this arg_max_y e(quieting|y) is B-UCP
# quieting B-UCP
#
# down B-PRT
#
# . O
#
# new sentence
# These B-NP
#
# and I-UCP
#
# other B-NP
#
# modern I-NP
#
# trading I-NP
#
# methods is tagged as UNK and the this arg_max_y e(methods|y) is B-UCP
# methods B-UCP
#
# `` O
#
# tend B-VP
#
# to B-PP
#
# promote B-VP
#
# dramatic I-ADJP
#
# shifts B-VP
#
# in B-PP
#
# assets I-NP
#
# , O
#
# '' O
#
# says B-VP
#
# George B-NP
#
# Douglas B-NP
#
# , O
#
# first B-ADVP
#
# vice I-ADVP
#
# president I-NP
#
# at B-PP
#
# Drexel B-NP
#
# Burnham I-NP
#
# Lambert I-NP
#
# Inc I-NP
#
# . O
#
# new sentence
# Executives B-NP
#
# at B-PP
#
# Olivetti B-NP
#
# , O
#
# whose B-NP
#
# earnings I-NP
#
# have I-VP
#
# been I-VP
#
# steadily B-ADVP
# sliding B-VP
#
# over B-PRT
#
# the B-NP
#
# past I-NP
#
# couple I-NP
#
# of I-PP
#
# years I-NP
#
# , O
#
# have I-VP
#
# acknowledged B-VP
#
# that B-SBAR
#
# in B-PP
#
# the B-NP
#
# past I-NP
#
# they B-NP
#
# have I-VP
#
# lagged B-VP
#
# at B-PP
#
# getting I-VP
#
# new I-NP
#
# technology I-NP
#
# to B-PP
#
# market I-NP
#
# . O
#
# new sentence
# Tom B-NP
#
# Schumacher I-NP
#
# , O
#
# executive I-NP
#
# vice I-ADVP
#
# president I-NP
#
# and I-UCP
#
# general B-ADJP
#
# manager I-NP
#
# of I-PP
#
# the B-NP
#
# California B-NP
#
# Trucking is tagged as UNK and the this arg_max_y e(Trucking|y) is B-UCP
# Trucking B-UCP
#
# Association I-NP
#
# in B-PP
#
# Sacremento is tagged as UNK and the this arg_max_y e(Sacremento|y) is B-UCP
# Sacremento B-UCP
#
# , O
#
# said B-VP
#
# his B-NP
#
# organization I-NP
#
# urged B-VP
#
# trucking B-NP
#
# firms I-NP
#
# to B-PP
#
# halt I-VP
#
# all I-ADVP
#
# deliveries I-NP
#
# into B-PP
#
# the B-NP
#
# Bay I-NP
#
# area I-NP
#
# yesterday B-NP
#
# , O
#
# except B-PP
#
# for B-PP
#
# emergency-medical is tagged as UNK and the this arg_max_y e(emergency-medical|y) is B-UCP
# emergency-medical B-UCP
#
# supplies B-VP
#
# . O
#
# new sentence
# Real-estate B-NP
#
# interests I-NP
#
# , O
#
# for B-PP
#
# example B-NP
#
# , O
#
# are B-VP
#
# protesting is tagged as UNK and the this arg_max_y e(protesting|y) is B-UCP
# protesting B-UCP
#
# an B-NP
#
# omission is tagged as UNK and the this arg_max_y e(omission|y) is B-UCP
# omission B-UCP
#
# in B-PP
#
# President B-NP
#
# Bush I-NP
#
# 's B-NP
#
# capital-gains I-NP
#
# proposal I-NP
#
# : O
#
# It B-NP
#
# does B-VP
#
# n't I-VP
#
# include I-VP
#
# real-estate I-NP
#
# gains I-NP
#
# . O
#
# new sentence
# We B-NP
#
# expect B-VP
#
# a B-LST
#
# choppy I-ADJP
#
# and I-UCP
#
# sloppy B-ADJP
#
# market I-NP
#
# for B-PP
#
# a B-LST
#
# short I-ADJP
#
# period I-NP
#
# , O
#
# but B-CONJP
#
# we B-NP
#
# do B-VP
#
# n't I-VP
#
# think B-VP
#
# it B-NP
#
# will B-VP
#
# be I-VP
#
# ugly is tagged as UNK and the this arg_max_y e(ugly|y) is B-UCP
# ugly B-UCP
#
# . O
#
# new sentence
# Sheldon I-NP
#
# B. I-NP
#
# Lubar is tagged as UNK and the this arg_max_y e(Lubar|y) is B-UCP
# Lubar B-UCP
#
# , O
#
# chairman B-NP
#
# of I-PP
#
# Lubar is tagged as UNK and the this arg_max_y e(Lubar|y) is B-UCP
# Lubar B-UCP
#
# & I-NP
#
# Co. I-NP
#
# , O
#
# and I-UCP
#
# John B-NP
#
# L. I-NP
#
# Murray B-NP
#
# , O
#
# chairman B-NP
#
# of I-PP
#
# Universal I-NP
#
# Foods I-NP
#
# Corp. I-NP
#
# , O
#
# were B-VP
#
# elected I-VP
#
# to B-PP
#
# the B-NP
#
# board I-NP
#
# of I-PP
#
# this B-NP
#
# engine I-NP
#
# maker I-NP
#
# . O
#
# new sentence
# HLR is tagged as UNK and the this arg_max_y e(HLR|y) is B-UCP
# HLR B-UCP
#
# : O
#
# new sentence
# And O
#
# the B-NP
#
# respondents I-NP
#
# ' B-NP
#
# commitment I-NP
#
# to B-PP
#
# the B-NP
#
# stock I-NP
#
# market I-NP
#
# remains B-VP
#
# somewhat B-ADJP
#
# lighter is tagged as UNK and the this arg_max_y e(lighter|y) is B-UCP
# lighter B-UCP
#
# than I-CONJP
#
# usual B-ADJP
#
# . O
#
# new sentence
# Now B-INTJ
#
# a B-LST
#
# startling is tagged as UNK and the this arg_max_y e(startling|y) is B-UCP
# startling B-UCP
#
# new I-NP
#
# approach I-NP
#
# is I-INTJ
#
# available B-ADJP
#
# to B-PP
#
# building I-NP
#
# your B-NP
#
# financial I-ADJP
#
# portfolio I-NP
#
# without B-PP
#
# undue is tagged as UNK and the this arg_max_y e(undue|y) is B-UCP
# undue B-UCP
#
# risk I-NP
#
# , O
#
# without B-PP
#
# extensive I-NP
#
# planning I-VP
#
# and I-UCP
#
# without B-PP
#
# hurting B-VP
#
# your B-NP
#
# life I-NP
#
# style I-NP
#
# one B-NP
#
# bit I-ADJP
#
# ! O
#
# new sentence
# `` O
#
# Losses B-NP
#
# from B-PP
#
# the B-NP
#
# earthquake I-NP
#
# are B-VP
#
# expected I-VP
#
# to B-PP
#
# be I-VP
#
# of I-PP
#
# similar B-ADJP
#
# magnitude I-NP
#
# to B-PP
#
# those B-NP
#
# of I-PP
#
# Hurricane B-NP
#
# Hugo I-NP
#
# , O
#
# '' O
#
# according B-PP
#
# to B-PP
#
# Moody B-NP
#
# 's B-NP
#
# . O
#
# new sentence
# Frank B-NP
#
# Carlucci I-NP
#
# III I-NP
#
# was B-VP
#
# named I-VP
#
# to B-PP
#
# this B-NP
#
# telecommunications I-NP
#
# company I-NP
#
# 's B-NP
#
# board I-NP
#
# , O
#
# filling I-VP
#
# the B-NP
#
# vacancy I-NP
#
# created B-VP
#
# by B-PP
#
# the B-NP
#
# death I-NP
#
# of I-PP
#
# William B-NP
#
# Sobey is tagged as UNK and the this arg_max_y e(Sobey|y) is B-UCP
# Sobey B-UCP
#
# last I-ADVP
#
# May B-NP
#
# . O
#
# new sentence
# Most B-NP
#
# banking I-NP
#
# issues I-NP
#
# retreated B-VP
#
# after B-SBAR
#
# a B-LST
#
# sector I-NP
#
# downgrade I-NP
#
# by B-PP
#
# Warburg I-NP
#
# Securities I-NP
#
# , O
#
# although B-SBAR
#
# National I-NP
#
# Westminister I-NP
#
# showed B-VP
#
# strength I-NP
#
# on B-PP
#
# positive B-ADJP
#
# comments I-NP
#
# from B-PP
#
# brokerage I-NP
#
# firms I-NP
#
# about B-PP
#
# its B-NP
#
# long-term I-ADJP
#
# prospects I-NP
#
# . O
#
# new sentence
# Latest is tagged as UNK and the this arg_max_y e(Latest|y) is B-UCP
# Latest B-UCP
#
# approvals I-NP
#
# : O
#
# Bell I-NP
#
# Atlantic I-NP
#
# 's B-NP
#
# New B-NP
#
# Jersey I-NP
#
# Bell I-NP
#
# and I-UCP
#
# General B-NP
#
# Dynamics I-NP
#
# . O
#
# new sentence
# How B-ADVP
#
# should B-VP
#
# a B-LST
#
# reasonable B-ADJP
#
# member I-NP
#
# of I-PP
#
# the B-NP
#
# Federal I-NP
#
# Reserve I-NP
#
# Board I-NP
#
# interpret I-VP
#
# a B-LST
#
# congressional B-NP
#
# decision I-NP
#
# to B-PP
#
# put I-VP
#
# the B-NP
#
# secretary I-NP
#
# on B-PP
#
# the B-NP
#
# board I-NP
#
# ? O
#
# new sentence
# Assistant O
#
# U.S. I-NP
#
# Attorney I-NP
#
# Randy B-NP
#
# Mastro I-NP
#
# , O
#
# who B-NP
#
# headed I-VP
#
# the B-NP
#
# government I-NP
#
# 's B-NP
#
# racketeering is tagged as UNK and the this arg_max_y e(racketeering|y) is B-UCP
# racketeering B-UCP
#
# case I-NP
#
# against B-PP
#
# the B-NP
#
# International I-NP
#
# Brotherhood is tagged as UNK and the this arg_max_y e(Brotherhood|y) is B-UCP
# Brotherhood B-UCP
#
# of I-PP
#
# Teamsters is tagged as UNK and the this arg_max_y e(Teamsters|y) is B-UCP
# Teamsters B-UCP
#
# , O
#
# will B-VP
#
# join I-VP
#
# Gibson B-NP
#
# , O
#
# Dunn I-NP
#
# & I-NP
#
# Crutcher is tagged as UNK and the this arg_max_y e(Crutcher|y) is B-UCP
# Crutcher B-UCP
#
# in B-PP
#
# its B-NP
#
# New B-NP
#
# York I-NP
#
# office I-NP
#
# . O
#
# new sentence
# `` O
#
# Sell B-NP
#
# stocks I-NP
#
# that B-SBAR
#
# are B-VP
#
# n't I-VP
#
# doing I-VP
#
# well I-CONJP
#
# now B-ADVP
#
# , O
#
# and I-UCP
#
# that B-SBAR
#
# do B-VP
#
# n't I-VP
#
# have I-VP
#
# good I-ADJP
#
# earnings I-NP
#
# prospects I-NP
#
# , O
#
# '' O
#
# says B-VP
#
# Alfred B-NP
#
# Goldman B-NP
#
# , O
#
# technical B-ADJP
#
# analyst I-NP
#
# at B-PP
#
# St. B-NP
#
# Louis-based I-NP
#
# A.G. B-NP
#
# Edwards I-NP
#
# & I-NP
#
# Sons O
#
# . O
#
# new sentence
# Leonard is tagged as UNK and the this arg_max_y e(Leonard|y) is B-UCP
# Leonard B-UCP
#
# Bickwit is tagged as UNK and the this arg_max_y e(Bickwit|y) is B-UCP
# Bickwit B-UCP
#
# , O
#
# an B-NP
#
# attorney I-NP
#
# in B-PP
#
# Washington B-NP
#
# for B-PP
#
# Mr. B-NP
#
# Keating I-NP
#
# , O
#
# declined B-VP
#
# to B-PP
#
# comment I-VP
#
# on B-PP
#
# the B-NP
#
# hearings I-NP
#
# , O
#
# except B-PP
#
# to B-PP
#
# say B-INTJ
#
# , O
#
# `` O
#
# We B-NP
#
# will B-VP
#
# be I-VP
#
# responding is tagged as UNK and the this arg_max_y e(responding|y) is B-UCP
# responding B-UCP
#
# comprehensively is tagged as UNK and the this arg_max_y e(comprehensively|y) is B-UCP
# comprehensively B-UCP
#
# in B-PP
#
# several B-NP
#
# forums I-NP
#
# to B-PP
#
# each B-NP
#
# of I-PP
#
# these B-NP
#
# allegations I-NP
#
# at B-PP
#
# the B-NP
#
# appropriate B-NP
#
# time I-NP
#
# . O
#
# '' O
#
# new sentence
# The B-NP
#
# directors I-NP
#
# ' B-NP
#
# action I-NP
#
# , O
#
# taken I-VP
#
# Oct. B-NP
#
# 10 I-ADVP
#
# but B-CONJP
#
# announced B-VP
#
# Friday B-NP
#
# , O
#
# had B-VP
#
# little I-ADJP
#
# or I-PP
#
# no I-INTJ
#
# effect I-NP
#
# on B-PP
#
# the B-NP
#
# company I-NP
#
# 's B-NP
#
# stock I-NP
#
# , O
#
# which B-NP
#
# stagnated is tagged as UNK and the this arg_max_y e(stagnated|y) is B-UCP
# stagnated B-UCP
#
# at B-PP
#
# $ B-NP
#
# 4.75 I-NP
#
# in B-PP
#
# light B-ADJP
#
# over-the-counter I-NP
#
# trading I-NP
#
# . O
#
# new sentence
# Few B-NP
#
# specialists B-NP
#
# said B-VP
#
# they B-NP
#
# expect B-VP
#
# the B-NP
#
# quake I-NP
#
# to B-PP
#
# have I-VP
#
# much I-ADVP
#
# of I-PP
#
# an B-NP
#
# effect I-NP
#
# on B-PP
#
# most B-ADJP
#
# California B-NP
#
# property I-NP
#
# values I-NP
#
# . O
#
# new sentence
# Food I-NP
#
# prices I-NP
#
# rose B-VP
#
# 0.2 B-NP
#
# % I-ADJP
#
# for B-PP
#
# the B-NP
#
# second I-NP
#
# month I-NP
#
# in B-PP
#
# a B-LST
#
# row I-NP
#
# , O
#
# far I-ADVP
#
# slower I-ADJP
#
# than I-CONJP
#
# the B-NP
#
# monthly B-ADVP
#
# rises B-VP
#
# earlier B-ADVP
#
# in B-PP
#
# the B-NP
#
# year I-NP
#
# . O
#
# new sentence
# There B-NP
#
# was B-VP
#
# no I-INTJ
#
# cost I-VP
#
# estimate I-NP
#
# for B-PP
#
# the B-NP
#
# second I-NP
#
# phase I-VP
#
# . O
#
# new sentence
# Some B-NP
#
# couples I-NP
#
# continue I-VP
#
# to B-PP
#
# try I-VP
#
# . O
#
# new sentence
# Stocks B-NP
#
# of I-PP
#
# major I-NP
#
# toy I-NP
#
# makers I-NP
#
# rallied B-VP
#
# in B-PP
#
# the B-NP
#
# wake I-NP
#
# of I-PP
#
# strong I-ADJP
#
# third-quarter B-NP
#
# earnings I-NP
#
# reports I-NP
#
# . O
#
# new sentence
# Bay I-NP
#
# Financial I-NP
#
# , O
#
# which B-NP
#
# said B-VP
#
# it B-NP
#
# may B-VP
#
# be I-VP
#
# forced I-VP
#
# to B-PP
#
# file I-VP
#
# under B-PP
#
# Chapter B-NP
#
# 11 B-NP
#
# if I-SBAR
#
# it B-NP
#
# ca B-VP
#
# n't I-VP
#
# reach I-VP
#
# an B-NP
#
# agreement I-NP
#
# with B-PP
#
# its B-NP
#
# lenders B-NP
#
# to B-PP
#
# relieve is tagged as UNK and the this arg_max_y e(relieve|y) is B-UCP
# relieve B-UCP
#
# its B-NP
#
# debt I-NP
#
# burden I-NP
#
# , O
#
# plunged B-VP
#
# 1 B-LST
#
# 3\/8 I-NP
#
# to B-PP
#
# 2 B-LST
#
# 1\/8 I-NP
#
# . O
#
# new sentence
# His B-NP
#
# recommendation is tagged as UNK and the this arg_max_y e(recommendation|y) is B-UCP
# recommendation B-UCP
#
# was B-VP
#
# rejected B-VP
#
# by B-PP
#
# the B-NP
#
# government I-NP
#
# . O
#
# new sentence
# `` O
#
# The B-NP
#
# programs I-NP
#
# have I-VP
#
# arthritis is tagged as UNK and the this arg_max_y e(arthritis|y) is B-UCP
# arthritis B-UCP
#
# , O
#
# '' O
#
# says B-VP
#
# Rep. B-NP
#
# Henry I-NP
#
# Hyde I-NP
#
# , O
#
# a B-LST
#
# conservative I-ADJP
#
# Republican I-NP
#
# from B-PP
#
# Illinois I-NP
#
# . O
#
# new sentence
# You B-NP
#
# 'll B-VP
#
# see I-VP
#
# carriers I-NP
#
# try I-VP
#
# to B-PP
#
# recoup is tagged as UNK and the this arg_max_y e(recoup|y) is B-UCP
# recoup B-UCP
#
# some B-NP
#
# of I-PP
#
# the B-NP
#
# price I-NP
#
# cutting I-VP
#
# that B-SBAR
#
# occurred B-VP
#
# previously B-ADVP
#
# . O
#
# '' O
#
# new sentence
# And O
#
# they B-NP
#
# have I-VP
#
# bought B-VP
#
# about B-PP
#
# $ B-NP
#
# 500 I-NP
#
# million I-NP
#
# in B-PP
#
# prepaid-tuition is tagged as UNK and the this arg_max_y e(prepaid-tuition|y) is B-UCP
# prepaid-tuition B-UCP
#
# plans B-VP
#
# , O
#
# offered I-VP
#
# in B-PP
#
# Michigan B-NP
#
# , O
#
# Florida B-NP
#
# and I-UCP
#
# Wyoming B-NP
#
# . O
#
# new sentence
# Meanwhile B-ADVP
#
# , O
#
# Eurocom B-NP
#
# , O
#
# which B-NP
#
# had B-VP
#
# held I-VP
#
# 20 I-NP
#
# % I-ADJP
#
# of I-PP
#
# WCRS B-NP
#
# 's B-NP
#
# ad I-NP
#
# unit I-NP
#
# , O
#
# will B-VP
#
# pay I-VP
#
# # B-ADJP
#
# 43.5 I-NP
#
# million I-NP
#
# -LRB- O
#
# $ B-NP
# 68.5 is tagged as UNK and the this arg_max_y e(68.5|y) is B-UCP
# 68.5 B-UCP
#
# million I-NP
#
# -RRB- O
#
# to B-PP
#
# raise I-VP
#
# its B-NP
#
# stake I-NP
#
# to B-PP
#
# 60 B-NP
#
# % I-ADJP
#
# . O
#
# new sentence
# The B-NP
#
# Treasury I-NP
#
# 's B-NP
#
# benchmark I-NP
#
# 30-year B-NP
#
# bond I-NP
#
# fell B-VP
#
# more B-ADJP
#
# than I-CONJP
#
# 1\/2 I-ADJP
#
# point I-ADVP
#
# , O
#
# or I-PP
#
# over B-PRT
#
# $ B-NP
#
# 5 I-NP
#
# for B-PP
#
# each B-NP
#
# $ B-NP
#
# 1,000 I-ADJP
#
# face B-VP
#
# amount I-NP
#
# , O
#
# while B-SBAR
#
# the B-NP
#
# yield I-VP
#
# moved I-VP
#
# above I-PP
#
# 8 B-NP
#
# % I-ADJP
#
# for B-PP
#
# the B-NP
#
# first B-ADVP
#
# time I-NP
#
# since B-SBAR
#
# Thursday B-NP
#
# . O
#
# new sentence
# Yet B-ADVP
#
# her B-NP
#
# intensity I-NP
#
# stops I-NP
#
# and I-UCP
#
# starts I-NP
#
# with B-PP
#
# the B-NP
#
# music I-NP
#
# . O
#
# new sentence
# The B-NP
#
# results I-NP
#
# compare I-VP
#
# with B-PP
#
# a B-LST
#
# year-earlier I-NP
#
# net B-NP
#
# loss I-NP
#
# of I-PP
#
# $ B-NP
#
# 1.5 I-NP
#
# million I-NP
#
# , O
#
# or I-PP
#
# seven B-NP
#
# cents I-NP
#
# a B-LST
#
# share I-NP
#
# , O
#
# based B-VP
#
# on B-PP
#
# 20.3 is tagged as UNK and the this arg_max_y e(20.3|y) is B-UCP
# 20.3 B-UCP
#
# million I-NP
#
# common I-ADJP
#
# and I-UCP
#
# dilutive I-NP
#
# equivalents I-NP
#
# outstanding B-ADJP
#
# . O
#
# new sentence
# Revenue B-NP
#
# dropped B-VP
#
# 1.6 I-NP
#
# % I-ADJP
#
# to B-PP
#
# $ B-NP
#
# 1.21 I-NP
#
# billion I-NP
#
# from B-PP
#
# $ B-NP
#
# 1.23 I-NP
#
# billion I-NP
#
# . O
#
# new sentence
# Charleston B-NP
#
# is I-INTJ
#
# historic I-NP
#
# and I-UCP
#
# aristocratic is tagged as UNK and the this arg_max_y e(aristocratic|y) is B-UCP
# aristocratic B-UCP
#
# , O
#
# as B-CONJP
#
# your B-NP
#
# reporter I-NP
#
# said B-VP
#
# , O
#
# but B-CONJP
#
# not B-CONJP
#
# haughty is tagged as UNK and the this arg_max_y e(haughty|y) is B-UCP
# haughty B-UCP
#
# , O
#
# as B-CONJP
#
# he B-NP
#
# suggested B-VP
#
# . O
#
# new sentence
# This B-NP
#
# magazine I-NP
#
# and I-UCP
#
# book I-NP
#
# publisher I-NP
#
# said B-VP
#
# three B-NP
#
# men I-NP
#
# were B-VP
#
# elected I-VP
#
# directors I-NP
#
# , O
#
# increasing B-VP
#
# the B-NP
#
# board I-NP
#
# to B-PP
#
# 10 I-ADVP
#
# . O
#
# new sentence
# Among B-PP
#
# the B-NP
#
# Guinness I-NP
#
# disk I-NP
#
# 's B-NP
#
# wonders B-NP
#
# : O
#
# the B-NP
#
# world I-NP
#
# 's B-NP
#
# loudest is tagged as UNK and the this arg_max_y e(loudest|y) is B-UCP
# loudest B-UCP
#
# recorded B-VP
#
# belch is tagged as UNK and the this arg_max_y e(belch|y) is B-UCP
# belch B-UCP
#
# . O
#
# new sentence
# The B-NP
#
# company I-NP
#
# , O
#
# which B-NP
#
# is I-INTJ
#
# retaining B-NP
#
# most B-ADJP
#
# of I-PP
#
# its B-NP
#
# wine B-UCP
#
# and I-UCP
#
# all I-ADVP
#
# of I-PP
#
# its B-NP
#
# soft-drink I-UCP
#
# interests I-NP
#
# , O
#
# did B-VP
#
# n't I-VP
#
# break I-VP
#
# out B-PRT
#
# results I-NP
#
# for B-PP
#
# the B-NP
#
# businesses I-NP
#
# it B-NP
#
# plans B-VP
#
# to B-PP
#
# sell I-VP
#
# . O
#
# new sentence
# `` O
#
# The B-NP
#
# press I-NP
#
# has B-VP
#
# been I-VP
#
# doing I-VP
#
# an B-NP
#
# excellent is tagged as UNK and the this arg_max_y e(excellent|y) is B-UCP
# excellent B-UCP
#
# job I-NP
#
# . O
#
# new sentence
# Two B-NP
#
# rules I-NP
#
# in B-PP
#
# pending B-ADJP
#
# congressional B-NP
#
# legislation I-NP
#
# threaten I-VP
#
# to B-PP
#
# hinder I-VP
#
# leveraged I-ADJP
#
# buy-outs B-NP
#
# by B-PP
#
# raising B-VP
#
# the B-NP
#
# price I-NP
#
# tags is tagged as UNK and the this arg_max_y e(tags|y) is B-UCP
# tags B-UCP
#
# of I-PP
#
# such B-PP
#
# deals I-NP
#
# by B-PP
#
# as B-CONJP
#
# much I-ADVP
#
# as B-CONJP
#
# 10 I-ADVP
#
# % I-ADJP
#
# . O
#
# new sentence
# `` O
#
# We B-NP
#
# hope B-VP
#
# to B-PP
#
# sensitize is tagged as UNK and the this arg_max_y e(sensitize|y) is B-UCP
# sensitize B-UCP
#
# employers I-NP
#
# '' O
#
# to B-PP
#
# recognize I-VP
#
# the B-NP
#
# problems I-NP
#
# so B-ADJP
#
# they B-NP
#
# can B-VP
#
# do B-VP
#
# something B-NP
#
# about B-PP
#
# them B-NP
#
# , O
#
# Dr. B-NP
#
# Warshaw I-NP
#
# said B-VP
#
# . O
#
# new sentence
# A B-NP
#
# year I-NP
#
# earlier B-ADVP
#
# sales I-NP
#
# totaled B-VP
#
# 7.567 is tagged as UNK and the this arg_max_y e(7.567|y) is B-UCP
# 7.567 B-UCP
#
# billion I-NP
#
# francs I-NP
#
# . O
#
# new sentence
# `` O
#
# We B-NP
#
# 're B-VP
#
# encouraging B-VP
#
# a B-LST
#
# graceful I-NP
#
# transition I-NP
#
# , O
#
# '' O
#
# says B-VP
#
# Mary I-NP
#
# Kay B-NP
#
# Poppenberg is tagged as UNK and the this arg_max_y e(Poppenberg|y) is B-UCP
# Poppenberg B-UCP
#
# , O
#
# the B-NP
#
# organization I-NP
#
# 's B-NP
#
# president I-NP
#
# . O
#
# new sentence
# The B-NP
#
# National I-NP
#
# Taxpayers I-NP
#
# Union I-NP
#
# would B-VP
#
# like B-PP
#
# Congress B-NP
#
# to B-PP
#
# add I-VP
#
# 800,000 I-NP
#
# acres I-NP
#
# to B-PP
#
# the B-NP
#
# 453,000 is tagged as UNK and the this arg_max_y e(453,000|y) is B-UCP
# 453,000 B-UCP
#
# of I-PP
#
# shoreline is tagged as UNK and the this arg_max_y e(shoreline|y) is B-UCP
# shoreline B-UCP
#
# in B-PP
#
# the B-NP
#
# system I-NP
#
# by B-PP
#
# enacting B-VP
#
# `` O
#
# The B-NP
#
# Coastal B-NP
#
# Barrier is tagged as UNK and the this arg_max_y e(Barrier|y) is B-UCP
# Barrier B-UCP
#
# Improvement is tagged as UNK and the this arg_max_y e(Improvement|y) is B-UCP
# Improvement B-UCP
#
# Act I-NP
#
# of I-PP
#
# 1989 I-NP
#
# . O
#
# '' O
#
# new sentence
# Digital B-NP
#
# 's B-NP
#
# failure I-NP
#
# to B-PP
#
# deliver I-VP
#
# a B-LST
#
# true I-ADJP
#
# mainframe-class I-NP
#
# machine I-NP
#
# before I-SBAR
#
# now B-ADVP
#
# may B-VP
#
# have I-VP
#
# cost I-VP
#
# the B-NP
#
# company I-NP
#
# as B-CONJP
#
# much I-ADVP
#
# as B-CONJP
#
# $ B-NP
#
# 1 B-LST
#
# billion I-NP
#
# in B-PP
#
# revenue I-NP
#
# in B-PP
#
# fiscal B-NP
#
# 1989 I-NP
#
# , O
#
# Mr. B-NP
#
# Willman I-NP
#
# says B-VP
#
# . O
#
# new sentence
# It B-NP
#
# is I-INTJ
#
# n't I-VP
#
# . O
#
# new sentence
# Detroit B-NP
#
# Edison B-NP
#
# , O
#
# the B-NP
#
# plan I-NP
#
# pioneer is tagged as UNK and the this arg_max_y e(pioneer|y) is B-UCP
# pioneer B-UCP
#
# , O
#
# generated B-VP
#
# $ B-NP
#
# 54,000 B-NP
#
# in B-PP
#
# matching B-VP
#
# funds I-NP
#
# this B-NP
#
# year I-NP
#
# , O
#
# up B-PRT
#
# from B-PP
#
# $ B-NP
#
# 39,000 is tagged as UNK and the this arg_max_y e(39,000|y) is B-UCP
# 39,000 B-UCP
#
# in B-PP
#
# 1988 B-NP
#
# . O
#
# new sentence
# Along B-PP
#
# with B-PP
#
# the B-NP
#
# car I-NP
#
# , O
#
# Wacoal B-NP
#
# plans B-VP
#
# to B-PP
#
# launch I-VP
#
# a B-LST
#
# series I-NP
#
# of I-PP
#
# Caspita-brand is tagged as UNK and the this arg_max_y e(Caspita-brand|y) is B-UCP
# Caspita-brand B-UCP
#
# men I-NP
#
# 's B-NP
#
# underwear I-NP
#
# . O
#
# new sentence
# A B-NP
#
# columnist I-NP
#
# in B-PP
#
# the B-NP
#
# Atlanta B-NP
#
# Journal I-NP
#
# and I-UCP
#
# Constitution I-NP
#
# wrote B-VP
#
# : O
#
# `` O
#
# Who B-NP
#
# did B-VP
#
# the B-NP
#
# research I-NP
#
# for B-PP
#
# this B-NP
#
# report I-VP
#
# ? O
#
# new sentence
# Computer I-NP
#
# Sciences is tagged as UNK and the this arg_max_y e(Sciences|y) is B-UCP
# Sciences B-UCP
#
# Corp. I-NP
#
# , O
#
# El B-NP
#
# Segundo I-NP
#
# , O
#
# Calif. B-NP
#
# , O
#
# said B-VP
#
# the B-NP
#
# National I-NP
#
# Aeronautics I-NP
#
# and I-UCP
#
# Space I-NP
#
# Administration I-NP
#
# will B-VP
#
# negotiate I-VP
#
# details B-NP
#
# of I-PP
#
# a B-LST
#
# contract I-NP
#
# valued B-VP
#
# at B-PP
#
# about B-PP
#
# $ B-NP
#
# 170 I-NP
#
# million I-NP
#
# to B-PP
#
# provide I-VP
#
# software I-NP
#
# for B-PP
#
# the B-NP
#
# Ames B-NP
#
# Research I-NP
#
# Center I-NP
#
# . O
#
# new sentence
# He B-NP
#
# was B-VP
#
# a B-LST
#
# `` O
#
# socialist B-NP
#
# warrior is tagged as UNK and the this arg_max_y e(warrior|y) is B-UCP
# warrior B-UCP
#
# '' O
#
# who B-NP
#
# felt B-VP
#
# rankled is tagged as UNK and the this arg_max_y e(rankled|y) is B-UCP
# rankled B-UCP
#
# by B-PP
#
# West I-NP
#
# Germany I-NP
#
# 's B-NP
#
# enormous I-ADJP
#
# postwar I-NP
#
# prosperity I-NP
#
# and I-UCP
#
# the B-NP
#
# Bonn B-NP
#
# government I-NP
#
# 's B-NP
#
# steadfast is tagged as UNK and the this arg_max_y e(steadfast|y) is B-UCP
# steadfast B-UCP
#
# refusal is tagged as UNK and the this arg_max_y e(refusal|y) is B-UCP
# refusal B-UCP
#
# to B-PP
#
# recognize I-VP
#
# the B-NP
#
# legitimacy B-NP
#
# of I-PP
#
# his B-NP
#
# state I-NP
#
# . O
#
# new sentence
# The B-NP
#
# Senate I-NP
#
# estimates B-VP
#
# that B-SBAR
#
# its B-NP
#
# version I-NP
#
# of I-PP
#
# the B-NP
#
# provision I-NP
#
# would B-VP
#
# yield I-VP
#
# $ B-NP
#
# 17 I-NP
#
# million I-NP
#
# the B-NP
#
# first B-ADVP
#
# year I-NP
#
# and I-UCP
#
# a B-LST
#
# total I-NP
#
# of I-PP
#
# $ B-NP
#
# 409 I-NP
#
# million I-NP
#
# over B-PRT
#
# five B-NP
#
# years I-NP
#
# . O
#
# new sentence
# Trinova B-NP
#
# third-quarter B-NP
#
# loss I-NP
#
# after B-SBAR
#
# a B-LST
#
# charge I-NP
#
# for B-PP
#
# a B-LST
#
# planned B-VP
#
# restructuring I-NP
#
# , O
#
# which B-NP
#
# will B-VP
#
# include I-VP
#
# the B-NP
#
# closing B-VP
#
# or I-PP
#
# downsizing is tagged as UNK and the this arg_max_y e(downsizing|y) is B-UCP
# downsizing B-UCP
#
# of I-PP
#
# about B-PP
#
# 25 B-NP
#
# % I-ADJP
#
# of I-PP
#
# its B-NP
#
# plants I-NP
#
# and I-UCP
#
# a B-LST
#
# work I-VP
#
# force I-VP
#
# cut I-VP
#
# of I-PP
#
# about B-PP
#
# 1,500 B-NP
#
# over B-PRT
#
# three B-NP
#
# years I-NP
#
# . O
#
# new sentence
# Dealers B-NP
#
# said B-VP
#
# it B-NP
#
# was B-VP
#
# hit I-VP
#
# by B-PP
#
# some B-NP
#
# profit-taking B-NP
#
# after B-SBAR
#
# gains I-NP
#
# since B-SBAR
#
# mid-week is tagged as UNK and the this arg_max_y e(mid-week|y) is B-UCP
# mid-week B-UCP
#
# . O
#
# new sentence
# GM B-NP
#
# said B-VP
#
# the B-NP
#
# assembly I-NP
#
# plant I-NP
#
# , O
#
# which B-NP
#
# builds B-VP
#
# the B-NP
#
# Chevrolet I-NP
#
# Corsica I-NP
#
# and I-UCP
#
# Beretta I-NP
#
# compact B-NP
#
# cars I-NP
#
# , O
#
# originally B-ADVP
#
# was B-VP
#
# scheduled I-VP
#
# to B-PP
#
# reopen I-VP
#
# Monday B-NP
#
# but B-CONJP
#
# now B-ADVP
#
# will B-VP
#
# not B-CONJP
#
# resume I-VP
#
# production I-NP
#
# until B-SBAR
#
# Oct. B-NP
#
# 30 I-NP
#
# . O
#
# new sentence
# The B-NP
#
# lawsuit I-NP
#
# states I-NP
#
# that B-SBAR
#
# unless B-SBAR
#
# the B-NP
#
# sanctions I-NP
#
# are B-VP
#
# halted I-NP
#
# pending B-ADJP
#
# an B-NP
#
# appeal I-VP
#
# , O
#
# the B-NP
#
# broker I-NP
#
# and I-UCP
#
# his B-NP
#
# firm I-NP
#
# `` O
#
# will B-VP
#
# be I-VP
#
# irreparably is tagged as UNK and the this arg_max_y e(irreparably|y) is B-UCP
# irreparably B-UCP
#
# injured I-VP
#
# and I-UCP
#
# their B-NP
#
# business I-NP
#
# will B-VP
#
# be I-VP
#
# totally B-ADJP
#
# and I-UCP
#
# permanently B-ADJP
#
# destroyed I-VP
#
# . O
#
# '' O
#
# new sentence
# Construction B-NP
#
# of I-PP
#
# the B-NP
#
# 34-floor is tagged as UNK and the this arg_max_y e(34-floor|y) is B-UCP
# 34-floor B-UCP
#
# building I-NP
#
# will B-VP
#
# begin I-ADVP
#
# next B-ADVP
#
# May B-NP
#
# and I-UCP
#
# should B-VP
#
# be I-VP
#
# completed I-VP
#
# in B-PP
#
# April B-NP
#
# 1992 B-NP
#
# . O
#
# new sentence
# Mr. B-NP
#
# Batchelder I-NP
#
# says B-VP
#
# that B-SBAR
#
# in B-PP
#
# the B-NP
#
# past I-NP
#
# , O
#
# banks I-NP
#
# would B-VP
#
# normally B-ADVP
#
# have I-VP
#
# loaned is tagged as UNK and the this arg_max_y e(loaned|y) is B-UCP
# loaned B-UCP
#
# 65 B-NP
#
# % I-ADJP
#
# of I-PP
#
# a B-LST
#
# total I-NP
#
# buy-out I-NP
#
# price I-NP
#
# , O
#
# with B-PP
#
# the B-NP
#
# loans I-NP
#
# secured I-ADJP
#
# by B-PP
#
# the B-NP
#
# target I-VP
#
# company I-NP
#
# 's B-NP
#
# assets I-NP
#
# . O
#
# new sentence
# They B-NP
#
# point I-ADVP
#
# at B-PP
#
# the B-NP
#
# numerous B-NP
#
# developing-country B-NP
#
# governments I-NP
#
# that B-SBAR
#
# have I-VP
#
# inflated I-VP
#
# , O
#
# taxed I-VP
#
# and I-UCP
#
# regulated I-VP
#
# themselves B-NP
#
# into B-PP
#
# despair is tagged as UNK and the this arg_max_y e(despair|y) is B-UCP
# despair B-UCP
#
# under B-PP
#
# successive is tagged as UNK and the this arg_max_y e(successive|y) is B-UCP
# successive B-UCP
#
# IMF I-NP
#
# programs I-NP
#
# . O
#
# new sentence
# It B-NP
#
# said B-VP
#
# the B-NP
#
# reduction I-NP
#
# reflects B-VP
#
# impaired is tagged as UNK and the this arg_max_y e(impaired|y) is B-UCP
# impaired B-UCP
#
# business I-NP
#
# prospects I-NP
#
# and I-UCP
#
# reduced I-VP
#
# financial I-ADJP
#
# flexibility B-NP
#
# caused B-VP
#
# by B-PP
#
# continuing I-VP
#
# losses I-NP
#
# at B-PP
#
# the B-NP
#
# maker I-NP
#
# of I-PP
#
# Winchester B-NP
#
# disk I-NP
#
# drives I-NP
#
# . O
#
# new sentence
# The B-NP
#
# company I-NP
#
# , O
#
# which B-NP
#
# went B-VP
#
# public B-ADJP
#
# in B-PP
#
# May B-NP
#
# , O
#
# intends B-VP
#
# to B-PP
#
# pay I-VP
#
# dividends I-NP
#
# from B-PP
#
# available B-ADJP
#
# cash B-NP
#
# flow I-NP
#
# ; O
#
# the B-NP
#
# amount I-NP
#
# may B-VP
#
# vary B-VP
#
# from B-PP
#
# quarter I-NP
#
# to B-PP
#
# quarter I-NP
#
# . O
#
# new sentence
# Last B-NP
#
# year I-NP
#
# , O
#
# the B-NP
#
# prisons I-NP
#
# ' B-NP
#
# sales I-NP
#
# to B-PP
#
# the B-NP
#
# Pentagon I-NP
#
# totaled B-VP
#
# $ B-NP
#
# 336 is tagged as UNK and the this arg_max_y e(336|y) is B-UCP
# 336 B-UCP
#
# million I-NP
#
# . O
#
# new sentence
# Then B-ADVP
#
# I B-NP
#
# remembered I-VP
#
# the B-NP
#
# quake I-NP
#
# of I-PP
#
# '71 is tagged as UNK and the this arg_max_y e('71|y) is B-UCP
# '71 B-UCP
#
# , O
#
# which B-NP
#
# I B-NP
#
# experienced I-VP
#
# in B-PP
#
# Santa B-NP
#
# Barbara B-NP
#
# in B-PP
#
# a B-LST
#
# second-story is tagged as UNK and the this arg_max_y e(second-story|y) is B-UCP
# second-story B-UCP
# motel is tagged as UNK and the this arg_max_y e(motel|y) is B-UCP
# motel B-UCP
#
# room I-NP
#
# . O
#
# new sentence
# The B-NP
#
# best I-ADVP
#
# course B-NP
#
# for B-PP
#
# individual B-NP
#
# investors B-NP
#
# is I-INTJ
#
# to B-PP
#
# sell I-VP
#
# these B-NP
#
# stocks I-NP
#
# now B-ADVP
#
# , O
#
# the B-NP
#
# two B-NP
#
# advisers I-NP
#
# say B-INTJ
#
# . O
#
# new sentence
# He B-NP
#
# believes B-VP
#
# that B-SBAR
#
# the B-NP
#
# task I-NP
#
# facing I-VP
#
# Fed I-NP
#
# Chairman I-NP
#
# Alan B-NP
#
# Greenspan I-NP
#
# is I-INTJ
#
# so B-ADJP
#
# difficult I-ADJP
#
# that B-SBAR
#
# it B-NP
#
# resembles is tagged as UNK and the this arg_max_y e(resembles|y) is B-UCP
# resembles B-UCP
#
# `` O
#
# juggling is tagged as UNK and the this arg_max_y e(juggling|y) is B-UCP
# juggling B-UCP
#
# a B-LST
#
# double-bladed is tagged as UNK and the this arg_max_y e(double-bladed|y) is B-UCP
# double-bladed B-UCP
#
# ax is tagged as UNK and the this arg_max_y e(ax|y) is B-UCP
# ax B-UCP
#
# and I-UCP
#
# a B-LST
#
# buzz is tagged as UNK and the this arg_max_y e(buzz|y) is B-UCP
# buzz B-UCP
#
# saw B-VP
#
# . O
#
# '' O
#
# new sentence
# Skoal is tagged as UNK and the this arg_max_y e(Skoal|y) is B-UCP
# Skoal B-UCP
#
# Daze is tagged as UNK and the this arg_max_y e(Daze|y) is B-UCP
# Daze B-UCP
#
# new sentence
# Soviet I-NP
#
# leader I-NP
#
# Mikhail B-NP
#
# Gorbachev I-NP
#
# opened B-VP
#
# a B-LST
#
# major I-NP
#
# U.S. I-NP
#
# trade I-NP
#
# exhibition is tagged as UNK and the this arg_max_y e(exhibition|y) is B-UCP
# exhibition B-UCP
#
# in B-PP
#
# Moscow B-NP
#
# and I-UCP
#
# spent B-VP
#
# two B-NP
#
# hours I-NP
#
# touring is tagged as UNK and the this arg_max_y e(touring|y) is B-UCP
# touring B-UCP
#
# some B-NP
#
# of I-PP
#
# the B-NP
#
# 150 I-NP
#
# stalls B-VP
#
# representing B-VP
#
# such B-PP
#
# blue-chip B-NP
#
# companies I-NP
#
# as B-CONJP
#
# General B-NP
#
# Motors I-NP
#
# Corp. I-NP
#
# , O
#
# International I-NP
#
# Business I-NP
#
# Machines I-NP
#
# Corp. I-NP
#
# and I-UCP
#
# Johnson I-NP
#
# & I-NP
#
# Johnson I-NP
#
# . O
#
# new sentence
# C.R. is tagged as UNK and the this arg_max_y e(C.R.|y) is B-UCP
# C.R. B-UCP
#
# Bard I-NP
#
# Inc. I-NP
#
# yesterday B-NP
#
# said B-VP
#
# third-quarter B-NP
#
# net B-NP
#
# plunged B-VP
#
# 51 B-NP
#
# % I-ADJP
#
# to B-PP
#
# $ B-NP
#
# 9.9 B-NP
#
# million I-NP
#
# , O
#
# or I-PP
#
# 18 B-NP
#
# cents I-NP
#
# a B-LST
#
# share I-NP
#
# , O
#
# from B-PP
#
# $ B-NP
#
# 20 I-NP
#
# million I-NP
#
# , O
#
# or I-PP
#
# 35 B-NP
#
# cents I-NP
#
# a B-LST
#
# share I-NP
#
# , O
#
# a B-LST
#
# year I-NP
#
# earlier B-ADVP
#
# . O
#
# new sentence
# Several B-NP
#
# factors I-NP
#
# apparently B-ADVP
#
# spared is tagged as UNK and the this arg_max_y e(spared|y) is B-UCP
# spared B-UCP
#
# the B-NP
#
# Valley I-NP
#
# -- O
#
# a B-LST
#
# sprawling is tagged as UNK and the this arg_max_y e(sprawling|y) is B-UCP
# sprawling B-UCP
#
# suburban O
#
# stretch I-NP
#
# from B-PP
#
# San B-NP
#
# Jose I-NP
#
# to B-PP
#
# Palo B-NP
#
# Alto I-NP
#
# -- O
#
# from B-PP
#
# the B-NP
#
# kind B-ADJP
#
# of I-PP
#
# impact I-NP
#
# felt B-VP
#
# in B-PP
#
# San B-NP
#
# Francisco I-NP
#
# , O
#
# an B-NP
#
# hour I-NP
#
# 's B-NP
#
# drive I-VP
#
# north I-NP
#
# . O
#
# new sentence
# City I-NP
#
# dwellers is tagged as UNK and the this arg_max_y e(dwellers|y) is B-UCP
# dwellers B-UCP
#
# love I-VP
#
# them B-NP
#
# because B-SBAR
#
# they B-NP
#
# shift I-VP
#
# smoothly B-ADVP
#
# in B-PP
#
# traffic B-NP
#
# , O
#
# bounce is tagged as UNK and the this arg_max_y e(bounce|y) is B-UCP
# bounce B-UCP
#
# easily I-ADVP
#
# over B-PRT
#
# curbs I-NP
#
# and I-UCP
#
# roll I-VP
#
# through B-PRT
#
# road I-NP
#
# glass B-NP
#
# with B-PP
#
# far I-ADVP
#
# fewer I-ADJP
#
# flat I-ADJP
#
# tires I-NP
#
# than I-CONJP
#
# racing I-NP
#
# bikes I-NP
#
# . O
#
# new sentence
# It B-NP
#
# arrived I-VP
#
# just I-CONJP
#
# as B-CONJP
#
# the B-NP
#
# regulator I-NP
#
# handling I-VP
#
# such B-PP
#
# operations I-NP
#
# was B-VP
#
# retiring I-VP
#
# . O
#
# new sentence
# And O
#
# Resolution B-NP
#
# Funding I-NP
#
# Corp. I-NP
#
# said B-VP
#
# late I-ADVP
#
# yesterday B-NP
#
# that B-SBAR
#
# it B-NP
#
# will B-VP
#
# sell I-VP
#
# $ B-NP
#
# 4.5 B-NP
#
# billion I-NP
#
# of I-PP
#
# 30-year B-NP
#
# bonds I-NP
#
# Wednesday B-NP
#
# . O
#
# new sentence
# Robert B-NP
#
# H. I-NP
#
# Carlson is tagged as UNK and the this arg_max_y e(Carlson|y) is B-UCP
# Carlson B-UCP
#
# , O
#
# previous I-NP
#
# president I-NP
#
# and I-UCP
#
# chief B-NP
#
# executive I-NP
#
# of I-PP
#
# Universal-Rundle is tagged as UNK and the this arg_max_y e(Universal-Rundle|y) is B-UCP
# Universal-Rundle B-UCP
#
# , O
#
# will B-VP
#
# assume B-VP
#
# the B-NP
#
# title I-NP
#
# of I-PP
#
# chairman B-NP
#
# of I-PP
#
# the B-NP
#
# unit I-NP
#
# , O
#
# a B-LST
#
# vitreous-china is tagged as UNK and the this arg_max_y e(vitreous-china|y) is B-UCP
# vitreous-china B-UCP
#
# maker I-NP
#
# . O
#
# new sentence
# An B-NP
#
# additional I-NP
#
# 299,000 is tagged as UNK and the this arg_max_y e(299,000|y) is B-UCP
# 299,000 B-UCP
#
# shares I-NP
#
# are B-VP
#
# authorized is tagged as UNK and the this arg_max_y e(authorized|y) is B-UCP
# authorized B-UCP
#
# for B-PP
#
# repurchase I-NP
#
# under B-PP
#
# an B-NP
#
# earlier B-ADVP
#
# stock I-NP
#
# buy-back I-NP
#
# program I-NP
#
# . O
#
# new sentence
# Georgia B-NP
#
# Gulf B-NP
#
# Corp. I-NP
#
# , O
#
# hurt I-VP
#
# by B-PP
#
# declining B-NP
#
# sales I-NP
#
# and I-UCP
#
# falling B-NP
#
# chemical I-NP
#
# prices I-NP
#
# , O
#
# said B-VP
#
# third-quarter B-NP
#
# earnings I-NP
#
# fell B-VP
#
# 13 B-NP
#
# % I-ADJP
#
# to B-PP
#
# $ B-NP
#
# 46.1 is tagged as UNK and the this arg_max_y e(46.1|y) is B-UCP
# 46.1 B-UCP
#
# million I-NP
#
# from B-PP
#
# $ B-NP
#
# 53.1 is tagged as UNK and the this arg_max_y e(53.1|y) is B-UCP
# 53.1 B-UCP
#
# million I-NP
#
# in B-PP
#
# the B-NP
#
# year-earlier I-NP
#
# period I-NP
#
# . O
#
# new sentence
# Congress B-NP
#
# sent B-VP
#
# President B-NP
#
# Bush I-NP
#
# an B-NP
#
# $ B-NP
#
# 18.4 is tagged as UNK and the this arg_max_y e(18.4|y) is B-UCP
# 18.4 B-UCP
#
# billion I-NP
#
# fiscal B-NP
#
# 1990 B-NP
#
# Treasury I-NP
#
# and I-UCP
#
# Postal is tagged as UNK and the this arg_max_y e(Postal|y) is B-UCP
# Postal B-UCP
#
# Service I-NP
#
# bill I-NP
#
# providing I-VP
#
# $ B-NP
#
# 5.5 B-NP
#
# billion I-NP
#
# for B-PP
#
# the B-NP
#
# Internal I-NP
#
# Revenue B-NP
#
# Service I-NP
#
# and I-UCP
#
# increasing B-VP
#
# the B-NP
#
# Customs is tagged as UNK and the this arg_max_y e(Customs|y) is B-UCP
# Customs B-UCP
#
# Service I-NP
#
# 's B-NP
#
# air-interdiction is tagged as UNK and the this arg_max_y e(air-interdiction|y) is B-UCP
# air-interdiction B-UCP
#
# program I-NP
#
# nearly B-ADJP
#
# a B-LST
#
# third I-NP
#
# . O
#
# new sentence
# The B-NP
#
# House I-NP
#
# Public I-NP
#
# Works I-NP
#
# and I-UCP
#
# Transportation I-NP
#
# Committee I-NP
#
# approved I-VP
#
# a B-LST
#
# bill I-NP
#
# that B-SBAR
#
# would B-VP
#
# give I-VP
#
# the B-NP
#
# Transportation I-NP
#
# Department I-NP
#
# power I-NP
#
# to B-PP
#
# block I-VP
#
# airline I-NP
#
# leveraged I-ADJP
#
# buy-outs B-NP
#
# , O
#
# despite B-PP
#
# a B-LST
#
# clear B-ADJP
#
# veto I-VP
#
# threat I-NP
#
# from B-PP
#
# the B-NP
#
# Bush I-NP
#
# administration I-NP
#
# . O
#
# new sentence
# Polls B-NP
#
# are B-VP
#
# no I-INTJ
#
# substitute is tagged as UNK and the this arg_max_y e(substitute|y) is B-UCP
# substitute B-UCP
#
# for B-PP
#
# principle B-NP
#
# , O
#
# but B-CONJP
#
# they B-NP
#
# 'll B-VP
#
# do B-VP
#
# for B-PP
#
# some B-NP
#
# politicians B-NP
#
# . O
#
# new sentence
# ...
# 9,000 B-UCP
#
# vessels I-NP
#
# fill I-VP
#
# what B-NP
#
# the B-NP
#
# chamber I-NP
#
# of I-PP
#
# commerce B-NP
#
# calls B-VP
#
# the B-NP
#
# nation I-NP
#
# 's B-NP
#
# largest I-NP
#
# pleasure-boat is tagged as UNK and the this arg_max_y e(pleasure-boat|y) is B-UCP
# pleasure-boat B-UCP
#
# harbor I-NP
#
# . O
#
# new sentence
# Like B-PP
#
# just I-CONJP
#
# about B-PP
#
# everything B-NP
#
# else B-ADJP
#
# , O
#
# that B-SBAR
#
# remains B-VP
#
# to B-PP
#
# be I-VP
#
# seen I-VP
#
# . O
#
# new sentence
# But O
#
# the B-NP
#
# statistics I-NP
#
# released B-VP
#
# yesterday B-NP
#
# show I-VP
#
# the B-NP
#
# firms I-NP
#
# did B-VP
#
# nothing B-NP
#
# of I-PP
#
# the B-NP
#
# sort I-VP
#
# . O
#
# new sentence
# `` O
#
# We B-NP
#
# feel I-VP
#
# we B-NP
#
# have I-VP
#
# the B-NP
#
# money I-NP
#
# necessary B-ADJP
#
# to B-PP
#
# handle I-VP
#
# the B-NP
#
# immediate I-NP
#
# , O
#
# short-term I-NP
#
# requirements I-NP
#
# , O
#
# '' O
#
# Mr. B-NP
#
# Fitzwater I-NP
#
# said B-VP
#
# . O
#
# new sentence
# U.S. I-NP
#
# takeover-stock I-NP
#
# speculators I-NP
#
# , O
#
# who B-NP
#
# may B-VP
#
# own I-NP
#
# between B-PP
#
# 20 I-NP
#
# % I-ADJP
#
# and I-UCP
#
# 30 I-NP
#
# % I-ADJP
#
# of I-PP
#
# Jaguar B-NP
#
# , O
#
# could B-VP
#
# give I-VP
#
# Ford B-NP
#
# enough I-ADJP
#
# votes I-NP
#
# to B-PP
#
# block I-VP
#
# the B-NP
#
# GM B-NP
#
# deal I-NP
#
# . O
#
# new sentence
# British B-NP
#
# government I-NP
#
# bonds I-NP
#
# , O
#
# or I-PP
#
# gilts is tagged as UNK and the this arg_max_y e(gilts|y) is B-UCP
# gilts B-UCP
#
# , O
#
# ended B-VP
#
# moderately B-ADVP
#
# lower I-ADJP
#
# as B-CONJP
#
# equities B-NP
#
# there B-ADVP
#
# recovered B-VP
#
# from B-PP
#
# Tuesday B-NP
#
# 's B-NP
#
# drop I-NP
#
# . O
#
# new sentence
# In B-PP
#
# New B-NP
#
# York I-NP
#
# Stock I-NP
#
# Exchange I-NP
#
# composite I-NP
#
# trading I-NP
#
# , O
#
# Baxter B-NP
#
# closed B-VP
#
# at B-PP
#
# $ B-NP
#
# 22.25 is tagged as UNK and the this arg_max_y e(22.25|y) is B-UCP
# 22.25 B-UCP
#
# a B-LST
#
# share I-NP
#
# , O
#
# down B-PRT
#
# 12.5 B-NP
#
# cents I-NP
#
# . O
#
# new sentence
# `` O
#
# There B-NP
#
# will B-VP
#
# be I-VP
#
# a B-LST
#
# big I-ADJP
#
# influx I-NP
#
# of I-PP
#
# federal I-NP
#
# dollars I-NP
#
# and I-UCP
#
# gains I-NP
#
# in B-PP
#
# state I-NP
#
# , O
#
# federal I-NP
#
# and I-UCP
#
# local B-ADJP
#
# employment I-NP
#
# , O
#
# '' O
#
# Ms. B-NP
#
# Mace I-NP
#
# says B-VP
#
# . O
#
# new sentence
# He B-NP
#
# allegedly B-ADVP
#
# entered I-VP
#
# into B-PP
#
# Panama B-NP
#
# 's B-NP
#
# first B-ADVP
#
# formal I-NP
#
# business I-NP
#
# arrangement I-NP
#
# with B-PP
#
# Colombian I-NP
#
# drug I-NP
#
# bosses is tagged as UNK and the this arg_max_y e(bosses|y) is B-UCP
# bosses B-UCP
#
# , O
#
# according B-PP
#
# to B-PP
#
# Floyd is tagged as UNK and the this arg_max_y e(Floyd|y) is B-UCP
# Floyd B-UCP
#
# Carlton is tagged as UNK and the this arg_max_y e(Carlton|y) is B-UCP
# Carlton B-UCP
#
# , O
#
# a B-LST
#
# pilot I-NP
#
# who B-NP
#
# once I-ADVP
#
# worked B-VP
#
# for B-PP
#
# Mr. B-NP
#
# Noriega I-NP
#
# and I-UCP
#
# who B-NP
#
# testified B-VP
#
# before I-SBAR
#
# the B-NP
#
# U.S. I-NP
#
# grand I-NP
#
# jury I-NP
#
# in B-PP
#
# Miami B-NP
#
# that B-SBAR
#
# would B-VP
#
# ultimately B-ADVP
#
# indict B-VP
#
# the B-NP
#
# Panamanian I-NP
#
# on B-PP
#
# drug I-NP
#
# charges I-NP
#
# . O
#
# new sentence
# Advancers is tagged as UNK and the this arg_max_y e(Advancers|y) is B-UCP
# Advancers B-UCP
#
# on B-PP
#
# the B-NP
#
# Big I-NP
#
# Board I-NP
#
# outpaced B-VP
#
# decliners B-NP
#
# by B-PP
#
# 822 I-NP
#
# to B-PP
#
# 668 B-NP
#
# . O
#
# new sentence
# `` O
#
# But O
#
# they B-NP
#
# may B-VP
#
# pay I-VP
#
# a B-LST
#
# price I-NP
#
# 10 I-ADVP
#
# or I-PP
#
# 20 I-NP
#
# years I-NP
#
# in B-PP
#
# the B-NP
#
# future I-NP
#
# . O
#
# '' O
#
# new sentence
# At B-PP
#
# current I-ADJP
#
# allocations is tagged as UNK and the this arg_max_y e(allocations|y) is B-UCP
# allocations B-UCP
#
# , O
#
# that B-SBAR
#
# means B-VP
#
# EPA is tagged as UNK and the this arg_max_y e(EPA|y) is B-UCP
# EPA B-UCP
#
# will B-VP
#
# be I-VP
#
# spending I-VP
#
# $ B-NP
#
# 300 I-NP
#
# billion I-NP
#
# on B-PP
#
# itself B-NP
#
# . O
#
# new sentence
# `` O
#
# It B-NP
#
# was B-VP
#
# a B-LST
#
# timing B-VP
#
# mistake I-NP
#
# . O
#
# '' O
#
# new sentence
# I B-NP
#
# was B-VP
#
# in B-PP
#
# the B-NP
#
# avenues is tagged as UNK and the this arg_max_y e(avenues|y) is B-UCP
# avenues B-UCP
#
# , O
#
# on B-PP
#
# the B-NP
#
# third I-NP
#
# floor I-NP
#
# of I-PP
#
# an B-NP
#
# old B-ADJP
#
# building I-NP
#
# , O
#
# and I-UCP
#
# except B-PP
#
# for B-PP
#
# my B-NP
#
# heart I-NP
#
# -LRB- O
#
# Beat is tagged as UNK and the this arg_max_y e(Beat|y) is B-UCP
# Beat B-UCP
#
# , O
#
# BEAT is tagged as UNK and the this arg_max_y e(BEAT|y) is B-UCP
# BEAT B-UCP
#
# ! O
#
# -RRB- O
#
# I B-NP
#
# 'm B-VP
#
# OK is tagged as UNK and the this arg_max_y e(OK|y) is B-UCP
# OK B-UCP
#
# . O
#
# new sentence
# London B-NP
#
# shares I-NP
#
# rallied B-VP
#
# to B-PP
#
# post I-VP
#
# strong I-ADJP
#
# gains I-NP
#
# after B-SBAR
#
# initial I-NP
#
# fears B-NP
#
# evaporated is tagged as UNK and the this arg_max_y e(evaporated|y) is B-UCP
# evaporated B-UCP
#
# that B-SBAR
#
# the B-NP
#
# California B-NP
#
# earthquake I-NP
#
# would B-VP
#
# depress I-VP
#
# Wall B-NP
#
# Street I-NP
#
# prices I-NP
#
# . O
#
# new sentence
# Hallwood B-NP
#
# is I-INTJ
#
# a B-LST
#
# merchant B-NP
#
# bank I-NP
#
# whose B-NP
#
# activities I-NP
#
# include I-VP
#
# the B-NP
#
# ownership I-NP
#
# , O
#
# management I-NP
#
# and I-UCP
#
# financial I-ADJP
#
# restructuring I-NP
#
# of I-PP
#
# shopping I-NP
#
# centers I-NP
#
# , O
#
# office I-NP
#
# buildings I-NP
#
# , O
#
# apartments I-NP
#
# and I-UCP
#
# other B-NP
#
# real B-ADJP
#
# estate I-NP
#
# . O
#
# new sentence
# Both B-NP
#
# Shearson B-NP
#
# 's B-NP
#
# Mr B-NP
#
# . O
#
# Will O
#
# and I-UCP
#
# Stephen B-NP
#
# Reitman I-NP
#
# , O
#
# European I-NP
# auto I-NP
#
# analyst I-NP
#
# at B-PP
#
# the B-NP
#
# London B-NP
#
# brokerage I-NP
#
# firm I-NP
#
# UBS-Phillips is tagged as UNK and the this arg_max_y e(UBS-Phillips|y) is B-UCP
# UBS-Phillips B-UCP
#
# & I-NP
#
# Drew I-NP
#
# , O
#
# recently I-ADVP
#
# switched B-VP
#
# their B-NP
#
# Jaguar B-NP
#
# recommendations B-NP
#
# to B-PP
#
# hold I-VP
#
# from B-PP
#
# buy I-VP
#
# . O
#
# new sentence
# Separately B-ADVP
#
# , O
#
# a B-LST
#
# third I-NP
#
# conference I-NP
#
# report I-VP
#
# covering B-VP
#
# an B-NP
#
# $ B-NP
#
# 18.4 is tagged as UNK and the this arg_max_y e(18.4|y) is B-UCP
# 18.4 B-UCP
#
# billion I-NP
#
# Treasury I-NP
#
# and I-UCP
#
# Postal is tagged as UNK and the this arg_max_y e(Postal|y) is B-UCP
# Postal B-UCP
#
# Service I-NP
#
# bill I-NP
#
# was B-VP
#
# sent B-VP
#
# to B-PP
#
# the B-NP
#
# Senate I-NP
#
# after B-SBAR
#
# passing B-VP
#
# the B-NP
#
# House I-NP
#
# on B-PP
#
# a B-LST
#
# 383-30 is tagged as UNK and the this arg_max_y e(383-30|y) is B-UCP
# 383-30 B-UCP
#
# roll I-VP
#
# call I-VP
#
# yesterday B-NP
#
# . O
#
# new sentence
# `` O
#
# From B-PP
#
# a B-LST
#
# public B-ADJP
#
# health I-NP
#
# point I-ADVP
#
# of I-PP
#
# view I-NP
#
# we B-NP
#
# 're B-VP
#
# relieved B-ADJP
#
# because B-SBAR
#
# hepatitis B-NP
#
# A B-NP
#
# is I-INTJ
#
# rarely B-ADJP
#
# life-threatening is tagged as UNK and the this arg_max_y e(life-threatening|y) is B-UCP
# life-threatening B-UCP
#
# , O
#
# '' O
#
# said B-VP
#
# Dr. B-NP
#
# Frank B-NP
#
# Provato is tagged as UNK and the this arg_max_y e(Provato|y) is B-UCP
# Provato B-UCP
#
# , O
#
# GTE B-NP
#
# 's B-NP
#
# medical B-NP
#
# director I-NP
#
# . O
#
# new sentence
# GOP I-NP
#
# pollster is tagged as UNK and the this arg_max_y e(pollster|y) is B-UCP
# pollster B-UCP
#
# Neil I-NP
#
# Newhouse is tagged as UNK and the this arg_max_y e(Newhouse|y) is B-UCP
# Newhouse B-UCP
#
# , O
#
# of I-PP
#
# the B-NP
#
# Wirthlin is tagged as UNK and the this arg_max_y e(Wirthlin|y) is B-UCP
# Wirthlin B-UCP
#
# Group I-NP
#
# , O
#
# says B-VP
#
# polls B-NP
#
# this B-NP
#
# summer I-NP
#
# showed B-VP
#
# that B-SBAR
#
# the B-NP
#
# single-issue is tagged as UNK and the this arg_max_y e(single-issue|y) is B-UCP
# single-issue B-UCP
#
# voters I-NP
#
# had B-VP
#
# about B-PP
#
# evened is tagged as UNK and the this arg_max_y e(evened|y) is B-UCP
# evened B-UCP
#
# out B-PRT
#
# . O
#
# new sentence
# But O
#
# he B-NP
#
# has B-VP
#
# opposed B-VP
#
# Medicaid B-NP
#
# funding I-NP
#
# of I-PP
#
# abortions B-NP
#
# for B-PP
#
# poor B-ADJP
#
# women I-NP
#
# who B-NP
#
# say B-INTJ
#
# they B-NP
#
# are B-VP
#
# victims I-NP
#
# of I-PP
#
# rape B-NP
#
# and I-UCP
#
# incest I-NP
#
# , O
#
# arguing B-VP
#
# that B-SBAR
#
# those B-NP
#
# exceptions I-NP
#
# are B-VP
#
# enforced is tagged as UNK and the this arg_max_y e(enforced|y) is B-UCP
# enforced B-UCP
#
# so B-ADJP
#
# loosely is tagged as UNK and the this arg_max_y e(loosely|y) is B-UCP
# loosely B-UCP
#
# that B-SBAR
#
# they B-NP
#
# open B-ADJP
#
# the B-NP
#
# way I-NP
#
# for B-PP
#
# abortions B-NP
#
# for B-PP
#
# other B-NP
#
# women I-NP
#
# . O
#
# new sentence
# Among B-PP
#
# the B-NP
#
# biggest B-ADJP
#
# winners I-NP
#
# were B-VP
#
# brokerage-house is tagged as UNK and the this arg_max_y e(brokerage-house|y) is B-UCP
# brokerage-house B-UCP
#
# stocks I-NP
#
# , O
#
# responding is tagged as UNK and the this arg_max_y e(responding|y) is B-UCP
# responding B-UCP
#
# to B-PP
#
# heavy B-NP
#
# trading I-NP
#
# volume I-NP
#
# . O
#
# new sentence
# Forget is tagged as UNK and the this arg_max_y e(Forget|y) is B-UCP
# Forget B-UCP
#
# about B-PP
#
# Treasury I-NP
#
# bills I-NP
#
# or I-PP
#
# a B-LST
#
# money-market B-NP
#
# fund I-NP
#
# . O
#
# new sentence
# Although B-SBAR
#
# a B-LST
#
# GOP I-NP
#
# president I-NP
#
# may B-VP
#
# limit I-VP
#
# local B-ADJP
#
# benefits I-NP
#
# to B-PP
#
# the B-NP
#
# voter I-NP
#
# 's B-NP
#
# particular B-ADJP
#
# district\/state is tagged as UNK and the this arg_max_y e(district\/state|y) is B-UCP
# district\/state B-UCP
#
# , O
#
# such B-PP
#
# a B-LST
#
# president I-NP
#
# is I-INTJ
#
# also I-CONJP
#
# likely B-ADJP
#
# to B-PP
#
# be I-VP
#
# more B-ADJP
#
# effective I-ADJP
#
# at B-PP
#
# preventing B-VP
#
# other B-NP
#
# districts\/states is tagged as UNK and the this arg_max_y e(districts\/states|y) is B-UCP
# districts\/states B-UCP
#
# and I-UCP
#
# their B-NP
#
# legislators I-NP
#
# from B-PP
#
# bringing B-VP
#
# home B-ADVP
#
# the B-NP
#
# local B-ADJP
#
# benefits I-NP
#
# . O
#
# new sentence
# He B-NP
#
# hurt I-VP
#
# himself B-NP
#
# further I-ADVP
#
# this B-NP
#
# summer I-NP
#
# by B-PP
#
# bringing B-VP
#
# homosexual B-NP
#
# issues I-NP
#
# into B-PP
#
# the B-NP
#
# debate I-NP
#
# ; O
#
# and I-UCP
#
# by B-PP
#
# wavering is tagged as UNK and the this arg_max_y e(wavering|y) is B-UCP
# wavering B-UCP
#
# on B-PP
#
# this B-NP
#
# issue I-NP
#
# and I-UCP
#
# abortion B-NP
#
# , O
#
# he B-NP
#
# has B-VP
#
# weakened B-VP
#
# his B-NP
#
# credibility I-NP
#
# in B-PP
#
# what B-NP
#
# is I-INTJ
#
# already B-ADVP
#
# a B-LST
#
# mean-spirited is tagged as UNK and the this arg_max_y e(mean-spirited|y) is B-UCP
# mean-spirited B-UCP
#
# campaign I-NP
#
# on B-PP
#
# both B-NP
#
# sides I-NP
#
# . O
#
# new sentence
# This B-NP
#
# week I-NP
#
# , O
#
# many B-NP
#
# carriers I-NP
#
# are B-VP
#
# announcing B-VP
#
# cut-rate is tagged as UNK and the this arg_max_y e(cut-rate|y) is B-UCP
# cut-rate B-UCP
#
# fares I-NP
#
# designed I-VP
#
# to B-PP
#
# get I-VP
#
# people B-NP
#
# to B-PP
#
# fly I-VP
#
# on B-PP
#
# some B-NP
#
# of I-PP
#
# the B-NP
#
# most B-ADJP
#
# hallowed is tagged as UNK and the this arg_max_y e(hallowed|y) is B-UCP
# hallowed B-UCP
#
# -- O
#
# and I-UCP
#
# slowest is tagged as UNK and the this arg_max_y e(slowest|y) is B-UCP
# slowest B-UCP
#
# -- O
#
# days I-NP
#
# of I-PP
#
# the B-NP
#
# year I-NP
#
# , O
#
# including B-PP
#
# Christmas B-NP
#
# . O
#
# new sentence
# `` O
#
# There B-NP
#
# is I-INTJ
#
# talk I-VP
#
# of I-PP
#
# some B-NP
#
# revamping is tagged as UNK and the this arg_max_y e(revamping|y) is B-UCP
# revamping B-UCP
#
# and I-UCP
#
# we B-NP
#
# 're B-VP
#
# certainly I-ADVP
#
# heading I-VP
#
# in B-PP
#
# the B-NP
#
# direction I-NP
#
# of I-PP
#
# less B-ADJP
#
# and I-UCP
#
# less B-ADJP
#
# animation B-NP
#
# , O
#
# '' O
#
# said B-VP
#
# Joseph B-NP
#
# S. I-NP
#
# Cicero I-NP
#
# , O
#
# vice I-ADVP
#
# president I-NP
#
# of I-PP
#
# finance I-VP
#
# and I-UCP
#
# administration I-NP
#
# for B-PP
#
# National I-NP
#
# Broadcasting I-NP
#
# Co. I-NP
#
# , O
#
# a B-LST
#
# unit I-NP
#
# of I-PP
#
# General B-NP
#
# Electric I-NP
#
# Co I-NP
#
# . O
#
# new sentence
# In B-PP
#
# July B-NP
#
# a B-LST
#
# year I-NP
#
# later B-ADVP
#
# , O
#
# Warner B-NP
#
# agreed B-VP
#
# to B-PP
#
# release I-NP
#
# the B-NP
#
# producers I-NP
#
# from B-PP
#
# their B-NP
#
# old B-ADJP
#
# contract I-NP
#
# when B-ADVP
#
# Messrs. B-NP
#
# Guber I-NP
#
# , O
#
# Peters I-NP
#
# and I-UCP
#
# Sugarman I-NP
#
# made I-VP
#
# a B-LST
#
# $ B-NP
#
# 100 I-NP
#
# million I-NP
#
# offer I-VP
#
# to B-PP
#
# buy I-VP
#
# 25 B-NP
#
# % I-ADJP
#
# of I-PP
#
# MGM\/UA B-NP
#
# . O
#
# new sentence
# The B-NP
#
# $ B-NP
#
# 125-billion-a-year is tagged as UNK and the this arg_max_y e(125-billion-a-year|y) is B-UCP
# 125-billion-a-year B-UCP
#
# Bay I-NP
#
# area I-NP
#
# economy I-NP
#
# represents B-VP
#
# one-fourth I-NP
#
# of I-PP
#
# the B-NP
#
# economy I-NP
#
# of I-PP
#
# the B-NP
#
# nation I-NP
#
# 's B-NP
#
# most B-ADJP
#
# populous is tagged as UNK and the this arg_max_y e(populous|y) is B-UCP
# populous B-UCP
#
# state I-NP
#
# and I-UCP
#
# accounts I-NP
#
# for B-PP
#
# 2 B-LST
#
# % I-ADJP
#
# to B-PP
#
# 3 B-LST
#
# % I-ADJP
#
# of I-PP
#
# the B-NP
#
# nation I-NP
#
# 's B-NP
#
# total I-NP
#
# output I-NP
#
# of I-PP
#
# goods I-NP
#
# and I-UCP
#
# services I-NP
#
# , O
#
# according B-PP
#
# to B-PP
#
# the B-NP
#
# Center I-NP
#
# for B-PP
#
# Continuing is tagged as UNK and the this arg_max_y e(Continuing|y) is B-UCP
# Continuing B-UCP
#
# Study is tagged as UNK and the this arg_max_y e(Study|y) is B-UCP
# Study B-UCP
#
# of I-PP
#
# the B-NP
#
# California B-NP
#
# Economy is tagged as UNK and the this arg_max_y e(Economy|y) is B-UCP
# Economy B-UCP
#
# in B-PP
#
# Palo B-NP
#
# Alto I-NP
#
# . O
#
# new sentence
# Confidence is tagged as UNK and the this arg_max_y e(Confidence|y) is B-UCP
# Confidence B-UCP
#
# in B-PP
#
# the B-NP
#
# pound I-NP
#
# is I-INTJ
#
# widely I-ADVP
#
# expected I-VP
#
# to B-PP
#
# take I-VP
#
# another B-NP
#
# sharp I-ADJP
#
# dive is tagged as UNK and the this arg_max_y e(dive|y) is B-UCP
# dive B-UCP
#
# if I-SBAR
#
# trade I-NP
#
# figures I-NP
#
# for B-PP
#
# September B-NP
#
# , O
#
# due B-ADJP
#
# for B-PP
#
# release I-NP
#
# tomorrow B-NP
#
# , O
#
# fail I-VP
#
# to B-PP
#
# show I-VP
#
# a B-LST
#
# substantial B-ADJP
#
# improvement I-NP
#
# from B-PP
#
# July B-NP
#
# and I-UCP
#
# August B-NP
#
# 's B-NP
#
# near-record B-NP
#
# deficits I-NP
#
# . O
#
# new sentence
# In B-PP
#
# one B-NP
#
# ingenious B-ADJP
#
# recent I-ADJP
#
# example B-NP
#
# of I-PP
#
# a B-LST
#
# Newport B-NP
#
# Beach I-NP
#
# boiler B-NP
#
# room I-NP
#
# , O
#
# prospective I-NP
#
# investors B-NP
#
# in B-PP
#
# Capital I-NP
#
# Trust I-NP
#
# Inc. I-NP
#
# were B-VP
#
# allegedly B-ADVP
#
# told I-VP
#
# that B-SBAR
#
# their B-NP
#
# investment I-NP
#
# in B-PP
#
# precious B-NP
#
# metals I-NP
#
# was B-VP
#
# insured B-ADJP
#
# against B-PP
#
# losses I-NP
#
# `` O
#
# caused B-VP
#
# by B-PP
#
# employees I-NP
#
# due B-ADJP
#
# to B-PP
#
# dishonesty B-NP
#
# , O
#
# destruction I-NP
#
# or I-PP
#
# disappearance I-NP
#
# , O
#
# '' O
#
# according B-PP
#
# to B-PP
#
# an B-NP
#
# indictment I-NP
#
# handed B-VP
#
# up B-PRT
#
# by B-PP
#
# a B-LST
#
# federal I-NP
#
# grand I-NP
#
# jury I-NP
#
# in B-PP
#
# Los B-NP
#
# Angeles I-NP
#
# last I-ADVP
#
# month I-NP
#
# . O
#
# new sentence
# That B-NP
#
# could B-VP
#
# widen is tagged as UNK and the this arg_max_y e(widen|y) is B-UCP
# widen B-UCP
#
# the B-NP
#
# yield I-VP
#
# spread I-VP
#
# between B-PP
#
# Treasurys B-NP
#
# and I-UCP
#
# asset-backed B-NP
#
# securities I-NP
#
# , O
#
# as B-CONJP
#
# well I-CONJP
#
# as B-CONJP
#
# make I-VP
#
# it B-NP
#
# tougher B-ADJP
#
# to B-PP
#
# unload I-VP
#
# the B-NP
#
# latter I-NP
#
# . O
#
# new sentence
# But O
#
# Pemex B-NP
#
# managers I-NP
#
# are B-VP
#
# the B-NP
#
# ones I-NP
#
# most B-ADJP
#
# thrilled is tagged as UNK and the this arg_max_y e(thrilled|y) is B-UCP
# thrilled B-UCP
#
# by B-PP
#
# the B-NP
#
# contract I-NP
#
# . O
#
# new sentence
# But O
#
# with B-PP
#
# industrial I-NP
#
# growth I-NP
#
# stagnant B-NP
#
# and I-UCP
#
# inflation B-NP
#
# showing B-VP
#
# signs B-NP
#
# of I-PP
#
# easing I-NP
#
# , O
#
# some B-NP
#
# voices I-NP
#
# may B-VP
#
# call I-VP
#
# for B-PP
#
# measures I-NP
#
# to B-PP
#
# pump I-VP
#
# new I-NP
#
# life I-NP
#
# into B-PP
#
# the B-NP
#
# economy I-NP
#
# . O
#
# new sentence
# Mr. B-NP
#
# Mason I-NP
#
# says B-VP
#
# he B-NP
#
# 's B-NP
#
# convinced I-ADJP
#
# the B-NP
#
# public B-ADJP
#
# still B-ADVP
#
# wants B-VP
#
# to B-PP
#
# invest I-VP
#
# in B-PP
#
# common I-ADJP
#
# stocks I-NP
#
# , O
#
# even B-ADVP
#
# though I-SBAR
#
# they B-NP
#
# believe B-VP
#
# the B-NP
#
# deck is tagged as UNK and the this arg_max_y e(deck|y) is B-UCP
# deck B-UCP
#
# is I-INTJ
#
# stacked is tagged as UNK and the this arg_max_y e(stacked|y) is B-UCP
# stacked B-UCP
#
# against B-PP
#
# them B-NP
#
# . O
#
# new sentence
# So B-ADVP
#
# far I-ADVP
#
# Galileo B-NP
#
# has B-VP
#
# been I-VP
#
# delayed I-VP
#
# twice I-ADJP
#
# , O
#
# once I-ADVP
#
# because B-SBAR
#
# of I-PP
#
# a B-LST
#
# computer I-NP
#
# malfunction is tagged as UNK and the this arg_max_y e(malfunction|y) is B-UCP
# malfunction B-UCP
#
# connected I-ADJP
#
# with B-PP
#
# a B-LST
#
# space-shuttle is tagged as UNK and the this arg_max_y e(space-shuttle|y) is B-UCP
# space-shuttle B-UCP
#
# engine I-NP
#
# , O
#
# and I-UCP
#
# yesterday B-NP
#
# because B-SBAR
#
# of I-PP
#
# the B-NP
#
# weather B-VP
#
# . O
#
# new sentence
# The B-NP
#
# economy I-NP
#
# 's B-NP
#
# slowdown I-NP
#
# is I-INTJ
#
# due B-ADJP
#
# only I-CONJP
#
# partly B-ADVP
#
# to B-PP
#
# the B-NP
#
# austerity I-NP
#
# program I-NP
#
# launched I-ADJP
#
# in B-PP
#
# September B-NP
#
# 1988 B-NP
#
# to B-PP
#
# cool I-VP
#
# an B-NP
#
# overheated is tagged as UNK and the this arg_max_y e(overheated|y) is B-UCP
# overheated B-UCP
#
# economy I-NP
#
# and I-UCP
#
# tame is tagged as UNK and the this arg_max_y e(tame|y) is B-UCP
# tame B-UCP
#
# inflation B-NP
#
# . O
#
# new sentence
# The B-NP
#
# GOP I-NP
#
# doubters is tagged as UNK and the this arg_max_y e(doubters|y) is B-UCP
# doubters B-UCP
#
# were B-VP
#
# in B-PP
#
# Congress B-NP
#
# . O
#
# new sentence

# %%
##running evalScript
! python EvalScript/evalResult.py EN/dev.out EN/dev.p2.out
# Out:
# #Entity in gold data: 13179
# #Entity in prediction: 18650
#
# #Correct Entity : 9542
# Entity  precision: 0.5116
# Entity  recall: 0.7240
# Entity  F: 0.5996
#
# #Correct Sentiment : 8456
# Sentiment  precision: 0.4534
# Sentiment  recall: 0.6416
# Sentiment  F: 0.5313

# %% [markdown]
# ## CN

# %%
emission_param_table_UNK_test_CN , unk_list_CN = gen_emission_param_table_UNK('CN/train', 'CN/dev.in')
emission_param_table_UNK_test_CN
# Out:
# updating emission_count_table and y_count_dic
# updating emission_param_table
# unl_list is:  ['0.03' '08' '10000' ... '龙川' '龙川县' '７']
# y_count_dic is:  {'O': 78714, 'B-neutral': 3238, 'I-neutral': 3507, 'B-positive': 1231, 'I-positive': 1382, 'B-negative': 276, 'I-negative': 135}
#                    【        原价        12         .         9         元  \
# O           0.004612  0.000038  0.000394  0.004205  0.000381  0.000394
# B-neutral   0.000000  0.000000  0.000309  0.000000  0.000309  0.000000
# I-neutral   0.000000  0.000000  0.000570  0.000285  0.000000  0.000000
# B-positive  0.000812  0.000000  0.000000  0.000000  0.000000  0.000000
# I-positive  0.000723  0.000000  0.000000  0.001447  0.000723  0.000723
# B-negative  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# I-negative  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                    ，         劵         后         7    ...     \
# O           0.061742  0.000038  0.000813  0.000381    ...
# B-neutral   0.000000  0.000000  0.000309  0.000000    ...
# I-neutral   0.004277  0.000000  0.000000  0.000855    ...
# B-positive  0.000000  0.000000  0.000000  0.000000    ...
# I-positive  0.000000  0.000000  0.000000  0.000000    ...
# B-negative  0.000000  0.000000  0.000000  0.000000    ...
# I-negative  0.000000  0.000000  0.000000  0.000000    ...
#
#             http://t.cn/RVbJ4yU      帐号密码       一九五      账号密码        高三  \
# O                      0.000013  0.000013  0.000000  0.000013  0.000013
# B-neutral              0.000000  0.000000  0.000000  0.000000  0.000000
# I-neutral              0.000000  0.000000  0.000285  0.000000  0.000000
# B-positive             0.000000  0.000000  0.000000  0.000000  0.000000
# I-positive             0.000000  0.000000  0.000000  0.000000  0.000000
# B-negative             0.000000  0.000000  0.000000  0.000000  0.000000
# I-negative             0.000000  0.000000  0.000000  0.000000  0.000000
#
#                   事是        唾沫        淹死       受害者       UNK
# O           0.000013  0.000013  0.000013  0.000000  0.000006
# B-neutral   0.000000  0.000000  0.000000  0.000000  0.000154
# I-neutral   0.000000  0.000000  0.000000  0.000000  0.000143
# B-positive  0.000000  0.000000  0.000000  0.000000  0.000406
# I-positive  0.000000  0.000000  0.000000  0.000000  0.000362
# B-negative  0.000000  0.000000  0.000000  0.003617  0.001808
# I-negative  0.000000  0.000000  0.000000  0.000000  0.003690
#
# [7 rows x 16936 columns]

# %%
gen_state('CN/dev.in','CN/dev.p2.out', emission_param_table_UNK_test_CN, unk_list_CN)
# Out:
# 十年 O
#
# 前 I-positive
#
# 马云 B-positive
#
# 告诉 O
#
# 你 B-negative
#
# ， O
#
# 网上 O
#
# 开店 is tagged as UNK and the this arg_max_y e(开店|y) is I-negative
# 开店 I-negative
#
# 不要 O
#
# 钱 O
#
# ， O
#
# 你 B-negative
#
# 说 O
#
# 是 O
#
# 骗子 O
#
# ， O
#
# 于是 O
#
# 你 B-negative
#
# 错过 O
#
# 了 O
#
# 淘宝 B-negative
#
# 时代 I-neutral
#
# ； O
#
# 几年 O
#
# 前 I-positive
#
# 马化腾 B-neutral
#
# 告诉 O
#
# 你 B-negative
#
# ， O
#
# 发短信 is tagged as UNK and the this arg_max_y e(发短信|y) is I-negative
# 发短信 I-negative
#
# 不要 O
#
# 钱 O
#
# ， O
#
# 你 B-negative
#
# 说 O
#
# 是 O
#
# 骗子 O
#
# ， O
#
# 于是 O
#
# 你 B-negative
#
# 错过 O
#
# 了 O
#
# 微信 B-negative
#
# 时代 I-neutral
#
# ； O
#
# 一年 O
#
# 前 I-positive
#
# 比邻 is tagged as UNK and the this arg_max_y e(比邻|y) is I-negative
# 比邻 I-negative
#
# 告诉 O
#
# 你 B-negative
#
# 打电话 O
#
# 不要 O
#
# 钱 O
#
# 你 B-negative
#
# 不 I-negative
#
# 相信 B-positive
#
# ， O
#
# 于是 O
#
# 你 B-negative
#
# 错过 O
#
# 了 O
#
# 比邻 is tagged as UNK and the this arg_max_y e(比邻|y) is I-negative
# 比邻 I-negative
#
# 时代 I-neutral
#
# ： O
#
# 几天 O
#
# 以前 I-neutral
#
# ， O
#
# 快 O
#
# 的 I-negative
#
# 打车 is tagged as UNK and the this arg_max_y e(打车|y) is I-negative
# 打车 I-negative
#
# 和 O
#
# 支付宝 is tagged as UNK and the this arg_max_y e(支付宝|y) is I-negative
# 支付宝 I-negative
#
# 告诉 O
#
# 你 B-negative
#
# ， O
#
# 打 I-positive
#
# 的 I-negative
#
# 坐车 O
#
# 减免 is tagged as UNK and the this arg_max_y e(减免|y) is I-negative
# 减免 I-negative
#
# 13 B-neutral
#
# 元 I-positive
#
# ， O
#
# 免费打 is tagged as UNK and the this arg_max_y e(免费打|y) is I-negative
# 免费打 I-negative
#
# 的 I-negative
#
# 不是 O
#
# 梦 B-negative
#
# ， O
#
# 你 B-negative
#
# 还 O
#
# 说 O
#
# 是 O
#
# 骗子 O
#
# 吗 I-neutral
#
# ？ O
#
# new sentence
# 。 O
#
# 相约 O
#
# 兰州 I-neutral
#
# 州 I-positive
#
# 10 I-negative
#
# 月 I-negative
#
# 18 O
#
# - I-neutral
#
# 10 I-negative
#
# 月 I-negative
#
# 20 O
#
# 日 O
#
# ， O
#
# 三 O
#
# 天天 O
#
# 泰国 B-positive
#
# 法力 I-neutral
#
# 刺符 I-neutral
#
# ， O
#
# 已经 O
#
# 转变成 O
#
# 一种 I-negative
#
# 佛教 B-neutral
#
# 神通 O
#
# 与 O
#
# 艺术 O
#
# 的 I-negative
#
# 结合 O
#
# 。 O
#
# 除了 O
#
# 可 O
#
# 保平安 O
#
# ， O
#
# 避难 O
#
# 消灾 O
#
# 之外 O
#
# ， O
#
# 更能 O
#
# 招财 B-positive
#
# 助 O
#
# 生意兴隆 O
#
# ， O
#
# 增强 O
#
# 人缘 O
#
# 及善缘 O
#
# 等 O
#
# 。 O
#
# 它 B-negative
#
# 不同于 O
#
# 一般 O
#
# 的 I-negative
#
# 艺术 O
#
# 纹身 I-positive
#
# ， O
#
# 师父 O
#
# 边刺 O
#
# 符边 O
#
# 念经 O
#
# 咒 O
#
# 加持 O
#
# ， O
#
# 完毕 O
#
# 后 O
#
# 撒 B-neutral
#
# 圣水 O
#
# 贴金 O
#
# 祈福 O
#
# 。 O
#
# 刺符 I-neutral
#
# 是 O
#
# 文化 I-positive
#
# ， O
#
# 虔诚 O
#
# 的 I-negative
#
# 信仰 B-positive
#
# 。 O
#
# new sentence
# # B-positive
#
# 青云 I-positive
#
# 志 I-positive
#
# # B-positive
#
# 一直 O
#
# 都 O
#
# 在 O
#
# 追 O
#
# 青云 I-positive
#
# 志 I-positive
#
# 啊 I-positive
#
# ！ O
#
# [ O
#
# 得意 O
#
# 地笑 O
#
# ] O
#
# 为什么 I-neutral
#
# 不 I-negative
#
# 每天 O
#
# 播 O
#
# 三集 is tagged as UNK and the this arg_max_y e(三集|y) is I-negative
# 三集 I-negative
#
# 啊 I-positive
#
# ！ O
#
# 看得 O
#
# 不 I-negative
#
# 过瘾 O
#
# 。 O
#
# new sentence
# 天才 B-neutral
#
# 是 O
#
# 百分之一 is tagged as UNK and the this arg_max_y e(百分之一|y) is I-negative
# 百分之一 I-negative
#
# 的 I-negative
#
# 灵感 O
#
# [ O
#
# 可 O
#
# . O
#
# 癵 O
#
# 灪 O
#
# | I-neutral
#
# 怜 O
#
# ] O
#
# 加 B-positive
#
# 百分之九十九 is tagged as UNK and the this arg_max_y e(百分之九十九|y) is I-negative
# 百分之九十九 I-negative
#
# 的 I-negative
#
# 汗水 O
#
# 。 O
#
# — O
#
# — O
#
# 爱迪生 is tagged as UNK and the this arg_max_y e(爱迪生|y) is I-negative
# 爱迪生 I-negative
#
# new sentence
# 【 O
#
# 紧扣 O
#
# 六大 O
#
# 任务 O
#
# 抓好 O
#
# 贯彻落实 O
#
# 】 O
#
# 中国 B-negative
#
# 兰州 I-neutral
#
# 网 I-neutral
#
# 10 I-negative
#
# 月 I-negative
#
# 11 O
#
# 日 O
#
# 消息 O
#
# 按照 O
#
# 全省 O
#
# 双联 O
#
# 行动 I-positive
#
# 开展 O
#
# “ O
#
# 大 I-positive
#
# 走访 O
#
# 回头 O
#
# 看 O
#
# ” O
#
# 活动 I-neutral
#
# 的 I-negative
#
# 安排 O
#
# 部署 O
#
# ， O
#
# 10 I-negative
#
# 月 I-negative
#
# 10 I-negative
#
# 日 O
#
# ， O
#
# 省委常委 O
#
# 、 O
#
# 市委书记 B-neutral
#
# 虞 B-neutral
#
# 海燕 I-neutral
#
# 赴 O
#
# 双联 O
#
# 点 O
#
# — O
#
# — O
#
# 永登县 B-neutral
#
# 通远乡 I-neutral
#
# 临平村 I-neutral
#
# 进行 O
#
# 走访 O
#
# 调研 O
#
# ， O
#
# 以 O
#
# 实际 O
#
# http O
#
# : O
#
# / O
#
# / O
#
# t O
#
# . O
#
# cn O
#
# / O
#
# RVbpRfJ O
#
# new sentence
# 发布 O
#
# 了 O
#
# 头条 B-neutral
#
# 文章 O
#
# ： O
#
# 《 B-positive
#
# 范冰冰 B-positive
#
# 照片 O
#
# 曝光 O
#
# ， O
#
# 竟有 is tagged as UNK and the this arg_max_y e(竟有|y) is I-negative
# 竟有 I-negative
#
# 这样 O
#
# 打扮 O
#
# ， O
#
# 网友 B-neutral
#
# 称醉 is tagged as UNK and the this arg_max_y e(称醉|y) is I-negative
# 称醉 I-negative
#
# 了 O
#
# ， O
#
# 最后 O
#
# 一张 B-positive
#
# 像 O
#
# 妖精 O
#
# 。 O
#
# 。 O
#
# 》 I-negative
#
# http://t.cn/RVt4zaA is tagged as UNK and the this arg_max_y e(http://t.cn/RVt4zaA|y) is I-negative
# http://t.cn/RVt4zaA I-negative
#
# new sentence
# 我 B-negative
#
# 很 O
#
# 失落 O
#
# ， O
#
# 充满活力 is tagged as UNK and the this arg_max_y e(充满活力|y) is I-negative
# 充满活力 I-negative
#
# 的 I-negative
#
# 带鱼 is tagged as UNK and the this arg_max_y e(带鱼|y) is I-negative
# 带鱼 I-negative
#
# 你 B-negative
#
# 快 O
#
# 回来 O
#
# ， O
#
# 晚安 O
#
# 好 B-negative
#
# 梦 B-negative
#
# new sentence
# 【 O
#
# 鸣沙山 B-neutral
#
# 】 O
#
# 鸣沙山 B-neutral
#
# 位于 O
#
# 敦煌市 O
#
# 以南 O
#
# 6 I-neutral
#
# 公里 I-neutral
#
# ， O
#
# 在 O
#
# 狂风怒吼 O
#
# 时 O
#
# ， O
#
# 沙山 O
#
# 会 O
#
# 发出 O
#
# 巨大 O
#
# 的 I-negative
#
# 响声 O
#
# ， O
#
# 轻风 O
#
# 吹拂 O
#
# 时 O
#
# ， O
#
# 声音 I-negative
#
# 又 O
#
# 似 O
#
# 管弦 O
#
# 丝竹 O
#
# ， O
#
# 故 O
#
# 名 O
#
# “ O
#
# 鸣沙山 B-neutral
#
# ” O
#
# 。 O
#
# 月牙泉 O
#
# 被 O
#
# 鸣沙山 B-neutral
#
# 环抱 O
#
# ， O
#
# 因 O
#
# 水面 O
#
# 酷似 O
#
# 一弯 O
#
# 新月 O
#
# 而 O
#
# 得名 O
#
# ， O
#
# 这是 O
#
# 鸣沙山 B-neutral
#
# 景区 I-neutral
#
# 最 O
#
# 著名 O
#
# 的 I-negative
#
# 地方 O
#
# ， O
#
# 充满 O
#
# 了 O
#
# 色彩 O
#
# 和 O
#
# 生机 O
#
# ， O
#
# 宛如 O
#
# 大漠 O
#
# 羌 O
#
# 笛声 O
#
# 中 O
#
# 的 I-negative
#
# 一段 O
#
# 江南 B-neutral
#
# 牧 O
#
# 笛声 O
#
# ， O
#
# 婉转 O
#
# 清扬 O
#
# ， O
#
# 欢快 O
#
# 灵动 O
#
# 。 O
#
# new sentence
# 他 B-negative
#
# 是 O
#
# 兰凌王 is tagged as UNK and the this arg_max_y e(兰凌王|y) is I-negative
# 兰凌王 I-negative
#
# ， O
#
# 一个 B-negative
#
# 美男子 is tagged as UNK and the this arg_max_y e(美男子|y) is I-negative
# 美男子 I-negative
#
# 。 O
#
# 她 B-negative
#
# 叫 O
#
# 郑儿 is tagged as UNK and the this arg_max_y e(郑儿|y) is I-negative
# 郑儿 I-negative
#
# ， O
#
# 皇后 I-positive
#
# 身边 O
#
# 的 I-negative
#
# 红人 is tagged as UNK and the this arg_max_y e(红人|y) is I-negative
# 红人 I-negative
#
# 。 O
#
# 她 B-negative
#
# 本 O
#
# 喜欢 O
#
# 他 B-negative
#
# ， O
#
# 总 O
#
# 希望 O
#
# 嫁给 O
#
# 他 B-negative
#
# ， O
#
# 可 O
#
# 老天 is tagged as UNK and the this arg_max_y e(老天|y) is I-negative
# 老天 I-negative
#
# 偏偏 O
#
# 开玩笑 is tagged as UNK and the this arg_max_y e(开玩笑|y) is I-negative
# 开玩笑 I-negative
#
# ， O
#
# 她 B-negative
#
# 做 O
#
# 了 O
#
# 太子妃 is tagged as UNK and the this arg_max_y e(太子妃|y) is I-negative
# 太子妃 I-negative
#
# 。 O
#
# 他 B-negative
#
# 要 O
#
# 被 O
#
# 砍头 is tagged as UNK and the this arg_max_y e(砍头|y) is I-negative
# 砍头 I-negative
#
# ， O
#
# 是 O
#
# 她 B-negative
#
# 救 O
#
# 了 O
#
# 他 B-negative
#
# ， O
#
# 她 B-negative
#
# 只 O
#
# 想要 O
#
# 一份 O
#
# 卑微 is tagged as UNK and the this arg_max_y e(卑微|y) is I-negative
# 卑微 I-negative
#
# 的 I-negative
#
# 爱情 I-neutral
#
# 。 O
#
# 可 O
#
# 他 B-negative
#
# ， O
#
# 却 O
#
# 钟情 is tagged as UNK and the this arg_max_y e(钟情|y) is I-negative
# 钟情 I-negative
#
# 一人 B-negative
#
# 。 O
#
# 她 B-negative
#
# ， O
#
# 虽恨 is tagged as UNK and the this arg_max_y e(虽恨|y) is I-negative
# 虽恨 I-negative
#
# ， O
#
# 死时 is tagged as UNK and the this arg_max_y e(死时|y) is I-negative
# 死时 I-negative
#
# ， O
#
# 却 O
#
# 还是 O
#
# 爱着 is tagged as UNK and the this arg_max_y e(爱着|y) is I-negative
# 爱着 I-negative
#
# 他 B-negative
#
# 。 O
#
# new sentence
# kpp is tagged as UNK and the this arg_max_y e(kpp|y) is I-negative
# kpp I-negative
#
# 蓝调 B-neutral
#
# 海客 B-neutral
#
# 谈 B-neutral
#
# 瀛洲 B-neutral
#
# ， O
#
# 烟涛 O
#
# 微茫 O
#
# [ O
#
# 嘻嘻 O
#
# ] O
#
# [ O
#
# 可爱 I-positive
#
# ] O
#
# [ O
#
# 肥皂 O
#
# ] O
#
# 信难求 O
#
# 。 O
#
# 越人语 O
#
# 天姥 B-neutral
#
# ， O
#
# 云霓 O
#
# 啪 O
#
# [ O
#
# 鲜花 B-positive
#
# ] O
#
# 啪 O
#
# [ O
#
# 鲜花 B-positive
#
# ] O
#
# 啪 O
#
# 明灭 O
#
# gf O
#
# 或 O
#
# 可睹 O
#
# 。 O
#
# 天姥 B-neutral
#
# 连天 O
#
# 向 B-positive
#
# 天横 O
#
# ， O
#
# 势拔 O
#
# 五岳 O
#
# 掩 O
#
# 赤城 O
#
# 。 O
#
# 天台 O
#
# 四万 O
#
# 八 I-neutral
#
# 千丈 O
#
# ， O
#
# 对此 O
#
# 啪 O
#
# [ O
#
# 爱 I-positive
#
# 你 B-negative
#
# ] O
#
# 啪 O
#
# [ O
#
# 爱 I-positive
#
# 你 B-negative
#
# ] O
#
# 啪 O
#
# 欲 O
#
# 倒 O
#
# 东 I-positive
#
# f O
#
# 南倾 O
#
# 。 O
#
# 我 B-negative
#
# 欲 O
#
# 因之梦 O
#
# 吴越 B-neutral
#
# 能 O
#
# 快乐 O
#
# 哦哦哦 O
#
# 啦 O
#
# 旅途 O
#
# llk is tagged as UNK and the this arg_max_y e(llk|y) is I-negative
# llk I-negative
#
# 11hvhfgvv is tagged as UNK and the this arg_max_y e(11hvhfgvv|y) is I-negative
# 11hvhfgvv I-negative
#
# new sentence
# # B-positive
#
# 一场 O
#
# 未知 O
#
# 的 I-negative
#
# 旅行 I-neutral
#
# # B-positive
#
# [ O
#
# 哈哈 O
#
# ] O
#
# 我 B-negative
#
# 发现 I-negative
#
# 了 O
#
# 一篇 O
#
# 关于 B-neutral
#
# 【 O
#
# 土耳其 B-neutral
#
# 】 O
#
# 的 I-negative
#
# # B-positive
#
# 蚂蜂 is tagged as UNK and the this arg_max_y e(蚂蜂|y) is I-negative
# 蚂蜂 I-negative
#
# 窝 O
#
# 游记 is tagged as UNK and the this arg_max_y e(游记|y) is I-negative
# 游记 I-negative
#
# # B-positive
#
# - I-neutral
#
# - I-neutral
#
# - I-neutral
#
# 《 B-positive
#
# Lulu is tagged as UNK and the this arg_max_y e(Lulu|y) is I-negative
# Lulu I-negative
#
# 的 I-negative
#
# 土国 is tagged as UNK and the this arg_max_y e(土国|y) is I-negative
# 土国 I-negative
#
# 历险记 is tagged as UNK and the this arg_max_y e(历险记|y) is I-negative
# 历险记 I-negative
#
# — O
#
# — O
#
# 土耳其 B-neutral
#
# 顺时针 is tagged as UNK and the this arg_max_y e(顺时针|y) is I-negative
# 顺时针 I-negative
#
# 9 I-positive
#
# 地 I-negative
#
# 13 B-neutral
#
# 日游 is tagged as UNK and the this arg_max_y e(日游|y) is I-negative
# 日游 I-negative
#
# （ I-neutral
#
# 干货 is tagged as UNK and the this arg_max_y e(干货|y) is I-negative
# 干货 I-negative
#
# + I-positive
#
# 海量 O
#
# 照片 O
#
# ） O
#
# 》 I-negative
#
# ， O
#
# 864 is tagged as UNK and the this arg_max_y e(864|y) is I-negative
# 864 I-negative
#
# 人 I-negative
#
# 【 O
#
# 喜欢 O
#
# 】 O
#
# 。 O
#
# （ I-neutral
#
# 分享 O
#
# 自 O
#
# @ B-positive
#
# 蚂蜂 is tagged as UNK and the this arg_max_y e(蚂蜂|y) is I-negative
# 蚂蜂 I-negative
#
# 窝 O
#
# 自由 I-neutral
#
# 行 I-positive
#
# ） O
#
# http://t.cn/Rqd7c0Q is tagged as UNK and the this arg_max_y e(http://t.cn/Rqd7c0Q|y) is I-negative
# http://t.cn/Rqd7c0Q I-negative
#
# new sentence
# 《 B-positive
#
# 海贼王 I-positive
#
# 》 I-negative
#
# 鹰眼 I-positive
#
# 第二 I-positive
#
# 版 I-positive
#
# 超酷 O
#
# 手办 O
#
# 图集 O
#
# 欣赏 O
#
# 。 O
#
# new sentence
# 人生 I-positive
#
# 版 I-positive
#
# 单机游戏 is tagged as UNK and the this arg_max_y e(单机游戏|y) is I-negative
# 单机游戏 I-negative
#
# 你们 B-positive
#
# 都 O
#
# 是 O
#
# 我 B-negative
#
# 的 I-negative
#
# 怪 O
#
# new sentence
# 数据 O
#
# 是 O
#
# 人 I-negative
#
# 的 I-negative
#
# 数据 O
#
# ， O
#
# 需要 O
#
# 读懂 is tagged as UNK and the this arg_max_y e(读懂|y) is I-negative
# 读懂 I-negative
#
# 人心 O
#
# 的 I-negative
#
# 数据 O
#
# ， O
#
# 才能 I-neutral
#
# 为人所用 is tagged as UNK and the this arg_max_y e(为人所用|y) is I-negative
# 为人所用 I-negative
#
# 。 O
#
# new sentence
# 【 O
#
# 新疆 B-neutral
#
# 新源县 is tagged as UNK and the this arg_max_y e(新源县|y) is I-negative
# 新源县 I-negative
#
# 吐尔根 is tagged as UNK and the this arg_max_y e(吐尔根|y) is I-negative
# 吐尔根 I-negative
#
# 乡 I-negative
#
# 】 O
#
# 有 O
#
# 一片 O
#
# 中世纪 is tagged as UNK and the this arg_max_y e(中世纪|y) is I-negative
# 中世纪 I-negative
#
# 遗留下来 is tagged as UNK and the this arg_max_y e(遗留下来|y) is I-negative
# 遗留下来 I-negative
#
# 最大 B-positive
#
# 的 I-negative
#
# 原始 O
#
# 野 is tagged as UNK and the this arg_max_y e(野|y) is I-negative
# 野 I-negative
#
# 杏林 is tagged as UNK and the this arg_max_y e(杏林|y) is I-negative
# 杏林 I-negative
# ， O
#
# 每年 O
#
# 的 I-negative
#
# 4 O
#
# 月 I-negative
#
# 10 I-negative
#
# 号 I-neutral
#
# 到 O
#
# 20 O
#
# 号 I-neutral
#
# 之间 I-neutral
#
# 开花 O
#
# ， O
#
# 花期 is tagged as UNK and the this arg_max_y e(花期|y) is I-negative
# 花期 I-negative
#
# 一般 O
#
# 在 O
#
# 4 O
#
# - I-neutral
#
# 5 I-neutral
#
# 天 I-neutral
#
# ， O
#
# 早上 O
#
# 日出 O
#
# 时间 O
#
# 8 B-positive
#
# 点 O
#
# ， O
#
# 晚上 O
#
# 落日 is tagged as UNK and the this arg_max_y e(落日|y) is I-negative
# 落日 I-negative
#
# 20 O
#
# 点 O
#
# 30 I-neutral
#
# 分 O
#
# 左右 O
#
# 。 O
#
# 面积 O
#
# 约 I-neutral
#
# 3 I-positive
#
# 万 O
#
# 余亩 O
#
# ， O
#
# 杏树 is tagged as UNK and the this arg_max_y e(杏树|y) is I-negative
# 杏树 I-negative
#
# 林在 is tagged as UNK and the this arg_max_y e(林在|y) is I-negative
# 林在 I-negative
#
# 沟沟壑壑 is tagged as UNK and the this arg_max_y e(沟沟壑壑|y) is I-negative
# 沟沟壑壑 I-negative
#
# ， O
#
# 绵延 O
#
# 十几公里 O
#
# ， O
#
# 山坡 O
#
# 上野 is tagged as UNK and the this arg_max_y e(上野|y) is I-negative
# 上野 I-negative
#
# 杏花 is tagged as UNK and the this arg_max_y e(杏花|y) is I-negative
# 杏花 I-negative
#
# 竞相 is tagged as UNK and the this arg_max_y e(竞相|y) is I-negative
# 竞相 I-negative
#
# 开放 O
#
# ， O
#
# 或 O
#
# 雪白 O
#
# 或 O
#
# 粉红 B-neutral
#
# 的 I-negative
#
# 杏花 is tagged as UNK and the this arg_max_y e(杏花|y) is I-negative
# 杏花 I-negative
#
# ， O
#
# 弥漫着 is tagged as UNK and the this arg_max_y e(弥漫着|y) is I-negative
# 弥漫着 I-negative
#
# 明朗 is tagged as UNK and the this arg_max_y e(明朗|y) is I-negative
# 明朗 I-negative
#
# 鲜艳 O
#
# 的 I-negative
#
# 气息 O
#
# 。 O
#
# new sentence
# 惦记 O
#
# 去 I-negative
#
# 看 O
#
# 广告牌 O
#
# 这件 I-neutral
#
# 事 O
#
# 惦记 O
#
# 了 O
#
# 很 O
#
# 久 B-positive
#
# ， O
#
# 很 O
#
# 早就 O
#
# 说 O
#
# 就算 O
#
# 一个 B-negative
#
# 人 I-negative
#
# 也 O
#
# 一定 O
#
# 要 O
#
# 去 I-negative
#
# 看 O
#
# 我 B-negative
#
# 林宥 B-positive
#
# 嘉 I-positive
#
# ！ O
#
# 临时 O
#
# 去 I-negative
#
# 广交会 O
#
# 办事 O
#
# ， O
#
# 心里 I-neutral
#
# 真的 O
#
# 好 B-negative
#
# 焦急 O
#
# ， O
#
# 自己 B-negative
#
# 太蠢 O
#
# 在 O
#
# 高德置 B-negative
#
# 地 I-negative
#
# 也 O
#
# 找 O
#
# 了 O
#
# 很久很久 O
#
# ， O
#
# 终于 O
#
# 看到 O
#
# 嘉哥 B-neutral
#
# 的 I-negative
#
# 视频 B-neutral
#
# 我 B-negative
#
# 不 I-negative
#
# 知道 O
#
# 怎么 O
#
# 形容 O
#
# 我 B-negative
#
# 的 I-negative
#
# 感觉 O
#
# 觉 O
#
# 广告 I-neutral
#
# 很 O
#
# 短 O
#
# ， O
#
# 却是 O
#
# 我们 B-negative
#
# 一起 O
#
# 努力 O
#
# 的 I-negative
#
# 结果 O
#
# 很 O
#
# 开心 O
#
# ！ O
#
# 这件 I-neutral
#
# 事 O
#
# 应该 O
#
# 足够 O
#
# 我 B-negative
#
# 开心 O
#
# 一个 B-negative
#
# 星期 O
#
# ， O
#
# 牛 I-neutral
#
# 那 O
#
# 就 O
#
# 赶 O
#
# 作业 O
#
# 加油 O
#
# 了 O
#
# ！ O
#
# new sentence
# 一不小心 O
#
# 火锅 I-positive
#
# 吃 O
#
# 撑 O
#
# 了 O
#
# ， O
#
# 那 O
#
# 就 O
#
# 动动手 O
#
# 指头 O
#
# 在 O
#
# # B-positive
#
# 亚洲 I-neutral
#
# 新歌 I-neutral
#
# 榜 I-neutral
#
# # B-positive
#
# 为 O
#
# @ B-positive
#
# TFBOYS I-neutral
#
# 组合 I-positive
#
# 的 I-negative
#
# http O
#
# : O
#
# / O
#
# / O
#
# t O
#
# . O
#
# cn O
#
# / O
#
# RVt9x63 O
#
# 打榜 O
#
# 吧 O
#
# ！ O
#
# new sentence
# 犹豫 is tagged as UNK and the this arg_max_y e(犹豫|y) is I-negative
# 犹豫 I-negative
#
# 了 O
#
# 两个 I-neutral
#
# 月 I-negative
#
# 终于 O
#
# 下手 O
#
# 了 O
#
# ， O
#
# 超 B-neutral
#
# 感谢 O
#
# 父母亲 is tagged as UNK and the this arg_max_y e(父母亲|y) is I-negative
# 父母亲 I-negative
#
# 支持 O
#
# [ O
#
# 泪 I-positive
#
# ] O
#
# [ O
#
# 泪 I-positive
#
# ] O
#
# [ O
#
# 泪 I-positive
#
# ] O
#
# 毕业 O
#
# 前 I-positive
#
# 不会 O
#
# 再换 is tagged as UNK and the this arg_max_y e(再换|y) is I-negative
# 再换 I-negative
#
# 定 O
#
# 焦头 is tagged as UNK and the this arg_max_y e(焦头|y) is I-negative
# 焦头 I-negative
#
# 了 O
#
# ！ O
#
# ！ O
#
# ！ O
#
# new sentence
# 由 O
#
# 五月天 B-neutral
#
# 信 B-positive
#
# 演唱 O
#
# 的 I-negative
#
# 新作 O
#
# 《 B-positive
#
# 你 B-negative
#
# 的 I-negative
#
# 名字 I-neutral
#
# 》 I-negative
#
# [ O
#
# 挖 O
#
# 鼻 I-neutral
#
# ] O
#
# new sentence
# 我 B-negative
#
# 的 I-negative
#
# 创意 B-neutral
#
# ... O
#
# @ B-positive
#
# 球球 I-neutral
#
# 大 I-positive
#
# 作战 I-positive
#
# # B-positive
#
# 带 O
#
# 着 O
#
# 球球 I-neutral
#
# 去 I-negative
#
# 旅行 I-neutral
#
# # B-positive
#
# http O
#
# : O
#
# / O
#
# / O
#
# t O
#
# . O
#
# cn O
#
# / O
#
# RVv94Ti is tagged as UNK and the this arg_max_y e(RVv94Ti|y) is I-negative
# RVv94Ti I-negative
#
# new sentence
# [ O
#
# 得意 O
#
# 地笑 O
#
# ] O
#
# 撸 is tagged as UNK and the this arg_max_y e(撸|y) is I-negative
# 撸 I-negative
#
# 大湿 is tagged as UNK and the this arg_max_y e(大湿|y) is I-negative
# 大湿 I-negative
#
# http://t.cn/RtQ3rrd is tagged as UNK and the this arg_max_y e(http://t.cn/RtQ3rrd|y) is I-negative
# http://t.cn/RtQ3rrd I-negative
#
# 二次元 O
#
# 邪恶 is tagged as UNK and the this arg_max_y e(邪恶|y) is I-negative
# 邪恶 I-negative
#
# 漫画 O
#
# 丁丁 B-negative
#
# 录音 is tagged as UNK and the this arg_max_y e(录音|y) is I-negative
# 录音 I-negative
#
# new sentence
# 由 O
#
# Dongsung is tagged as UNK and the this arg_max_y e(Dongsung|y) is I-negative
# Dongsung I-negative
#
# Jung is tagged as UNK and the this arg_max_y e(Jung|y) is I-negative
# Jung I-negative
#
# 设计 O
#
# 的 I-negative
#
# 拉环 O
#
# 油漆 is tagged as UNK and the this arg_max_y e(油漆|y) is I-negative
# 油漆 I-negative
#
# 桶 B-neutral
#
# （ I-neutral
#
# Easy is tagged as UNK and the this arg_max_y e(Easy|y) is I-negative
# Easy I-negative
#
# Ring is tagged as UNK and the this arg_max_y e(Ring|y) is I-negative
# Ring I-negative
#
# ） O
#
# ， O
#
# 盖子 O
#
# 上面 O
#
# 加入 O
#
# 了 O
#
# 2 I-positive
#
# 个 O
#
# 拉环 O
#
# ， O
#
# 无需 O
#
# 借助 O
#
# 起子 is tagged as UNK and the this arg_max_y e(起子|y) is I-negative
# 起子 I-negative
#
# 或 O
#
# 其它 O
#
# 工具 O
#
# ， O
#
# 两手 is tagged as UNK and the this arg_max_y e(两手|y) is I-negative
# 两手 I-negative
#
# 拉 I-positive
#
# 住 O
#
# 往下压 is tagged as UNK and the this arg_max_y e(往下压|y) is I-negative
# 往下压 I-negative
#
# ， O
#
# 利用 O
#
# 物理 O
#
# 的 I-negative
#
# 压强 is tagged as UNK and the this arg_max_y e(压强|y) is I-negative
# 压强 I-negative
#
# 理论 is tagged as UNK and the this arg_max_y e(理论|y) is I-negative
# 理论 I-negative
#
# ， O
#
# 就 O
#
# 能 O
#
# 将 O
#
# 盖子 O
#
# 轻易 O
#
# 打开 O
#
# ， O
#
# 一个 B-negative
#
# 非常 O
#
# 有趣 O
#
# 简单 O
#
# 的 I-negative
#
# 设计 O
#
# 。 O
#
# new sentence
# 【 O
#
# 惊险 is tagged as UNK and the this arg_max_y e(惊险|y) is I-negative
# 惊险 I-negative
#
# 着陆 is tagged as UNK and the this arg_max_y e(着陆|y) is I-negative
# 着陆 I-negative
#
# ！ O
#
# 飞机 O
#
# 降落 is tagged as UNK and the this arg_max_y e(降落|y) is I-negative
# 降落 I-negative
#
# 瞬间 O
#
# 被 O
#
# 大风 is tagged as UNK and the this arg_max_y e(大风|y) is I-negative
# 大风 I-negative
#
# 吹 O
#
# 歪 O
#
# 】 O
#
# 近日 O
#
# ， O
#
# 一架 is tagged as UNK and the this arg_max_y e(一架|y) is I-negative
# 一架 I-negative
#
# 波音 is tagged as UNK and the this arg_max_y e(波音|y) is I-negative
# 波音 I-negative
#
# 客机 is tagged as UNK and the this arg_max_y e(客机|y) is I-negative
# 客机 I-negative
#
# 准备 O
#
# 在 O
#
# 捷克 is tagged as UNK and the this arg_max_y e(捷克|y) is I-negative
# 捷克 I-negative
#
# 机场 I-neutral
#
# 降落 is tagged as UNK and the this arg_max_y e(降落|y) is I-negative
# 降落 I-negative
#
# 时 O
#
# ， O
#
# 突然 O
#
# 遭遇 O
#
# 了 O
#
# 大风 is tagged as UNK and the this arg_max_y e(大风|y) is I-negative
# 大风 I-negative
#
# ， O
#
# 造成 O
#
# 飞机 O
#
# 机身 O
#
# 整个 O
#
# 倾斜 O
#
# ， O
#
# 为了 O
#
# 防止 O
#
# 撞机 is tagged as UNK and the this arg_max_y e(撞机|y) is I-negative
# 撞机 I-negative
#
# 事故 O
#
# 的 I-negative
#
# 发生 O
#
# ， O
#
# 驾驶员 O
#
# 立即 is tagged as UNK and the this arg_max_y e(立即|y) is I-negative
# 立即 I-negative
#
# 放弃 O
#
# 了 O
#
# 着陆 is tagged as UNK and the this arg_max_y e(着陆|y) is I-negative
# 着陆 I-negative
#
# 。 O
#
# 第二次 O
#
# 降落 is tagged as UNK and the this arg_max_y e(降落|y) is I-negative
# 降落 I-negative
#
# 时 O
#
# ， O
#
# 飞机 O
#
# 仍然 O
#
# 有 O
#
# 一定 O
#
# 幅度 is tagged as UNK and the this arg_max_y e(幅度|y) is I-negative
# 幅度 I-negative
#
# 的 I-negative
#
# 摇摆 is tagged as UNK and the this arg_max_y e(摇摆|y) is I-negative
# 摇摆 I-negative
#
# ， O
#
# 但是 O
#
# 这次 O
#
# 安全 I-neutral
#
# 降落 is tagged as UNK and the this arg_max_y e(降落|y) is I-negative
# 降落 I-negative
#
# 。 O
#
# 事后 is tagged as UNK and the this arg_max_y e(事后|y) is I-negative
# 事后 I-negative
#
# 驾驶员 O
#
# 被 O
#
# 当地 O
#
# 称为 I-neutral
#
# 英雄 B-neutral
#
# 。 O
#
# （ I-neutral
#
# 参考消息 is tagged as UNK and the this arg_max_y e(参考消息|y) is I-negative
# 参考消息 I-negative
#
# ） O
#
# http://t.cn/RVb01hs is tagged as UNK and the this arg_max_y e(http://t.cn/RVb01hs|y) is I-negative
# http://t.cn/RVb01hs I-negative
#
# new sentence
# 魔导 is tagged as UNK and the this arg_max_y e(魔导|y) is I-negative
# 魔导 I-negative
#
# 士 is tagged as UNK and the this arg_max_y e(士|y) is I-negative
# 士 I-negative
#
# 联合 I-neutral
#
# 知名 O
#
# COSER is tagged as UNK and the this arg_max_y e(COSER|y) is I-negative
# COSER I-negative
#
# 推出 O
#
# 震撼 O
#
# 级 I-positive
#
# 希尔 is tagged as UNK and the this arg_max_y e(希尔|y) is I-negative
# 希尔 I-negative
#
# 瓦 I-neutral
#
# 娜斯 is tagged as UNK and the this arg_max_y e(娜斯|y) is I-negative
# 娜斯 I-negative
#
# Cosplay is tagged as UNK and the this arg_max_y e(Cosplay|y) is I-negative
# Cosplay I-negative
#
# 大片 O
#
# . O
#
# new sentence
# 年龄 O
#
# 只是 O
#
# 一个 B-negative
#
# 数字 O
#
# ， O
#
# 永远 O
#
# 活在 O
#
# 十六岁 O
#
# 的 I-negative
#
# 花季 is tagged as UNK and the this arg_max_y e(花季|y) is I-negative
# 花季 I-negative
#
# 。 O
#
# 祝福 O
#
# 照片 O
#
# 中 O
#
# 可爱 I-positive
#
# 的 I-negative
#
# 小女孩 is tagged as UNK and the this arg_max_y e(小女孩|y) is I-negative
# 小女孩 I-negative
#
# 生日快乐 O
#
# ！ O
#
# [ O
#
# 蛋糕 I-negative
#
# ] O
#
# 谢谢 O
#
# 我们 B-negative
#
# 家 B-neutral
#
# “ O
#
# 老二 is tagged as UNK and the this arg_max_y e(老二|y) is I-negative
# 老二 I-negative
#
# ” O
#
# 的 I-negative
#
# 生日礼物 is tagged as UNK and the this arg_max_y e(生日礼物|y) is I-negative
# 生日礼物 I-negative
#
# ， O
#
# 超棒超 is tagged as UNK and the this arg_max_y e(超棒超|y) is I-negative
# 超棒超 I-negative
#
# 喜欢 O
#
# ！ O
#
# [ O
#
# 心 O
#
# ] O
#
# new sentence
# 《 B-positive
#
# 亚马逊 is tagged as UNK and the this arg_max_y e(亚马逊|y) is I-negative
# 亚马逊 I-negative
#
# 资深 O
#
# 卖 O
#
# 家教 is tagged as UNK and the this arg_max_y e(家教|y) is I-negative
# 家教 I-negative
#
# 您 I-neutral
#
# 做 O
#
# AMAZON is tagged as UNK and the this arg_max_y e(AMAZON|y) is I-negative
# AMAZON I-negative
#
# 08 is tagged as UNK and the this arg_max_y e(08|y) is I-negative
# 08 I-negative
#
# 亚马逊 is tagged as UNK and the this arg_max_y e(亚马逊|y) is I-negative
# 亚马逊 I-negative
#
# 卖家 O
#
# Add is tagged as UNK and the this arg_max_y e(Add|y) is I-negative
# Add I-negative
#
# A B-negative
#
# Product is tagged as UNK and the this arg_max_y e(Product|y) is I-negative
# Product I-negative
#
# 单个 is tagged as UNK and the this arg_max_y e(单个|y) is I-negative
# 单个 I-negative
#
# 产品 B-neutral
#
# 上传 O
#
# http://t.cn/R5icp3c is tagged as UNK and the this arg_max_y e(http://t.cn/R5icp3c|y) is I-negative
# http://t.cn/R5icp3c I-negative
#
# - I-neutral
#
# 跨境 is tagged as UNK and the this arg_max_y e(跨境|y) is I-negative
# 跨境 I-negative
#
# 电商 is tagged as UNK and the this arg_max_y e(电商|y) is I-negative
# 电商 I-negative
#
# 视频教程 is tagged as UNK and the this arg_max_y e(视频教程|y) is I-negative
# 视频教程 I-negative
#
# ， O
#
# Amazon B-neutral
#
# ( O
#
# 亚马逊 is tagged as UNK and the this arg_max_y e(亚马逊|y) is I-negative
# 亚马逊 I-negative
#
# ) O
#
# eBay is tagged as UNK and the this arg_max_y e(eBay|y) is I-negative
# eBay I-negative
#
# Aliexpress is tagged as UNK and the this arg_max_y e(Aliexpress|y) is I-negative
# Aliexpress I-negative
#
# ( O
#
# 全球 I-positive
#
# 速卖通 is tagged as UNK and the this arg_max_y e(速卖通|y) is I-negative
# 速卖通 I-negative
#
# ) O
#
# Wish is tagged as UNK and the this arg_max_y e(Wish|y) is I-negative
# Wish I-negative
#
# 商户 is tagged as UNK and the this arg_max_y e(商户|y) is I-negative
# 商户 I-negative
#
# Lazada is tagged as UNK and the this arg_max_y e(Lazada|y) is I-negative
# Lazada I-negative
#
# 等 O
#
# 电商 is tagged as UNK and the this arg_max_y e(电商|y) is I-negative
# 电商 I-negative
#
# 平台 I-positive
#
# 实战 is tagged as UNK and the this arg_max_y e(实战|y) is I-negative
# 实战 I-negative
#
# 运营 is tagged as UNK and the this arg_max_y e(运营|y) is I-negative
# 运营 I-negative
#
# 推广 O
#
# 培训 is tagged as UNK and the this arg_max_y e(培训|y) is I-negative
# 培训 I-negative
#
# 》 I-negative
#
# @ B-positive
#
# adoncn is tagged as UNK and the this arg_max_y e(adoncn|y) is I-negative
# adoncn I-negative
#
# new sentence
# 就 O
#
# 知道 O
#
# 你 B-negative
#
# 还是 O
#
# 爱 I-positive
#
# 我 B-negative
#
# 的 I-negative
#
# my O
#
# 泉 B-positive
#
# 现在 O
#
# 超 B-neutral
#
# 开心 O
#
# [ O
#
# 好 B-negative
#
# 喜欢 O
#
# ] O
#
# new sentence
# @ B-positive
#
# 林俊杰 B-negative
#
# 已经 O
#
# 在 O
#
# # B-positive
#
# 明星 I-neutral
#
# 势力 I-neutral
#
# 榜 I-neutral
#
# # B-positive
#
# 港澳台 O
#
# 榜上 O
#
# 为 O
#
# 你 B-negative
#
# 加油 O
#
# 啦 O
#
# ， O
#
# 你 B-negative
#
# 是 O
#
# 我 B-negative
#
# 今生 O
#
# 唯一 I-positive
#
# 的 I-negative
#
# 执著 O
#
# 哦 O
#
# 。 O
#
# 棒棒 O
#
# 哒 O
#
# ！ O
#
# http://t.cn/Rz5DeQ3 is tagged as UNK and the this arg_max_y e(http://t.cn/Rz5DeQ3|y) is I-negative
# http://t.cn/Rz5DeQ3 I-negative
#
# new sentence
# 【 O
#
# 宁波 is tagged as UNK and the this arg_max_y e(宁波|y) is I-negative
# 宁波 I-negative
#
# 博物馆 I-positive
#
# ， O
#
# 中国 B-negative
#
# 建筑业 is tagged as UNK and the this arg_max_y e(建筑业|y) is I-negative
# 建筑业 I-negative
#
# 最高 O
#
# 荣誉 O
#
# 】 O
#
# 宁波 is tagged as UNK and the this arg_max_y e(宁波|y) is I-negative
# 宁波 I-negative
#
# 博物馆 I-positive
#
# 又名 O
#
# 鄞州 is tagged as UNK and the this arg_max_y e(鄞州|y) is I-negative
# 鄞州 I-negative
#
# 博物馆 I-positive
#
# ， O
#
# 与 O
#
# 这座 O
#
# 城市 B-negative
#
# 的 I-negative
#
# 年纪 O
#
# 相仿 is tagged as UNK and the this arg_max_y e(相仿|y) is I-negative
# 相仿 I-negative
#
# 的 I-negative
#
# 瓦 I-neutral
#
# 爿 is tagged as UNK and the this arg_max_y e(爿|y) is I-negative
# 爿 I-negative
#
# 墙 O
#
# 所 O
#
# 筑造 is tagged as UNK and the this arg_max_y e(筑造|y) is I-negative
# 筑造 I-negative
#
# 的 I-negative
#
# 震撼 O
#
# ， O
#
# 宁波 is tagged as UNK and the this arg_max_y e(宁波|y) is I-negative
# 宁波 I-negative
#
# 博物馆 I-positive
#
# 像泊 is tagged as UNK and the this arg_max_y e(像泊|y) is I-negative
# 像泊 I-negative
#
# 在 O
#
# 岸上 is tagged as UNK and the this arg_max_y e(岸上|y) is I-negative
# 岸上 I-negative
#
# 的 I-negative
#
# 船 I-positive
#
# ， O
#
# 这艘 is tagged as UNK and the this arg_max_y e(这艘|y) is I-negative
# 这艘 I-negative
#
# 经典之作 is tagged as UNK and the this arg_max_y e(经典之作|y) is I-negative
# 经典之作 I-negative
#
# 由 O
#
# 普 is tagged as UNK and the this arg_max_y e(普|y) is I-negative
# 普 I-negative
#
# 利兹 is tagged as UNK and the this arg_max_y e(利兹|y) is I-negative
# 利兹 I-negative
#
# 克 O
#
# 建筑 O
#
# 奖 O
#
# 首位 O
#
# 中国籍 is tagged as UNK and the this arg_max_y e(中国籍|y) is I-negative
# 中国籍 I-negative
#
# 获奖者 is tagged as UNK and the this arg_max_y e(获奖者|y) is I-negative
# 获奖者 I-negative
#
# 王澍 is tagged as UNK and the this arg_max_y e(王澍|y) is I-negative
# 王澍 I-negative
#
# 掌 O
#
# 舵 is tagged as UNK and the this arg_max_y e(舵|y) is I-negative
# 舵 I-negative
#
# 驶入 is tagged as UNK and the this arg_max_y e(驶入|y) is I-negative
# 驶入 I-negative
#
# 世界 B-negative
#
# 建筑 O
#
# 青史 is tagged as UNK and the this arg_max_y e(青史|y) is I-negative
# 青史 I-negative
#
# 。 O
#
# new sentence
# 波斯顿 is tagged as UNK and the this arg_max_y e(波斯顿|y) is I-negative
# 波斯顿 I-negative
#
# 男士 I-neutral
#
# 薄荷 is tagged as UNK and the this arg_max_y e(薄荷|y) is I-negative
# 薄荷 I-negative
#
# 味 O
#
# 润唇膏 is tagged as UNK and the this arg_max_y e(润唇膏|y) is I-negative
# 润唇膏 I-negative
#
# 3g is tagged as UNK and the this arg_max_y e(3g|y) is I-negative
# 3g I-negative
#
# new sentence
# 训觉 is tagged as UNK and the this arg_max_y e(训觉|y) is I-negative
# 训觉 I-negative
#
# 了 O
#
# ， O
#
# 各位 O
#
# 小伙伴 B-neutral
#
# 们 I-negative
#
# ， O
#
# 晚安 O
#
# ！ O
#
# new sentence
# 逃票 is tagged as UNK and the this arg_max_y e(逃票|y) is I-negative
# 逃票 I-negative
#
# 。 O
#
# 。 O
#
# 。 O
#
# 绿岛 is tagged as UNK and the this arg_max_y e(绿岛|y) is I-negative
# 绿岛 I-negative
#
# 风 B-neutral
#
# 排气扇 is tagged as UNK and the this arg_max_y e(排气扇|y) is I-negative
# 排气扇 I-negative
#
# new sentence
# 再 O
#
# 不 I-negative
#
# 看 O
#
# 我 B-negative
#
# 的 I-negative
#
# 直播 I-negative
#
# ， O
#
# 你 B-negative
#
# 就 O
#
# OUT is tagged as UNK and the this arg_max_y e(OUT|y) is I-negative
# OUT I-negative
#
# 了 O
#
# ！ O
#
# 知 I-neutral
#
# 你 B-negative
#
# 冷暖 is tagged as UNK and the this arg_max_y e(冷暖|y) is I-negative
# 冷暖 I-negative
#
# 正在 O
#
# @ B-positive
#
# QQ B-neutral
#
# 空间 O
#
# 直播 I-negative
#
# ， O
#
# 点此 O
#
# 进入 B-neutral
#
# > O
#
# > O
#
# http://t.cn/RVtTfZD is tagged as UNK and the this arg_max_y e(http://t.cn/RVtTfZD|y) is I-negative
# http://t.cn/RVtTfZD I-negative
#
# new sentence
# 别人 B-neutral
#
# 都 O
#
# 管 O
#
# 我 B-negative
#
# 叫 O
#
# 预言 O
#
# 帝 O
#
# ， O
#
# 我 B-negative
#
# 猜 O
#
# 荷兰 B-positive
#
# 和 O
#
# 法国 B-neutral
#
# 比赛 I-neutral
#
# 的 I-negative
#
# 结果 O
#
# 为 O
#
# 荷兰 B-positive
#
# 胜 O
#
# 。 O
#
# 来 B-negative
#
# # B-positive
#
# 最佳阵容 O
#
# # B-positive
#
# 一起 O
#
# 猜 O
#
# 比分 O
#
# 吧 O
#
# ！ O
#
# 下载 O
#
# 链接 O
#
# ： O
#
# http://t.cn/R5dgyif O
#
# new sentence
# Eason is tagged as UNK and the this arg_max_y e(Eason|y) is I-negative
# Eason I-negative
#
# 是 O
#
# 我 B-negative
#
# 听 O
#
# 的 I-negative
#
# 所有 O
#
# 歌手 O
#
# 中 O
#
# 现场 I-positive
#
# 唱 I-neutral
#
# 的 I-negative
#
# 最 O
#
# 棒 O
#
# 的 I-negative
#
# [ O
#
# 怒骂 O
#
# ] O
#
# new sentence
# h is tagged as UNK and the this arg_max_y e(h|y) is I-negative
# h I-negative
#
# i O
#
# 小朋友 O
#
# 以后 O
#
# 的 I-negative
#
# 人生 I-positive
#
# 要 O
#
# 自己 B-negative
#
# 罩 I-negative
#
# 着 O
#
# 自己 B-negative
#
# 啦 O
# 谢谢 O
#
# 你们 B-positive
#
# 给 O
#
# 我 B-negative
#
# 的 I-negative
#
# 爱 I-positive
#
# ～ I-positive
#
# new sentence
# 佳静 is tagged as UNK and the this arg_max_y e(佳静|y) is I-negative
# 佳静 I-negative
#
# 公主 I-positive
#
# 又 O
#
# 回去 O
#
# 了 O
#
# ， O
#
# 感冒 I-neutral
#
# 快点 O
#
# 好 B-negative
#
# ， O
#
# 下次 O
#
# 就 O
#
# 我 B-negative
#
# 来看 O
#
# 你 B-negative
#
# 了 O
#
# [ O
#
# 爱 I-positive
#
# 你 B-negative
#
# ] O
#
# new sentence
# 下次 O
#
# 再 O
#
# 合作 O
#
# 设计 O
#
# 的 I-negative
#
# 时候 O
#
# 一定 O
#
# 要 O
#
# 先谈 is tagged as UNK and the this arg_max_y e(先谈|y) is I-negative
# 先谈 I-negative
#
# 好 B-negative
#
# 怎么 O
#
# 在 O
#
# ps is tagged as UNK and the this arg_max_y e(ps|y) is I-negative
# ps I-negative
#
# 里 O
#
# 给 O
#
# 图层 is tagged as UNK and the this arg_max_y e(图层|y) is I-negative
# 图层 I-negative
#
# 起名 I-positive
#
# 建组加 is tagged as UNK and the this arg_max_y e(建组加|y) is I-negative
# 建组加 I-negative
#
# 蒙版 is tagged as UNK and the this arg_max_y e(蒙版|y) is I-negative
# 蒙版 I-negative
#
# ... O
#
# 我 B-negative
#
# 现在 O
#
# 看着 O
#
# 队友 is tagged as UNK and the this arg_max_y e(队友|y) is I-negative
# 队友 I-negative
#
# 的 I-negative
#
# psd is tagged as UNK and the this arg_max_y e(psd|y) is I-negative
# psd I-negative
#
# 图层 is tagged as UNK and the this arg_max_y e(图层|y) is I-negative
# 图层 I-negative
#
# 完全 O
#
# 是 O
#
# 懵 is tagged as UNK and the this arg_max_y e(懵|y) is I-negative
# 懵 I-negative
#
# 逼 I-negative
#
# 的 I-negative
#
# ... O
#
# new sentence
# 北极熊 is tagged as UNK and the this arg_max_y e(北极熊|y) is I-negative
# 北极熊 I-negative
#
# 系列 I-neutral
#
# 陶艺 is tagged as UNK and the this arg_max_y e(陶艺|y) is I-negative
# 陶艺 I-negative
#
# 艺术品 is tagged as UNK and the this arg_max_y e(艺术品|y) is I-negative
# 艺术品 I-negative
#
# ， O
#
# 好 B-negative
#
# 想 O
#
# 买 O
#
# 一套 B-negative
#
# ！ O
#
# new sentence
# 我 B-negative
#
# 在 O
#
# 为 O
#
# # B-positive
#
# 叮咯咙 O
#
# 咚 O
#
# 呛 O
#
# # B-positive
#
# @ B-positive
#
# 霍尊 I-positive
#
# 加油 O
#
# 助威 O
#
# ， O
#
# 发博 is tagged as UNK and the this arg_max_y e(发博|y) is I-negative
# 发博 I-negative
#
# 支持 O
#
# 你 B-negative
#
# 喜爱 O
#
# 的 I-negative
#
# 明星 I-neutral
#
# ， O
#
# 与 O
#
# 他们 B-positive
#
# 一起 O
#
# 弘扬 is tagged as UNK and the this arg_max_y e(弘扬|y) is I-negative
# 弘扬 I-negative
#
# 传统 O
#
# 文化 I-positive
#
# ， O
#
# 助力 O
#
# “ O
#
# 非遗 is tagged as UNK and the this arg_max_y e(非遗|y) is I-negative
# 非遗 I-negative
#
# ” O
#
# 传承 O
#
# ！ O
#
# http://t.cn/RcDQrs7 is tagged as UNK and the this arg_max_y e(http://t.cn/RcDQrs7|y) is I-negative
# http://t.cn/RcDQrs7 I-negative
#
# new sentence
# # B-positive
#
# 微博 B-neutral
#
# 橱窗 O
#
# ## B-positive
#
# 全网 is tagged as UNK and the this arg_max_y e(全网|y) is I-negative
# 全网 I-negative
#
# 诚信通 is tagged as UNK and the this arg_max_y e(诚信通|y) is I-negative
# 诚信通 I-negative
#
# 官方 O
#
# # B-positive
#
# 厂家直销 O
#
# LED I-neutral
#
# 电子 O
#
# 蜡烛 O
#
# 节能 is tagged as UNK and the this arg_max_y e(节能|y) is I-negative
# 节能 I-negative
#
# 环保 O
#
# 无烟 is tagged as UNK and the this arg_max_y e(无烟|y) is I-negative
# 无烟 I-negative
#
# 电子 O
#
# 婚庆 is tagged as UNK and the this arg_max_y e(婚庆|y) is I-negative
# 婚庆 I-negative
#
# 工艺 O
#
# 表白 O
#
# 蜡烛 O
#
# 灯 I-positive
#
# 批发 O
#
# http://t.cn/RVqKlNY is tagged as UNK and the this arg_max_y e(http://t.cn/RVqKlNY|y) is I-negative
# http://t.cn/RVqKlNY I-negative
#
# new sentence
# 津南 is tagged as UNK and the this arg_max_y e(津南|y) is I-negative
# 津南 I-negative
#
# ， O
#
# 10 I-negative
#
# 月 I-negative
#
# 12 I-neutral
#
# 日 O
#
# ， O
#
# 周三 O
#
# ， O
#
# 空气质量 O
#
# 指数 I-neutral
#
# ： O
#
# 78 O
#
# ， O
#
# 空气质量 O
#
# ： O
#
# 良 O
#
# 。 O
#
# new sentence
# 我 B-negative
#
# 也 O
#
# 不 I-negative
#
# 知道 O
#
# 那根筋 is tagged as UNK and the this arg_max_y e(那根筋|y) is I-negative
# 那根筋 I-negative
#
# 搭错 is tagged as UNK and the this arg_max_y e(搭错|y) is I-negative
# 搭错 I-negative
#
# 了 O
#
# ， O
#
# 学着 is tagged as UNK and the this arg_max_y e(学着|y) is I-negative
# 学着 I-negative
#
# 传播学 is tagged as UNK and the this arg_max_y e(传播学|y) is I-negative
# 传播学 I-negative
#
# ， O
#
# 还 O
#
# 辅修 is tagged as UNK and the this arg_max_y e(辅修|y) is I-negative
# 辅修 I-negative
#
# 了 O
#
# 一门 is tagged as UNK and the this arg_max_y e(一门|y) is I-negative
# 一门 I-negative
#
# pr is tagged as UNK and the this arg_max_y e(pr|y) is I-negative
# pr I-negative
#
# 。 O
#
# 到 O
#
# 现在 O
#
# reading is tagged as UNK and the this arg_max_y e(reading|y) is I-negative
# reading I-negative
#
# 根本 O
#
# 读 O
#
# 不 I-negative
#
# 完 I-positive
#
# ， O
#
# 现在 O
#
# 想想 O
#
# 那些 I-neutral
#
# 英文 I-positive
#
# 短文 is tagged as UNK and the this arg_max_y e(短文|y) is I-negative
# 短文 I-negative
#
# 真实 O
#
# 简单 O
#
# 那 O
#
# ！ O
#
# 一眼 O
#
# 就 O
#
# 过 O
#
# 了 O
#
# 。 O
#
# 。 O
#
# 真想 is tagged as UNK and the this arg_max_y e(真想|y) is I-negative
# 真想 I-negative
#
# 回家 O
#
# 。 O
#
# essay is tagged as UNK and the this arg_max_y e(essay|y) is I-negative
# essay I-negative
#
# 怎么办 O
#
# new sentence
# 在 O
#
# 马来西亚 O
#
# 发现 I-negative
#
# 了 O
#
# 这 O
#
# 条长 is tagged as UNK and the this arg_max_y e(条长|y) is I-negative
# 条长 I-negative
#
# 达 I-positive
#
# 55 O
#
# 英尺 O
#
# （ I-neutral
#
# 约 I-neutral
#
# 16 I-positive
#
# . O
#
# 7 I-neutral
#
# 米 B-neutral
#
# ） O
#
# 的 I-negative
#
# 蟒蛇 is tagged as UNK and the this arg_max_y e(蟒蛇|y) is I-negative
# 蟒蛇 I-negative
#
# ， O
#
# 这 O
#
# 也许 O
#
# 是 O
#
# 人类 B-negative
#
# 发现 I-negative
#
# 的 I-negative
#
# 最长 O
#
# 的 I-negative
#
# 蟒蛇 is tagged as UNK and the this arg_max_y e(蟒蛇|y) is I-negative
# 蟒蛇 I-negative
#
# 了 O
#
# ， O
#
# 它 B-negative
#
# 重达 is tagged as UNK and the this arg_max_y e(重达|y) is I-negative
# 重达 I-negative
#
# 300 O
#
# 公斤 O
#
# ， O
#
# 估计 O
#
# 已经 O
#
# 是 O
#
# 140 is tagged as UNK and the this arg_max_y e(140|y) is I-negative
# 140 I-negative
#
# 岁 I-negative
#
# 高龄 O
#
# 了 O
#
# 。 O
#
# 据说 is tagged as UNK and the this arg_max_y e(据说|y) is I-negative
# 据说 I-negative
#
# 是 O
#
# 林业 is tagged as UNK and the this arg_max_y e(林业|y) is I-negative
# 林业 I-negative
#
# 工人 is tagged as UNK and the this arg_max_y e(工人|y) is I-negative
# 工人 I-negative
#
# 在 O
#
# 用 O
#
# 挖掘机 I-neutral
#
# 开辟 is tagged as UNK and the this arg_max_y e(开辟|y) is I-negative
# 开辟 I-negative
#
# 新路 is tagged as UNK and the this arg_max_y e(新路|y) is I-negative
# 新路 I-negative
#
# 时 O
#
# 挖出 is tagged as UNK and the this arg_max_y e(挖出|y) is I-negative
# 挖出 I-negative
#
# 了 O
#
# 这条 O
#
# 巨蟒 is tagged as UNK and the this arg_max_y e(巨蟒|y) is I-negative
# 巨蟒 I-negative
#
# ， O
#
# 而开 is tagged as UNK and the this arg_max_y e(而开|y) is I-negative
# 而开 I-negative
#
# 挖掘机 I-neutral
#
# 的 I-negative
#
# 司机 I-positive
#
# 也 O
#
# 因为 O
#
# 受到 O
#
# 惊吓 is tagged as UNK and the this arg_max_y e(惊吓|y) is I-negative
# 惊吓 I-negative
#
# ， O
#
# 突发 O
#
# 心脏病 B-negative
#
# 死 O
#
# 。 O
#
# new sentence
# 【 O
#
# 石界 is tagged as UNK and the this arg_max_y e(石界|y) is I-negative
# 石界 I-negative
#
# 画语 is tagged as UNK and the this arg_max_y e(画语|y) is I-negative
# 画语 I-negative
#
# ： O
#
# 一转 is tagged as UNK and the this arg_max_y e(一转|y) is I-negative
# 一转 I-negative
#
# 已 O
#
# 是 O
#
# 万年 O
#
# 身 O
#
# ， O
#
# 沉淀 O
#
# 方是 is tagged as UNK and the this arg_max_y e(方是|y) is I-negative
# 方是 I-negative
#
# 石 is tagged as UNK and the this arg_max_y e(石|y) is I-negative
# 石 I-negative
#
# 】 O
#
# （ I-neutral
#
# 我 B-negative
#
# 在 O
#
# @ B-positive
#
# 头条 B-neutral
#
# 号 I-neutral
#
# 发了 O
#
# 一篇 O
#
# 文章 O
#
# ） O
#
# http://t.cn/RVtThY7 is tagged as UNK and the this arg_max_y e(http://t.cn/RVtThY7|y) is I-negative
# http://t.cn/RVtThY7 I-negative
#
# new sentence
# 图透下 is tagged as UNK and the this arg_max_y e(图透下|y) is I-negative
# 图透下 I-negative
#
# … O
#
# 忍不住 O
#
# … O
#
# 新舞 is tagged as UNK and the this arg_max_y e(新舞|y) is I-negative
# 新舞 I-negative
#
# 视频 B-neutral
#
# 出来 O
#
# 了 O
#
# ， O
#
# 投稿 O
#
# 投稿 O
#
# new sentence
# # B-positive
#
# 爱享 I-positive
#
# 蜜月旅行 I-positive
#
# # B-positive
#
# 浪漫 B-positive
#
# 来袭 O
#
# ( O
#
# ╭ B-positive
#
# ￣ O
#
# 3 I-positive
#
# ￣ O
#
# ) O
#
# ╭ B-positive
#
# ♡ O
#
# 我 B-negative
#
# 刚刚 O
#
# 抽到 O
#
# 了 O
#
# @ B-positive
#
# 疯狂 I-neutral
#
# 婚礼 I-neutral
#
# 季 I-positive
#
# 的 I-negative
#
# 现金 B-positive
#
# 红包 I-positive
#
# ！ O
#
# 掐指一算 O
#
# ， O
#
# 马上 O
#
# 就要 O
#
# 脱单 O
#
# 了 O
#
# ！ O
#
# 你 B-negative
#
# 还 O
#
# 不 I-negative
#
# 赶紧 O
#
# 来 B-negative
#
# 参与 O
#
# ？ O
#
# http://t.cn/RVqKaUk O
#
# new sentence
# # B-positive
#
# 哔哩 is tagged as UNK and the this arg_max_y e(哔哩|y) is I-negative
# 哔哩 I-negative
#
# 哔哩 is tagged as UNK and the this arg_max_y e(哔哩|y) is I-negative
# 哔哩 I-negative
#
# 动画 I-neutral
#
# # B-positive
#
# 【 O
#
# 泰剧 is tagged as UNK and the this arg_max_y e(泰剧|y) is I-negative
# 泰剧 I-negative
#
# / O
#
# 7 I-neutral
#
# 月 I-negative
#
# 】 O
#
# 《 B-positive
#
# 夏日 O
#
# 菊花茶 is tagged as UNK and the this arg_max_y e(菊花茶|y) is I-negative
# 菊花茶 I-negative
#
# 》 I-negative
#
# 中字 O
#
# 第一集 is tagged as UNK and the this arg_max_y e(第一集|y) is I-negative
# 第一集 I-negative
#
# @ B-positive
#
# 天府 is tagged as UNK and the this arg_max_y e(天府|y) is I-negative
# 天府 I-negative
#
# 泰剧 is tagged as UNK and the this arg_max_y e(泰剧|y) is I-negative
# 泰剧 I-negative
#
# - I-neutral
#
# P1 is tagged as UNK and the this arg_max_y e(P1|y) is I-negative
# P1 I-negative
#
# 哈哈哈 O
#
# 承包 is tagged as UNK and the this arg_max_y e(承包|y) is I-negative
# 承包 I-negative
#
# 本集 is tagged as UNK and the this arg_max_y e(本集|y) is I-negative
# 本集 I-negative
#
# 笑 O
#
# 点 O
#
# http://t.cn/Rtc0wQk is tagged as UNK and the this arg_max_y e(http://t.cn/Rtc0wQk|y) is I-negative
# http://t.cn/Rtc0wQk I-negative
#
# new sentence
# # B-positive
#
# 微笑 I-positive
#
# 童行 I-positive
#
# # B-positive
#
# 是 O
#
# 的 I-negative
#
# ， O
#
# 能 O
#
# 触动 is tagged as UNK and the this arg_max_y e(触动|y) is I-negative
# 触动 I-negative
#
# 人心 O
#
# 的 I-negative
#
# 童星 B-positive
#
# ~ I-positive
#
# new sentence
# # B-positive
#
# 青云 I-positive
#
# 志 I-positive
#
# # B-positive
#
# 赵丽颖 B-positive
#
# 真的 O
#
# 太漂亮 O
#
# 了 O
#
# ， O
#
# 就 O
#
# 因为 O
#
# 他 B-negative
#
# 所以 O
#
# 我 B-negative
#
# 来看 O
#
# 青云 I-positive
#
# 志 I-positive
#
# 真是 O
#
# 爱死 is tagged as UNK and the this arg_max_y e(爱死|y) is I-negative
# 爱死 I-negative
#
# 了 O
#
# ， O
#
# 特别 O
#
# 好 B-negative
#
# 的 I-negative
#
# 呢 O
#
# new sentence
# # B-positive
#
# 龙珠 B-positive
#
# Z I-positive
#
# ： O
#
# 复活 I-positive
#
# 的 I-negative
#
# 弗利 I-positive
#
# 萨 I-positive
#
# 定档 O
#
# 1021 O
#
# # B-positive
#
# 心中 O
#
# 一缕 O
#
# 燥动 O
#
# 飘过 O
#
# ， O
#
# 龙珠 B-positive
#
# z I-positive
#
# 好赞 O
#
# 好受 is tagged as UNK and the this arg_max_y e(好受|y) is I-negative
# 好受 I-negative
#
# 欢迎 O
#
# 的 I-negative
#
# 哈 O
#
# ， O
#
# 绝对 I-neutral
#
# 的 I-negative
#
# 哈 O
#
# 。 O
#
# new sentence
# 这个 I-negative
#
# 基准 is tagged as UNK and the this arg_max_y e(基准|y) is I-negative
# 基准 I-negative
#
# 站 I-neutral
#
# 有 O
#
# 什么 O
#
# 作用 O
#
# ？ O
#
# new sentence
# # B-positive
#
# 赵丽颖 B-positive
#
# 记忆 I-neutral
#
# 被 O
#
# 掏空 O
#
# # B-positive
#
# 电光 is tagged as UNK and the this arg_max_y e(电光|y) is I-negative
# 电光 I-negative
#
# 人 I-negative
#
# 什么 O
#
# 的 I-negative
#
# 有 O
#
# 多里 is tagged as UNK and the this arg_max_y e(多里|y) is I-negative
# 多里 I-negative
#
# hi is tagged as UNK and the this arg_max_y e(hi|y) is I-negative
# hi I-negative
#
# 啊 I-positive
#
# 的 I-negative
#
# 赵丽颖 B-positive
#
# new sentence
# 「 B-negative
#
# － I-neutral
#
# 娅 is tagged as UNK and the this arg_max_y e(娅|y) is I-negative
# 娅 I-negative
#
# 娅 is tagged as UNK and the this arg_max_y e(娅|y) is I-negative
# 娅 I-negative
#
# 」 I-negative
#
# 的 I-negative
#
# 直播间 I-neutral
#
# 有 O
#
# 一个 B-negative
#
# 关于 B-neutral
#
# 你 B-negative
#
# 的 I-negative
#
# 评论 O
#
# ， O
#
# 是否 I-neutral
#
# 查看 O
#
# ？ O
#
# http://t.cn/RVbGsfF is tagged as UNK and the this arg_max_y e(http://t.cn/RVbGsfF|y) is I-negative
# http://t.cn/RVbGsfF I-negative
#
# new sentence
# 自体 is tagged as UNK and the this arg_max_y e(自体|y) is I-negative
# 自体 I-negative
#
# 脂肪 B-neutral
#
# 全脸 is tagged as UNK and the this arg_max_y e(全脸|y) is I-negative
# 全脸 I-negative
#
# 填充 O
#
# 充 is tagged as UNK and the this arg_max_y e(充|y) is I-negative
# 充 I-negative
#
# Wendy B-neutral
#
# 会 O
#
# 根据 O
#
# 每个 B-negative
#
# 宝宝 I-positive
#
# 不同 O
#
# 凹陷 is tagged as UNK and the this arg_max_y e(凹陷|y) is I-negative
# 凹陷 I-negative
#
# 程度 O
#
# 进行 O
#
# 设计 O
#
# 术 I-positive
#
# 前 I-positive
#
# 可以 O
# 和 O
#
# Wendy B-neutral
#
# 沟通 O
#
# 自己 B-negative
#
# 喜欢 O
#
# 的 I-negative
#
# 风格 I-neutral
#
# 格 O
#
# 美美 O
#
# 哒 O
#
# 哒 O
#
# new sentence
# 【 O
#
# 19 I-neutral
#
# 万 O
#
# 中国 B-negative
#
# Note I-neutral
#
# 7 I-neutral
#
# 用户 O
#
# 请 O
#
# 关机 O
#
# 三星 B-neutral
#
# 全球 I-positive
#
# 停售 is tagged as UNK and the this arg_max_y e(停售|y) is I-negative
# 停售 I-negative
#
# Note I-neutral
#
# 7 I-neutral
#
# 】 O
#
# 最 O
#
# 短命 is tagged as UNK and the this arg_max_y e(短命|y) is I-negative
# 短命 I-negative
#
# 的 I-negative
#
# 机皇 is tagged as UNK and the this arg_max_y e(机皇|y) is I-negative
# 机皇 I-negative
#
# Galaxy B-neutral
#
# Note I-neutral
#
# 7 I-neutral
#
# ， O
#
# 成为 O
#
# 三星 B-neutral
#
# 手机 B-neutral
#
# 帝国 O
#
# 的 I-negative
#
# “ O
#
# 滑铁卢 is tagged as UNK and the this arg_max_y e(滑铁卢|y) is I-negative
# 滑铁卢 I-negative
#
# ” O
#
# 。 O
#
# http://t.cn/RVqokOH is tagged as UNK and the this arg_max_y e(http://t.cn/RVqokOH|y) is I-negative
# http://t.cn/RVqokOH I-negative
#
# new sentence
# 我 B-negative
#
# 参与 O
#
# 了 O
#
# @ B-positive
#
# 太原 is tagged as UNK and the this arg_max_y e(太原|y) is I-negative
# 太原 I-negative
#
# 同城会 is tagged as UNK and the this arg_max_y e(同城会|y) is I-negative
# 同城会 I-negative
#
# 发起 O
#
# 的 I-negative
#
# 投票 O
#
# 【 O
#
# 卖萌 O
#
# 日 O
#
# 你 B-negative
#
# 想 O
#
# 表白 O
#
# 哪位 O
#
# 男神 I-positive
#
# ？ O
#
# 】 O
#
# ， O
#
# 我 B-negative
#
# 投给 O
#
# 了 O
#
# “ O
#
# 朴灿烈 is tagged as UNK and the this arg_max_y e(朴灿烈|y) is I-negative
# 朴灿烈 I-negative
#
# ” O
#
# 这个 I-negative
#
# 选项 O
#
# 。 O
#
# 你 B-negative
#
# 也 O
#
# 快 O
#
# 来 B-negative
#
# 表态 O
#
# 吧 O
#
# ~ I-positive
#
# http://t.cn/RVUl65x is tagged as UNK and the this arg_max_y e(http://t.cn/RVUl65x|y) is I-negative
# http://t.cn/RVUl65x I-negative
#
# new sentence
# # B-positive
#
# 全世界 I-neutral
#
# 最好 I-neutral
#
# 的 I-negative
#
# 金钟 B-positive
#
# 仁 I-positive
#
# # B-positive
#
# . O
#
# # B-positive
#
# 金钟 B-positive
#
# 仁 I-positive
#
# 美颜 is tagged as UNK and the this arg_max_y e(美颜|y) is I-negative
# 美颜 I-negative
#
# 暴击 is tagged as UNK and the this arg_max_y e(暴击|y) is I-negative
# 暴击 I-negative
#
# # B-positive
#
# . O
#
# 好久不见 B-neutral
#
# … O
#
# 晚安 O
#
# 安 B-neutral
#
# new sentence
# # B-positive
#
# 阴阳师 I-positive
#
# 手游 I-positive
#
# # B-positive
#
# 我 B-negative
#
# 爱 I-positive
#
# 画符 B-positive
#
# ， O
#
# 召唤 O
#
# 有毒 O
#
# ！ O
#
# 使出 O
#
# 了 O
#
# 浑身 O
#
# 力气 O
#
# 召唤 O
#
# 出 O
#
# 了 O
#
# 傀儡 O
#
# 师 O
#
# ！ O
#
# 吾辈 O
#
# … O
#
# … O
#
# 好像 O
#
# 偷渡 O
#
# 成功 O
#
# 了 O
#
# ʅ O
#
# （ I-neutral
#
# ´ O
#
# ◔ O
#
# ౪ O
#
# ◔ O
#
# ） O
#
# ʃ O
#
# http://t.cn/RcSYU1q这个号真是⋯⋯抽sr神号 is tagged as UNK and the this arg_max_y e(http://t.cn/RcSYU1q这个号真是⋯⋯抽sr神号|y) is I-negative
# http://t.cn/RcSYU1q这个号真是⋯⋯抽sr神号 I-negative
#
# new sentence
# # B-positive
#
# 赵丽颖 B-positive
#
# 记忆 I-neutral
#
# 被 O
#
# 掏空 O
#
# # B-positive
#
# 又 O
#
# 是 O
#
# 一部 O
#
# 好 B-negative
#
# 赵丽颖 B-positive
#
# 呀 O
#
# ， O
#
# 真 O
#
# 期待 O
#
# ， O
#
# 大爱大爱 is tagged as UNK and the this arg_max_y e(大爱大爱|y) is I-negative
# 大爱大爱 I-negative
#
# 呀 O
#
# 。 O
#
# [ O
#
# 围观 O
#
# ] O
#
# new sentence
# 缅甸 O
#
# 散 O
#
# 拼 O
#
# 18 O
#
# 包 I-positive
#
# ， O
#
# 只要 O
#
# 70 B-negative
#
#  O
#
# new sentence
# 假如 O
#
# 你 B-negative
#
# 记不住 is tagged as UNK and the this arg_max_y e(记不住|y) is I-negative
# 记不住 I-negative
#
# 你 B-negative
#
# 为了 O
#
# 爱情 I-neutral
#
# 而 O
#
# 做 O
#
# 出来 O
#
# 的 I-negative
#
# 一件 O
#
# 最 O
#
# 傻 O
#
# 的 I-negative
#
# 是 O
#
# ， O
#
# 你 B-negative
#
# 就 O
#
# 不算 O
#
# 真正 I-neutral
#
# 恋爱 O
#
# 过 O
#
# ； O
#
# 假如 O
#
# 你 B-negative
#
# 不曾 is tagged as UNK and the this arg_max_y e(不曾|y) is I-negative
# 不曾 I-negative
#
# 絮絮 is tagged as UNK and the this arg_max_y e(絮絮|y) is I-negative
# 絮絮 I-negative
#
# 地 I-negative
#
# 讲 O
#
# 你 B-negative
#
# 恋人 is tagged as UNK and the this arg_max_y e(恋人|y) is I-negative
# 恋人 I-negative
#
# 的 I-negative
#
# 好处 O
#
# ， O
#
# 使 O
#
# 听 O
#
# 的 I-negative
#
# 人 I-negative
#
# 不耐烦 is tagged as UNK and the this arg_max_y e(不耐烦|y) is I-negative
# 不耐烦 I-negative
#
# ， O
#
# 你 B-negative
#
# 就 O
#
# 不算 O
#
# 真正 I-neutral
#
# 恋爱 O
#
# 过 O
#
# 。 O
#
# — O
#
# — O
#
# — O
#
# 罗兰 is tagged as UNK and the this arg_max_y e(罗兰|y) is I-negative
# 罗兰 I-negative
#
# new sentence
# 80 O
#
# 分钟 I-neutral
#
# 艰难 O
#
# 取胜 is tagged as UNK and the this arg_max_y e(取胜|y) is I-negative
# 取胜 I-negative
#
# ， O
#
# LOL B-neutral
#
# 你 B-negative
#
# 玩 O
#
# 过 O
#
# 最长 O
#
# 的 I-negative
#
# 一局 O
#
# 是 O
#
# 多少 O
#
# ？ O
#
# （ I-neutral
#
# 来自 O
#
# @ B-positive
#
# 看荐 is tagged as UNK and the this arg_max_y e(看荐|y) is I-negative
# 看荐 I-negative
#
# ） O
#
# # B-positive
#
# 神奇 I-positive
#
# 动物 I-positive
#
# 在 O
#
# 哪里 I-positive
#
# # B-positive
#
# http://t.cn/RVb0SCd is tagged as UNK and the this arg_max_y e(http://t.cn/RVb0SCd|y) is I-negative
# http://t.cn/RVb0SCd I-negative
#
# new sentence
# 这么 O
#
# 多年 O
#
# 后 O
#
# 的 I-negative
#
# 一瞬间 O
#
# ， O
#
# 泪水 O
#
# 猛然间 is tagged as UNK and the this arg_max_y e(猛然间|y) is I-negative
# 猛然间 I-negative
#
# 涌出 is tagged as UNK and the this arg_max_y e(涌出|y) is I-negative
# 涌出 I-negative
#
# 了 O
#
# 眼眶 is tagged as UNK and the this arg_max_y e(眼眶|y) is I-negative
# 眼眶 I-negative
#
# 。 O
#
# 分享 O
#
# 单曲 O
#
# http://t.cn/RVb0YS2 is tagged as UNK and the this arg_max_y e(http://t.cn/RVb0YS2|y) is I-negative
# http://t.cn/RVb0YS2 I-negative
#
# （ I-neutral
#
# @ B-positive
#
# 网易 I-neutral
#
# 云 I-neutral
#
# 音乐 I-neutral
#
# ） O
#
# new sentence
# # B-positive
#
# 偶滴 B-positive
#
# 歌神 I-positive
#
# 啊 I-positive
#
# # B-positive
#
# 信 B-positive
#
# 单枪匹马 O
#
# 的 I-negative
#
# 来 B-negative
#
# 了 O
#
# 很 O
#
# 经典 I-positive
#
# 。 O
#
# new sentence
# # B-positive
#
# 青云 I-positive
#
# 志 I-positive
#
# # B-positive
#
# 特别 O
#
# 喜欢 O
#
# 这部 O
#
# 剧 O
#
# 故事情节 is tagged as UNK and the this arg_max_y e(故事情节|y) is I-negative
# 故事情节 I-negative
#
# 非常 O
#
# 看得 O
#
# 很 O
#
# 过瘾 O
#
# 我 B-negative
#
# 一直 O
#
# 在 O
#
# 追 O
#
# 着 O
#
# 这部 O
#
# 电视剧 O
#
# 。 O
#
# new sentence
# 有 O
#
# 的 I-negative
#
# 女人 B-neutral
#
# 恋爱 O
#
# 时 O
#
# 让 O
#
# 男人 B-neutral
#
# 宠着 is tagged as UNK and the this arg_max_y e(宠着|y) is I-negative
# 宠着 I-negative
#
# 自己 B-negative
#
# ， O
#
# 结婚 B-negative
#
# 后 O
#
# 仍然 O
#
# 要 O
#
# 老公 B-positive
#
# 百般 O
#
# 宠着 is tagged as UNK and the this arg_max_y e(宠着|y) is I-negative
# 宠着 I-negative
#
# 自己 B-negative
#
# ， O
#
# 却 O
#
# 忘记 O
#
# 做 O
#
# 为 O
#
# 一个 B-negative
#
# 女人 B-neutral
#
# 应该 O
#
# 做 O
#
# 的 I-negative
#
# 份 O
#
# 内 O
#
# 之事 is tagged as UNK and the this arg_max_y e(之事|y) is I-negative
# 之事 I-negative
#
# 。 O
#
# 这样 O
#
# 的 I-negative
#
# 女人 B-neutral
#
# 不 I-negative
#
# 懂得 O
#
# 爱情 I-neutral
#
# 。 O
#
# new sentence
# 瑞士 B-positive
#
# ， O
#
# 徒步 O
#
# 爱好者 O
#
# 的 I-negative
#
# 天堂 O
#
# 。 O
#
# by O
#
# 鸢尾 B-neutral
#
# new sentence
# 最近 O
#
# 在 O
#
# # B-positive
#
# 抱抱 I-negative
#
# # B-positive
#
# 玩 O
#
# 直播 I-negative
#
# ， O
#
# 太 O
#
# 好玩 O
#
# 了 O
#
# ， O
#
# 美女 I-positive
#
# 帅哥 O
#
# 大把大把 O
#
# ， O
#
# 看 O
#
# 土豪 I-negative
#
# 刷 I-neutral
#
# 飞机 O
#
# 跑车 I-neutral
#
# 也 O
#
# 是 O
#
# 醉 O
#
# 了 O
#
# ， O
#
# 你 B-negative
#
# 来 B-negative
#
# 给 O
#
# 我 B-negative
#
# 刷 I-neutral
#
# 辆车 O
#
# 呗 I-neutral
#
# ， O
#
# 下载 O
#
# ： O
#
# http://t.cn/8srPTXk O
#
# new sentence
# 【 O
#
# 红衣主教 is tagged as UNK and the this arg_max_y e(红衣主教|y) is I-negative
# 红衣主教 I-negative
#
# ： O
#
# 亚历山大 is tagged as UNK and the this arg_max_y e(亚历山大|y) is I-negative
# 亚历山大 I-negative
#
# 的 I-negative
#
# 传说 I-positive
#
# 】 O
#
# 游戏 I-negative
#
# 包含 O
#
# 了 O
#
# 多种 O
#
# 经典 I-positive
#
# 的 I-negative
#
# RPG is tagged as UNK and the this arg_max_y e(RPG|y) is I-negative
# RPG I-negative
#
# 元素 O
#
# , O
#
# 例如 O
#
# 《 B-positive
#
# 最终幻想 is tagged as UNK and the this arg_max_y e(最终幻想|y) is I-negative
# 最终幻想 I-negative
#
# 》 I-negative
#
# 、 O
#
# 《 B-positive
#
# 王国 B-neutral
#
# 之心 is tagged as UNK and the this arg_max_y e(之心|y) is I-negative
# 之心 I-negative
#
# 》 I-negative
#
# 和 O
#
# 《 B-positive
#
# 塞尔达 is tagged as UNK and the this arg_max_y e(塞尔达|y) is I-negative
# 塞尔达 I-negative
#
# 》 I-negative
#
# 等等 O
#
# 。 O
#
# 并 O
#
# 将 O
#
# 各种 O
#
# 游戏 I-negative
#
# 的 I-negative
#
# 规则 is tagged as UNK and the this arg_max_y e(规则|y) is I-negative
# 规则 I-negative
#
# 和 O
#
# 模式 is tagged as UNK and the this arg_max_y e(模式|y) is I-negative
# 模式 I-negative
#
# 融合 O
#
# 其中 O
#
# ， O
#
# 而 O
#
# 目前 O
#
# 已经 O
#
# 得知 is tagged as UNK and the this arg_max_y e(得知|y) is I-negative
# 得知 I-negative
#
# 的 I-negative
#
# 两大 is tagged as UNK and the this arg_max_y e(两大|y) is I-negative
# 两大 I-negative
#
# 特色 O
#
# 系统 I-positive
#
# 模式 is tagged as UNK and the this arg_max_y e(模式|y) is I-negative
# 模式 I-negative
#
# 为 O
#
# 自定义 is tagged as UNK and the this arg_max_y e(自定义|y) is I-negative
# 自定义 I-negative
#
# 装备 O
#
# 系统 I-positive
#
# 和 O
#
# 卡牌 O
#
# [ O
#
# 鼓掌 O
#
# ] O
#
# 模式 is tagged as UNK and the this arg_max_y e(模式|y) is I-negative
# 模式 I-negative
#
# 。 O
#
# new sentence
# 【 O
#
# 妙香山 is tagged as UNK and the this arg_max_y e(妙香山|y) is I-negative
# 妙香山 I-negative
#
# 】 O
#
# 妙香山 is tagged as UNK and the this arg_max_y e(妙香山|y) is I-negative
# 妙香山 I-negative
#
# 与 O
#
# 金刚山 is tagged as UNK and the this arg_max_y e(金刚山|y) is I-negative
# 金刚山 I-negative
#
# 齐名 is tagged as UNK and the this arg_max_y e(齐名|y) is I-negative
# 齐名 I-negative
#
# ， O
#
# 山势 O
#
# 奇妙 O
#
# ， O
#
# 景致 O
#
# 佳绝 is tagged as UNK and the this arg_max_y e(佳绝|y) is I-negative
# 佳绝 I-negative
#
# ， O
#
# 尤其 O
#
# 以上 O
#
# 元洞 is tagged as UNK and the this arg_max_y e(元洞|y) is I-negative
# 元洞 I-negative
#
# 、 O
#
# 万 O
#
# 瀑洞 is tagged as UNK and the this arg_max_y e(瀑洞|y) is I-negative
# 瀑洞 I-negative
#
# 、 O
#
# 毗卢峰 is tagged as UNK and the this arg_max_y e(毗卢峰|y) is I-negative
# 毗卢峰 I-negative
#
# 的 I-negative
#
# 景色 O
#
# 为 O
#
# 最佳 O
#
# ， O
#
# 是 O
#
# 登山 is tagged as UNK and the this arg_max_y e(登山|y) is I-negative
# 登山 I-negative
#
# 的 I-negative
#
# 好去处 is tagged as UNK and the this arg_max_y e(好去处|y) is I-negative
# 好去处 I-negative
#
# 。 O
#
# 这里 O
#
# 有 O
#
# 700 O
#
# 种 O
#
# 植物 I-neutral
#
# ， O
#
# 33 I-positive
#
# 种 O
#
# 走兽 is tagged as UNK and the this arg_max_y e(走兽|y) is I-negative
# 走兽 I-negative
#
# ， O
#
# 115 B-neutral
#
# 种 O
#
# 禽鸟 is tagged as UNK and the this arg_max_y e(禽鸟|y) is I-negative
# 禽鸟 I-negative
#
# ， O
#
# 20 O
#
# 多种 O
#
# 鱼类 is tagged as UNK and the this arg_max_y e(鱼类|y) is I-negative
# 鱼类 I-negative
#
# 。 O
#
# 妙香山 is tagged as UNK and the this arg_max_y e(妙香山|y) is I-negative
# 妙香山 I-negative
#
# 文物 is tagged as UNK and the this arg_max_y e(文物|y) is I-negative
# 文物 I-negative
#
# 荟萃 is tagged as UNK and the this arg_max_y e(荟萃|y) is I-negative
# 荟萃 I-negative
#
# ， O
#
# 由 O
#
# 公园 I-positive
#
# 11 O
#
# 世纪 O
#
# 修建 I-neutral
#
# 的 I-negative
#
# 普贤 is tagged as UNK and the this arg_max_y e(普贤|y) is I-negative
# 普贤 I-negative
#
# 寺 I-neutral
#
# 、 O
#
# 石塔 is tagged as UNK and the this arg_max_y e(石塔|y) is I-negative
# 石塔 I-negative
#
# 等 O
#
# 古迹 is tagged as UNK and the this arg_max_y e(古迹|y) is I-negative
# 古迹 I-negative
#
# 和 O
#
# 显示 O
#
# 印刷技术 is tagged as UNK and the this arg_max_y e(印刷技术|y) is I-negative
# 印刷技术 I-negative
#
# 发展 I-neutral
#
# 水平 O
#
# 的 I-negative
#
# 文物古迹 is tagged as UNK and the this arg_max_y e(文物古迹|y) is I-negative
# 文物古迹 I-negative
#
# 。 O
#
# new sentence
# @ B-positive
#
# 黄致列 is tagged as UNK and the this arg_max_y e(黄致列|y) is I-negative
# 黄致列 I-negative
#
# HCY is tagged as UNK and the this arg_max_y e(HCY|y) is I-negative
# HCY I-negative
#
# 我 B-negative
#
# 在 O
#
# # B-positive
#
# 明星 I-neutral
#
# 势力 I-neutral
#
# 榜 I-neutral
#
# # B-positive
#
# 上 O
#
# 为 O
#
# 你 B-negative
#
# 加油 O
#
# 啦 O
#
# ， O
#
# 你 B-negative
#
# 是 O
#
# 我 B-negative
#
# 今生 O
#
# 唯一 I-positive
#
# 的 I-negative
#
# 执著 O
#
# 哦 O
#
# 。 O
#
# 棒棒 O
#
# 哒 O
#
# ！ O
#
# http://t.cn/R4TYsHh is tagged as UNK and the this arg_max_y e(http://t.cn/R4TYsHh|y) is I-negative
# http://t.cn/R4TYsHh I-negative
#
# new sentence
# 我 B-negative
#
# 恨 O
#
# 秦始皇 is tagged as UNK and the this arg_max_y e(秦始皇|y) is I-negative
# 秦始皇 I-negative
#
# 。 O
#
# 他 B-negative
#
# 烧书 is tagged as UNK and the this arg_max_y e(烧书|y) is I-negative
# 烧书 I-negative
#
# 。 O
#
# 居然 O
#
# 没有 O
#
# 烧 B-neutral
#
# 完 I-positive
#
# 。 O
#
# new sentence
# 哈哈哈 O
#
# .. O
#
# 未來 O
#
# 的 I-negative
#
# 選擇 O
#
# 好像 O
#
# yahoo B-neutral
#
# 的 I-negative
#
# 新聞 O
#
# 都 O
#
# 沒 O
#
# 啥 O
#
# 在 O
#
# 報 O
#
# ... O
#
# 難怪 O
#
# 不 I-negative
#
# 夯 O
# ... O
#
# new sentence
# 就 O
#
# 想 O
#
# 今天 O
#
# 跑 O
#
# 个步 is tagged as UNK and the this arg_max_y e(个步|y) is I-negative
# 个步 I-negative
#
# [ O
#
# 加油 O
#
# ] O
#
# 下雨 O
#
# 了 O
#
# [ O
#
# 沙尘暴 O
#
# ] O
#
# （ I-neutral
#
# 好 B-negative
#
# 吧 O
#
# 每次 O
#
# 都 O
#
# 会 O
#
# 给 O
#
# 我 B-negative
#
# 一个 B-negative
#
# 很棒 O
#
# 的 I-negative
#
# 理由 I-neutral
#
# [ O
#
# 白眼 O
#
# ] O
#
# ） O
#
# 我 B-negative
#
# 洁哥 is tagged as UNK and the this arg_max_y e(洁哥|y) is I-negative
# 洁哥 I-negative
#
# 去 I-negative
#
# 约会 O
#
# 了 O
#
# 我 B-negative
#
# 在 O
#
# 宿舍 I-neutral
#
# 想 O
#
# 市友 is tagged as UNK and the this arg_max_y e(市友|y) is I-negative
# 市友 I-negative
#
# 。 O
#
# http://t.cn/RZ2fkYd is tagged as UNK and the this arg_max_y e(http://t.cn/RZ2fkYd|y) is I-negative
# http://t.cn/RZ2fkYd I-negative
#
# new sentence
# # B-positive
#
# 赵丽颖 B-positive
#
# 提名 O
#
# 金鹰 I-neutral
#
# 视后 is tagged as UNK and the this arg_max_y e(视后|y) is I-negative
# 视后 I-negative
#
# # B-positive
#
# 唯一 I-positive
#
# 能 O
#
# 做 O
#
# 的 I-negative
#
# 就是 O
#
# 努力 O
#
# 投票 O
#
# @ B-positive
#
# 赵丽颖 B-positive
#
# # B-positive
#
# 赵丽颖 B-positive
#
# # B-positive
#
# new sentence
# 天蝎 B-neutral
#
# 渴望 B-neutral
#
# 理解 is tagged as UNK and the this arg_max_y e(理解|y) is I-negative
# 理解 I-negative
#
# ， O
#
# 却 O
#
# 不 I-negative
#
# 奢求 is tagged as UNK and the this arg_max_y e(奢求|y) is I-negative
# 奢求 I-negative
#
# 理解 is tagged as UNK and the this arg_max_y e(理解|y) is I-negative
# 理解 I-negative
#
# ， O
#
# 安于 O
#
# 孤独 O
#
# ， O
#
# 更能 O
#
# 乐于 is tagged as UNK and the this arg_max_y e(乐于|y) is I-negative
# 乐于 I-negative
#
# 孤独 O
#
# 。 O
#
# 天蝎 B-neutral
#
# 的 I-negative
#
# 优势 O
#
# 在于 O
#
# ， O
#
# 对于 O
#
# 别有用心 is tagged as UNK and the this arg_max_y e(别有用心|y) is I-negative
# 别有用心 I-negative
#
# 的 I-negative
#
# 人 I-negative
#
# ， O
#
# 能够 O
#
# ...
# 火线 I-negative
#
# 回归 O
#
# 队长 is tagged as UNK and the this arg_max_y e(队长|y) is I-negative
# 队长 I-negative
#
# 带伤 is tagged as UNK and the this arg_max_y e(带伤|y) is I-negative
# 带伤 I-negative
#
# 登场 is tagged as UNK and the this arg_max_y e(登场|y) is I-negative
# 登场 I-negative
#
# 存 is tagged as UNK and the this arg_max_y e(存|y) is I-negative
# 存 I-negative
#
# 变数 is tagged as UNK and the this arg_max_y e(变数|y) is I-negative
# 变数 I-negative
#
# 】 O
#
# 10 I-negative
#
# 月 I-negative
#
# 10 I-negative
#
# 日 O
#
# 下午 O
#
# ， O
#
# 亚足联 is tagged as UNK and the this arg_max_y e(亚足联|y) is I-negative
# 亚足联 I-negative
#
# 公布 O
#
# 了 O
#
# 乌兹别克斯坦 B-neutral
#
# 主场 O
#
# 与 O
#
# 中国队 is tagged as UNK and the this arg_max_y e(中国队|y) is I-negative
# 中国队 I-negative
#
# 的 I-negative
#
# 23 O
#
# 人大 is tagged as UNK and the this arg_max_y e(人大|y) is I-negative
# 人大 I-negative
#
# 名单 O
#
# 。 O
#
# 效力 O
#
# 于 B-neutral
#
# 长春亚泰 is tagged as UNK and the this arg_max_y e(长春亚泰|y) is I-negative
# 长春亚泰 I-negative
#
# 的 I-negative
#
# 中卫 is tagged as UNK and the this arg_max_y e(中卫|y) is I-negative
# 中卫 I-negative
#
# 伊斯梅 is tagged as UNK and the this arg_max_y e(伊斯梅|y) is I-negative
# 伊斯梅 I-negative
#
# 洛夫 is tagged as UNK and the this arg_max_y e(洛夫|y) is I-negative
# 洛夫 I-negative
#
# 以及 O
#
# 老将 is tagged as UNK and the this arg_max_y e(老将|y) is I-negative
# 老将 I-negative
#
# 海因里希 is tagged as UNK and the this arg_max_y e(海因里希|y) is I-negative
# 海因里希 I-negative
#
# 停赛 is tagged as UNK and the this arg_max_y e(停赛|y) is I-negative
# 停赛 I-negative
#
# ， O
#
# 库蒂 is tagged as UNK and the this arg_max_y e(库蒂|y) is I-negative
# 库蒂 I-negative
#
# 巴耶夫 is tagged as UNK and the this arg_max_y e(巴耶夫|y) is I-negative
# 巴耶夫 I-negative
#
# 、 O
#
# 哈姆 is tagged as UNK and the this arg_max_y e(哈姆|y) is I-negative
# 哈姆 I-negative
#
# 达莫夫 is tagged as UNK and the this arg_max_y e(达莫夫|y) is I-negative
# 达莫夫 I-negative
#
# 入替 is tagged as UNK and the this arg_max_y e(入替|y) is I-negative
# 入替 I-negative
#
# 。 O
#
# http://t.cn/RV4VykA is tagged as UNK and the this arg_max_y e(http://t.cn/RV4VykA|y) is I-negative
# http://t.cn/RV4VykA I-negative
#
# new sentence
# 这 O
#
# 是 O
#
# 在 O
#
# 故宫 is tagged as UNK and the this arg_max_y e(故宫|y) is I-negative
# 故宫 I-negative
#
# 吗 I-neutral
#
# ？ O
#
# 明天 O
#
# 会 O
#
# 在 O
#
# 哪儿 I-negative
#
# 宣传 O
#
# new sentence
# 奥克斯 is tagged as UNK and the this arg_max_y e(奥克斯|y) is I-negative
# 奥克斯 I-negative
#
# 烘 is tagged as UNK and the this arg_max_y e(烘|y) is I-negative
# 烘 I-negative
#
# 鞋器 is tagged as UNK and the this arg_max_y e(鞋器|y) is I-negative
# 鞋器 I-negative
#
# 干 I-positive
#
# 鞋器 is tagged as UNK and the this arg_max_y e(鞋器|y) is I-negative
# 鞋器 I-negative
#
# ￥ O
#
# 9.9 O
#
# new sentence
# 《 B-positive
#
# 湄公河 B-positive
#
# 行动 I-positive
#
# 》 I-negative
#
# 哮天 is tagged as UNK and the this arg_max_y e(哮天|y) is I-negative
# 哮天 I-negative
#
# 死 O
#
# 了 O
#
# ， O
#
# 伤心 O
#
# [ O
#
# 泪 I-positive
#
# ] O
#
# new sentence
# 今天 O
#
# 我 B-negative
#
# 在 O
#
# # B-positive
#
# 百词 I-neutral
#
# 斩 I-neutral
#
# # B-positive
#
# 背 I-neutral
#
# 了 O
#
# 58 B-neutral
#
# 个 O
#
# 四级 O
#
# 词汇 O
#
# 单词 O
#
# ， O
#
# 我 B-negative
#
# 已经 O
#
# 在 O
#
# 百词 I-neutral
#
# 斩 I-neutral
#
# 坚持 O
#
# 了 O
#
# 5 I-neutral
#
# 天 I-neutral
#
# 。 O
#
# 你 B-negative
#
# 也 O
#
# 来 B-negative
#
# 背单词 O
#
# 吧 O
#
# > O
#
# > O
#
# > O
#
# http://t.cn/R4frbda O
#
# # B-positive
#
# 7 I-neutral
#
# 天 I-neutral
#
# 养成 O
#
# 一个 B-negative
#
# 好 B-negative
#
# 习惯 O
#
# # B-positive
#
# new sentence
# 章鱼 B-positive
#
# 保罗 B-neutral
#
# 附体 O
#
# ， O
#
# 我 B-negative
#
# 有 O
#
# 强烈 O
#
# 预感 O
#
# 门兴格 B-positive
#
# 拉 I-positive
#
# 德巴赫 I-positive
#
# 和 O
#
# 汉堡 I-positive
#
# 的 I-negative
#
# 比赛结果 O
#
# 是 O
#
# 门兴格 B-positive
#
# 拉 I-positive
#
# 德巴赫 I-positive
#
# 胜 O
#
# ！ O
#
# 来 B-negative
#
# # B-positive
#
# 最佳阵容 O
#
# # B-positive
#
# 游戏 I-negative
#
# 跟进 O
#
# 我 B-negative
#
# 的 I-negative
#
# 竞猜 O
#
# ， O
#
# 猜 O
#
# 对 O
#
# 赚 O
#
# 钻石 B-neutral
#
# 喽 O
#
# ！ O
#
# 下载 O
#
# 链接 O
#
# ： O
#
# http://t.cn/Rz5lIRS O
#
# new sentence
# 相信 B-positive
#
# 桔子 B-positive
#
# 的 I-negative
#
# 眼光 O
#
# ， O
#
# 跟着 O
#
# 桔子 B-positive
#
# 看 O
#
# 了 O
#
# 几部 O
#
# 不错 O
#
# 的 I-negative
#
# 电影 I-positive
#
# 了 O
#
# 。 O
#
# 智取 B-positive
#
# 威虎山 I-positive
#
# 很 O
#
# 好看 O
#
# 啊 I-positive
#
# 。 O
#
# new sentence
# 【 O
#
# 云 I-neutral
#
# 龙湾 I-positive
#
# 】 O
#
# 山 I-neutral
#
# 那边 O
#
# 是 O
#
# 海 B-neutral
#
# ， O
#
# 海 B-neutral
#
# 那边 O
#
# 是 O
#
# 山 I-neutral
#
# 。 O
#
# 山是 O
#
# 铜鼓 B-neutral
#
# 岭 I-neutral
#
# ， O
#
# 海是 O
#
# 云 I-neutral
#
# 龙湾 I-positive
#
# 。 O
#
# 山与海 O
#
# 相依相偎 O
#
# ， O
#
# 相互 O
#
# 映衬 O
#
# ， O
#
# 构成 O
#
# 了 O
#
# 奇特 O
#
# 壮美 O
#
# 的 I-negative
#
# 自然景观 O
#
# 与 O
#
# 人间 O
#
# 胜迹 O
#
# 。 O
#
# 岭南 O
#
# ， O
#
# 一碧万顷 O
#
# ， O
#
# 海天 O
#
# 无际 O
#
# ， O
#
# 涛声 O
#
# 不 I-negative
#
# 绝 O
#
# ， O
#
# 浪花 O
#
# 腾雪 O
#
# ， O
#
# 那 O
#
# 湛蓝 O
#
# 澄碧 O
#
# 的 I-negative
#
# 海水 O
#
# ， O
#
# 让 O
#
# 人 I-negative
#
# 一 I-positive
#
# 看 O
#
# 就 O
#
# 想 O
#
# 跳下去 O
#
# 洗个 O
#
# 痛快 O
#
# ， O
#
# 这 O
#
# 就是 O
#
# 云 I-neutral
#
# 龙湾 I-positive
#
# 。 O
#
# new sentence
# 人生 I-positive
#
# 犹如 O
#
# 一 I-positive
#
# 本书 O
#
# [ O
#
# 可怜 O
#
# ] O
#
# 愚蠢 O
#
# 者 I-neutral
#
# 草草 O
#
# 翻过 O
#
# [ O
#
# 可怜 O
#
# ] O
#
# 聪 O
#
# - I-neutral
#
# 麷 O
#
# 齺 O
#
# * O
#
# 明人 O
#
# 细细 O
#
# 阅读 O
#
# 。 O
#
# 为何 O
#
# 如此 O
#
# . O
#
# 因为 O
#
# 他们 B-positive
#
# 只能 O
#
# 读 O
#
# 它 B-negative
#
# 一次 O
#
# 。 O
#
# — O
#
# — O
#
# 保罗 B-neutral
#
# new sentence
# 生日快乐 O
#
# 婷婷 is tagged as UNK and the this arg_max_y e(婷婷|y) is I-negative
# 婷婷 I-negative
#
# 大 I-positive
#
# 宝贝 B-positive
#
# [ O
#
# 蛋糕 I-negative
#
# ] O
#
# new sentence
# 【 O
#
# 奔驰 B-neutral
#
# 新一代 I-neutral
#
# S B-negative
#
# 级 I-positive
#
# 】 O
#
# 梅赛德斯 B-neutral
#
# - I-neutral
#
# 奔驰 B-neutral
#
# 将 O
#
# 基于 O
#
# 全新 I-positive
#
# 一代 I-neutral
#
# S B-negative
#
# 级 I-positive
#
# 轿车 I-positive
#
# ， O
#
# 从而 O
#
# 打造出 O
#
# 敞篷 B-neutral
#
# 轿 I-neutral
#
# 跑车 I-neutral
#
# ， O
#
# 并且 O
#
# 提供 O
#
# 三套 O
#
# 动力 I-positive
#
# 配置 O
#
# 。 O
#
# 作为 O
#
# 以 O
#
# 新一代 I-neutral
#
# S B-negative
#
# 级 I-positive
#
# 而 O
#
# 打造 O
#
# 的 I-negative
#
# 衍生 O
#
# 版 I-positive
#
# 车型 I-positive
#
# ， O
#
# 全新 I-positive
#
# 梅赛德斯 B-neutral
#
# - I-neutral
#
# 奔驰 B-neutral
#
# S B-negative
#
# 级 I-positive
#
# 敞篷车 I-positive
#
# 将 O
#
# 在 O
#
# 多方面 O
#
# 进行 O
#
# 升级 O
#
# 强化 O
#
# ， O
#
# 而 O
#
# 这 O
#
# 均 O
#
# 源自 O
#
# 于 B-neutral
#
# 全新 I-positive
#
# 平台 I-positive
#
# 的 I-negative
#
# 技术 I-neutral
#
# 优势 O
#
# 。 O
#
# new sentence
# 轩轩 B-positive
#
# 与 O
#
# 安然 B-positive
#
# 恋爱 O
#
# 第 I-neutral
#
# 260 O
#
# 天 I-neutral
#
# [ O
#
# 偷乐 O
#
# ] O
#
# ~ I-positive
#
# 咳咳 O
#
# 咳 O
#
# ~ I-positive
#
# 原谅 O
#
# 男主人 O
# 最近 O
#
# 确确实实 O
#
# 很 O
#
# 忙 O
#
# [ O
#
# 失望 O
#
# ] O
#
# ~ I-positive
#
# 忙 O
#
# 着 O
#
# 换届 O
#
# 各种 O
#
# 烦事 O
#
# [ O
#
# 哼 O
#
# ] O
#
# ~ I-positive
#
# 但 O
#
# 今天 O
#
# 已经 O
#
# 算是 O
#
# 彻彻底底 O
#
# 忙 O
#
# 完 I-positive
#
# 啦 O
#
# ~ I-positive
#
# 可以 O
#
# 好好 O
#
# 和 O
#
# 女主人 O
#
# 在 O
#
# 一起 O
#
# 啦 O
#
# ~ I-positive
#
# new sentence
# 之前 O
#
# 关注 O
#
# 了 O
#
# @ B-positive
#
# 羊毛 I-positive
#
# 仓 I-positive
#
# 2 I-positive
#
# 块 I-neutral
#
# 9 I-positive
#
# 给 O
#
# 男票 O
#
# 买 O
#
# 了 O
#
# 件 I-neutral
#
# 衣服 B-neutral
#
# ， O
#
# 又 O
#
# 省 O
#
# 了 O
#
# 不少 O
#
# [ O
#
# 喵 B-positive
#
# 喵 B-positive
#
# ] O
#
# [ O
#
# 威武 O
#
# ] O
#
# 不明真相 O
#
# 的 I-negative
#
# 他 B-negative
#
# 还 O
#
# 在 O
#
# 那 O
#
# 嘚 O
#
# 瑟 O
#
# 呢 O
#
# [ O
#
# 偷乐 O
#
# ] O
#
# 喜欢 O
#
# 的 I-negative
#
# 赶紧 O
#
# 关注 O
#
# @ B-positive
#
# 羊毛 I-positive
#
# 仓 I-positive
#
# 领券 O
#
# 吧 O
#
# 。 O
#
# new sentence
# [ O
#
# / O
#
# ] O
#
# 昨天 O
#
# 过 O
#
# 的 I-negative
#
# 那 O
#
# 是 O
#
# 相当 O
#
# 的 I-negative
#
# 充实 O
#
# ！ O
#
# 政治 O
#
# 老师 I-neutral
#
# 布置 is tagged as UNK and the this arg_max_y e(布置|y) is I-negative
# 布置 I-negative
#
# 了 O
#
# 两张 is tagged as UNK and the this arg_max_y e(两张|y) is I-negative
# 两张 I-negative
#
# 选择 O
#
# 三个 B-positive
#
# 大 I-positive
#
# 题 O
#
# 。 O
#
# 下午 O
#
# 数学 is tagged as UNK and the this arg_max_y e(数学|y) is I-negative
# 数学 I-negative
#
# 考了 is tagged as UNK and the this arg_max_y e(考了|y) is I-negative
# 考了 I-negative
#
# 两节课 is tagged as UNK and the this arg_max_y e(两节课|y) is I-negative
# 两节课 I-negative
#
# … O
#
# 考完 is tagged as UNK and the this arg_max_y e(考完|y) is I-negative
# 考完 I-negative
#
# 自习课 is tagged as UNK and the this arg_max_y e(自习课|y) is I-negative
# 自习课 I-negative
#
# 就 O
#
# 开始 O
#
# 写 O
#
# 海量 O
#
# 的 I-negative
#
# 政治 O
#
# 题 O
#
# 晚自习 O
#
# 要 O
#
# 讲 O
#
# … O
#
# 讲完 is tagged as UNK and the this arg_max_y e(讲完|y) is I-negative
# 讲完 I-negative
#
# 剩下 O
#
# 的 I-negative
#
# 半个 O
#
# 小时 O
#
# 她 B-negative
#
# 又 O
#
# 发 O
#
# 一张 B-positive
#
# 要 O
#
# 写 O
#
# … O
#
# 下 O
#
# 了 O
#
# 一晚 O
#
# 就 O
#
# 去 I-negative
#
# 上 O
#
# 数学 is tagged as UNK and the this arg_max_y e(数学|y) is I-negative
# 数学 I-negative
#
# 了 O
#
# 。 O
#
# 。 O
#
# 。 O
#
# 一大早 is tagged as UNK and the this arg_max_y e(一大早|y) is I-negative
# 一大早 I-negative
#
# 到 O
#
# 学校 I-positive
#
# 竟 O
#
# 得知 is tagged as UNK and the this arg_max_y e(得知|y) is I-negative
# 得知 I-negative
#
# 政治 O
#
# 老师 I-neutral
#
# 又 O
#
# 布置 is tagged as UNK and the this arg_max_y e(布置|y) is I-negative
# 布置 I-negative
#
# 一套 B-negative
#
# 选择题 is tagged as UNK and the this arg_max_y e(选择题|y) is I-negative
# 选择题 I-negative
#
# … O
#
# 早自习 O
#
# 没 O
#
# 背书 is tagged as UNK and the this arg_max_y e(背书|y) is I-negative
# 背书 I-negative
#
# 还要 O
#
# 防 O
#
# 着 O
#
# 老师 I-neutral
#
# 进 O
#
# 教室 B-neutral
#
# 溜达 is tagged as UNK and the this arg_max_y e(溜达|y) is I-negative
# 溜达 I-negative
#
# 战战兢兢 is tagged as UNK and the this arg_max_y e(战战兢兢|y) is I-negative
# 战战兢兢 I-negative
#
# 急 O
#
# new sentence
# 《 B-positive
#
# 法医 B-negative
#
# 秦明 I-negative
#
# 》 I-negative
#
# 一口气 O
#
# 看 O
#
# 了 O
#
# 6 I-neutral
#
# 集 O
#
# ， O
#
# 口味 O
#
# 相当 O
#
# 重 I-neutral
#
# ， O
#
# 尤其 O
#
# 是 O
#
# 第一集 is tagged as UNK and the this arg_max_y e(第一集|y) is I-negative
# 第一集 I-negative
#
# 炸 B-positive
#
# 尸体 O
#
# ， O
#
# 煮 O
#
# 尸体 O
#
# ， O
#
# 整张 is tagged as UNK and the this arg_max_y e(整张|y) is I-negative
# 整张 I-negative
#
# 人 I-negative
#
# 皮 O
#
# ， O
#
# 道具 is tagged as UNK and the this arg_max_y e(道具|y) is I-negative
# 道具 I-negative
#
# 非常 O
#
# 赞 O
#
# ， O
#
# 不 I-negative
#
# 过瘾 O
#
# ， O
#
# 一周 O
#
# 等 O
#
# 四集 O
#
# 的 I-negative
#
# 时候 O
#
# 又 O
#
# 到 O
#
# 了 O
#
# 。 O
#
# 虽然 O
#
# 是 O
#
# 原著 O
#
# 粉 O
#
# ， O
#
# 但 O
#
# 原著 O
#
# 并 O
#
# 没有 O
#
# 看 O
#
# 完呐 is tagged as UNK and the this arg_max_y e(完呐|y) is I-negative
# 完呐 I-negative
#
# [ O
#
# 拜拜 O
#
# ] O
#
# [ O
#
# 拜拜 O
#
# ] O
#
# 看到 O
#
# 一半 O
#
# 没有 O
#
# 的 I-negative
#
# 时候 O
#
# 好 B-negative
#
# 想 O
#
# 知道 O
#
# 凶手 O
#
# 是 O
#
# 谁 O
#
# 啊 I-positive
#
# ！ O
#
# 还有 O
#
# 主演 O
#
# 超级 O
#
# 棒 O
#
# 呐 O
#
# ， O
#
# 张若昀 B-negative
#
# ， O
#
# 焦俊艳 is tagged as UNK and the this arg_max_y e(焦俊艳|y) is I-negative
# 焦俊艳 I-negative
#
# ， O
#
# cp O
#
# 了 O
#
# 。 O
#
# 个人 B-neutral
#
# 认为 O
#
# 比 O
#
# 十宗 is tagged as UNK and the this arg_max_y e(十宗|y) is I-negative
# 十宗 I-negative
#
# 罪 I-neutral
#
# 拍 B-neutral
#
# 的 I-negative
#
# 好看 O
#
# 。 O
#
# @ B-positive
#
# 法医 B-negative
#
# 秦明 I-negative
#
# new sentence
# 【 O
#
# 牛皮 O
#
# 单肩 is tagged as UNK and the this arg_max_y e(单肩|y) is I-negative
# 单肩 I-negative
#
# 包女 is tagged as UNK and the this arg_max_y e(包女|y) is I-negative
# 包女 I-negative
#
# 斜挎包 is tagged as UNK and the this arg_max_y e(斜挎包|y) is I-negative
# 斜挎包 I-negative
#
# 新款 I-neutral
#
# 夏季 O
#
# 时尚 I-neutral
#
# 韩版 O
#
# 简约 O
#
# 】 O
#
# new sentence
# 话 O
#
# 卓姐 is tagged as UNK and the this arg_max_y e(卓姐|y) is I-negative
# 卓姐 I-negative
#
# 代购 I-neutral
#
# · I-neutral
#
# 少量 O
#
# 现货 O
#
# 秒 B-neutral
#
# 发发 is tagged as UNK and the this arg_max_y e(发发|y) is I-negative
# 发发 I-negative
#
# “ O
#
# 给 O
#
# 我 B-negative
#
# 三天 O
#
# ， O
#
# 我 B-negative
#
# 就 O
#
# 还 O
#
# 你 B-negative
#
# 奇迹 is tagged as UNK and the this arg_max_y e(奇迹|y) is I-negative
# 奇迹 I-negative
#
# ” O
#
# ‼ O
#
# ️ O
#
# ‼ O
#
# ️ O
#
# 这个 I-negative
#
# 是 O
#
# 后 O
#
# WHOO is tagged as UNK and the this arg_max_y e(WHOO|y) is I-negative
# WHOO I-negative
#
# 密贴 is tagged as UNK and the this arg_max_y e(密贴|y) is I-negative
# 密贴 I-negative
#
# 的 I-negative
#
# 广告语 is tagged as UNK and the this arg_max_y e(广告语|y) is I-negative
# 广告语 I-negative
#
# ， O
#
# 不是 O
#
# 广告 I-neutral
#
# 夸大 is tagged as UNK and the this arg_max_y e(夸大|y) is I-negative
# 夸大 I-negative
#
# ， O
#
# 而是 O
#
# 密贴 is tagged as UNK and the this arg_max_y e(密贴|y) is I-negative
# 密贴 I-negative
#
# 真的 O
#
# 好用 is tagged as UNK and the this arg_max_y e(好用|y) is I-negative
# 好用 I-negative
#
# ！ O
#
# 也 O
#
# 是 O
#
# 一直 O
#
# 热卖 O
#
# 的 I-negative
#
# 产品 B-neutral
#
# [ O
#
# 色 O
#
# ] O
#
# [ O
#
# 色 O
#
# ] O
#
# [ O
#
# 色 O
#
# ] O
#
# 韩国 B-neutral
#
# 后 O
#
# WHOO is tagged as UNK and the this arg_max_y e(WHOO|y) is I-negative
# WHOO I-negative
#
# 秘贴 is tagged as UNK and the this arg_max_y e(秘贴|y) is I-negative
# 秘贴 I-negative
#
# 自生 is tagged as UNK and the this arg_max_y e(自生|y) is I-negative
# 自生 I-negative
#
# 精华 I-neutral
#
# 套盒 O
#
# ， O
#
# 李英爱 is tagged as UNK and the this arg_max_y e(李英爱|y) is I-negative
# 李英爱 I-negative
#
# 一年 O
#
# 用 O
#
# 六瓶 is tagged as UNK and the this arg_max_y e(六瓶|y) is I-negative
# 六瓶 I-negative
#
# 的 I-negative
#
# 精华 I-neutral
#
# 套盒 O
#
# 。 O
#
# 功效 O
#
# 特点 O
#
# ： O
#
# 高 B-neutral
#
# 保湿 B-positive
#
# 、 O
#
# 抗皱 is tagged as UNK and the this arg_max_y e(抗皱|y) is I-negative
# 抗皱 I-negative
#
# 抗敏 is tagged as UNK and the this arg_max_y e(抗敏|y) is I-negative
# 抗敏 I-negative
#
# 、 O
#
# 促进 O
#
# 循环 O
#
# 、 O
#
# 皮肤 B-neutral
#
# 弹力 O
#
# 、 O
#
# 自 O
#
# 生 I-neutral
#
# 能力 I-positive
#
# 、 O
#
# 自行 O
#
# 治愈 is tagged as UNK and the this arg_max_y e(治愈|y) is I-negative
# 治愈 I-negative
#
# 能力 I-positive
#
# 。 O
#
# new sentence
# # B-positive
#
# 360 B-neutral
#
# 搜索 B-neutral
#
# 人气 O
#
# 榜 I-neutral
#
# # B-positive
#
# 正在 O
#
# 火热 O
#
# 评选 O
#
# 中 O
#
# ！ O
#
# 我 B-negative
#
# 投给 O
#
# 了 O
#
# 吴奇隆 B-positive
#
# ， O
#
# 吴奇隆 B-positive
#
# 目前 O
#
# 已经 O
#
# 有 O
#
# 2942 O
#
# 票 O
#
# 了 O
#
# ， O
#
# 在 O
#
# 人气 O
#
# 男演员 B-neutral
#
# 排行榜 I-neutral
#
# 中 O
#
# 排名第 O
#
# 51 O
#
# 。 O
#
# 各位 O
#
# 小伙伴 B-neutral
#
# 快 O
#
# 来 B-negative
#
# 投票 O
#
# 吧 O
#
# ！ O
#
# http://t.cn/Rz0e1TL O
#
# new sentence
# : O
#
# [ O
#
# 微风 O
#
# ] O
#
# 奶酪 is tagged as UNK and the this arg_max_y e(奶酪|y) is I-negative
# 奶酪 I-negative
#
# 陷阱 O
#
# [ O
#
# 微风 O
#
# ] O
#
# 安利 O
#
# 给 O
#
# 你们 B-positive
#
# 一部 O
#
# 超甜 is tagged as UNK and the this arg_max_y e(超甜|y) is I-negative
# 超甜 I-negative
#
# 的 I-negative
#
# 韩剧 is tagged as UNK and the this arg_max_y e(韩剧|y) is I-negative
# 韩剧 I-negative
#
# 一口气 O
#
# 看 O
#
# 完全 O
#
# 集超 is tagged as UNK and the this arg_max_y e(集超|y) is I-negative
# 集超 I-negative
#
# 满足 O
#
# ， O
#
# 还 O
#
# 没 O
#
# 看 O
#
# 的 I-negative
#
# 宝宝 I-positive
#
# 有福 is tagged as UNK and the this arg_max_y e(有福|y) is I-negative
# 有福 I-negative
#
# 啦 O
#
# ！ O
#
# 女主 O
#
# 敲 O
#
# 耐看 is tagged as UNK and the this arg_max_y e(耐看|y) is I-negative
# 耐看 I-negative
#
# ~ I-positive
#
# ~ I-positive
#
# ~ I-positive
#
# 赞赞后 is tagged as UNK and the this arg_max_y e(赞赞后|y) is I-negative
# 赞赞后 I-negative
#
# si is tagged as UNK and the this arg_max_y e(si|y) is I-negative
# si I-negative
#
# ， O
#
# 一起 O
#
# 追剧 O
#
# 吧 O
#
# new sentence
# 席卷 is tagged as UNK and the this arg_max_y e(席卷|y) is I-negative
# 席卷 I-negative
#
# 大 I-positive
#
# 商场 is tagged as UNK and the this arg_max_y e(商场|y) is I-negative
# 商场 I-negative
#
# 与 O
#
# 路边摊 is tagged as UNK and the this arg_max_y e(路边摊|y) is I-negative
# 路边摊 I-negative
#
# ， O
#
# 中国 B-negative
#
# 支付 is tagged as UNK and the this arg_max_y e(支付|y) is I-negative
# 支付 I-negative
#
# “ O
#
# 比 O
#
# 韩国 B-neutral
#
# 的 I-negative
#
# 都 O
#
# 要 O
#
# 好 B-negative
#
# ” O
#
# 分享 O
#
# 链接 O
#
# http://t.cn/RVt4ovz is tagged as UNK and the this arg_max_y e(http://t.cn/RVt4ovz|y) is I-negative
# http://t.cn/RVt4ovz I-negative
#
# new sentence
# 1012 is tagged as UNK and the this arg_max_y e(1012|y) is I-negative
# 1012 I-negative
#
# 周三 O
#
# 南洋 B-neutral
#
# 明天 O
#
# 是 O
#
# 去 I-negative
#
# 是 O
#
# 留 B-neutral
#
# ， O
#
# 还 O
#
# 没有 O
#
# 谱 O
#
# ？ O
#
# 还是 O
#
# 去 I-negative
#
# 吧 O
#
# ！ O
#
# 看 O
#
# 明天 O
#
# 看盘 is tagged as UNK and the this arg_max_y e(看盘|y) is I-negative
# 看盘 I-negative
#
# 情况 O
#
# ， O
#
# 明天 O
#
# 要 O
#
# 上班 O
#
# 了 O
#
# ！ O
#
# new sentence
# 美丽 O
#
# 的 I-negative
#
# 包 I-positive
#
# 臀 is tagged as UNK and the this arg_max_y e(臀|y) is I-negative
# 臀 I-negative
#
# 美人鱼 is tagged as UNK and the this arg_max_y e(美人鱼|y) is I-negative
# 美人鱼 I-negative
#
# 尾裙 is tagged as UNK and the this arg_max_y e(尾裙|y) is I-negative
# 尾裙 I-negative
#
# → O
#
# 「 B-negative
#
# 地止 is tagged as UNK and the this arg_max_y e(地止|y) is I-negative
# 地止 I-negative
#
# 见 O
#
# 苹论 is tagged as UNK and the this arg_max_y e(苹论|y) is I-negative
# 苹论 I-negative
#
# 】 O
#
# new sentence
# 看到 O
#
# 大家 O
#
# 都 O
#
# 在 O
#
# 夸 O
#
# 衣服 B-neutral
#
# 好看 O
#
# ， O
#
# 非常 O
#
# 开心 O
#
# ！ O
#
# 觉得 O
#
# 自己 B-negative
#
# 这 O
#
# 段时间 O
#
# 的 I-negative
#
# 努力 O
#
# 没有 O
#
# 白费 O
#
# 啊 I-positive
#
# ！ O
#
# 当然 O
#
# 更要 O
#
# 感谢 O
#
# 的 I-negative
#
# 是 O
#
# 我们 B-negative
#
# 本次 O
#
# 的 I-negative
#
# 设计师 O
#
# — O
#
# — O
#
# 阿昌 B-positive
#
# ！ O
#
# 图案 I-neutral
#
# 都 O
#
# 实现 O
#
# 得 I-neutral
#
# 非常 O
#
# 棒 O
#
# ！ O
#
# new sentence
# ③ O
#
# 傅园慧 is tagged as UNK and the this arg_max_y e(傅园慧|y) is I-negative
# 傅园慧 I-negative
#
# 手机 B-neutral
#
# 奥运村 is tagged as UNK and the this arg_max_y e(奥运村|y) is I-negative
# 奥运村 I-negative
#
# 被 O
#
# 偷 O
#
# new sentence
# 【 O
#
# 博鳌 is tagged as UNK and the this arg_max_y e(博鳌|y) is I-negative
# 博鳌 I-negative
#
# 旅游 I-positive
#
# 风景区 I-neutral
#
# 】 O
#
# 博鳌 is tagged as UNK and the this arg_max_y e(博鳌|y) is I-negative
# 博鳌 I-negative
#
# 位于 O
#
# 琼海市 is tagged as UNK and the this arg_max_y e(琼海市|y) is I-negative
# 琼海市 I-negative
#
# 东部 I-neutral
#
# 海滨 O
#
# ， O
#
# 属 I-neutral
#
# 热带 I-neutral
#
# 北缘 is tagged as UNK and the this arg_max_y e(北缘|y) is I-negative
# 北缘 I-negative
#
# ， O
#
# 北纬 is tagged as UNK and the this arg_max_y e(北纬|y) is I-negative
# 北纬 I-negative
#
# 19 I-neutral
#
# . O
#
# 3 I-positive
#
# 度 I-positive
#
# ， O
#
# 东经 is tagged as UNK and the this arg_max_y e(东经|y) is I-negative
# 东经 I-negative
#
# 110 O
#
# . O
#
# 5 I-neutral
#
# 度 I-positive
#
# ， O
#
# 东 I-positive
#
# 、 O
#
# 南临 is tagged as UNK and the this arg_max_y e(南临|y) is I-negative
# 南临 I-negative
#
# 南海 B-neutral
#
# ， O
#
# 距 O
#
# 琼海市 is tagged as UNK and the this arg_max_y e(琼海市|y) is I-negative
# 琼海市 I-negative
#
# 嘉积 is tagged as UNK and the this arg_max_y e(嘉积|y) is I-negative
# 嘉积 I-negative
#
# 镇 I-positive
#
# 17 O
#
# 公里 I-neutral
#
# 、 O
#
# 海口市 is tagged as UNK and the this arg_max_y e(海口市|y) is I-negative
# 海口市 I-negative
#
# 105 O
#
# 公里 I-neutral
#
# 、 O
#
# 三亚市 is tagged as UNK and the this arg_max_y e(三亚市|y) is I-negative
# 三亚市 I-negative
#
# 180 O
#
# 公里 I-neutral
#
# 。 O
#
# new sentence

# %%
! python EvalScript/evalResult.py CN/dev.out CN/dev.p2.out
# Out:
# #Entity in gold data: 700
# #Entity in prediction: 4248
#
# #Correct Entity : 345
# Entity  precision: 0.0812
# Entity  recall: 0.4929
# Entity  F: 0.1395
#
# #Correct Sentiment : 167
# Sentiment  precision: 0.0393
# Sentiment  recall: 0.2386
# Sentiment  F: 0.0675

# %% [markdown]
# ## SG

# %%
emission_param_table_UNK_test_SG , unk_list_SG = gen_emission_param_table_UNK('SG/train', 'SG/dev.in')
emission_param_table_UNK_test_SG
# Out:
# updating emission_count_table and y_count_dic
# updating emission_param_table
# unl_list is:  ['#25-28' '#2503love' '#2k16' ... '的家家家' '老江' '金味']
# y_count_dic is:  {'O': 178169, 'B-neutral': 24868, 'I-neutral': 28760, 'B-positive': 3672, 'I-positive': 2558, 'B-negative': 1139, 'I-negative': 501}
#              Welcome     lunch       for  Charlotte       and       Tin  \
# O           0.000112  0.000292  0.008284    0.00000  0.009715  0.000006
# B-neutral   0.000000  0.000040  0.000000    0.00004  0.000000  0.000080
# I-neutral   0.000000  0.000000  0.000139    0.00000  0.002017  0.000000
# B-positive  0.000000  0.000000  0.000000    0.00000  0.000000  0.000272
# I-positive  0.000000  0.000000  0.000391    0.00000  0.005081  0.000000
# B-negative  0.000000  0.000000  0.000000    0.00000  0.000000  0.000000
# I-negative  0.000000  0.000000  0.000000    0.00000  0.001994  0.000000
#
#                    2         .  #DellPinoys  #iworkfordell    ...     \
# O           0.001369  0.023826     0.000006       0.000006    ...
# B-neutral   0.000040  0.000000     0.000000       0.000000    ...
# I-neutral   0.003442  0.005528     0.000000       0.000000    ...
# B-positive  0.000000  0.000000     0.000000       0.000000    ...
# I-positive  0.003518  0.011335     0.000000       0.000000    ...
# B-negative  0.000000  0.000000     0.000000       0.000000    ...
# I-negative  0.001994  0.007976     0.000000       0.000000    ...
#
#             https://t.co/1LOoAaD3m3  https://t.co/vOaV71uXX2  \
# O                          0.000006                 0.000006
# B-neutral                  0.000000                 0.000000
# I-neutral                  0.000000                 0.000000
# B-positive                 0.000000                 0.000000
# I-positive                 0.000000                 0.000000
# B-negative                 0.000000                 0.000000
# I-negative                 0.000000                 0.000000
#
#             https://t.co/3JciGQSjPg  https://t.co/BpLrevmNT9  \
# O                          0.000006                 0.000006
# B-neutral                  0.000000                 0.000000
# I-neutral                  0.000000                 0.000000
# B-positive                 0.000000                 0.000000
# I-positive                 0.000000                 0.000000
# B-negative                 0.000000                 0.000000
# I-negative                 0.000000                 0.000000
#
#             https://t.co/2OyQGc0up3      didn  https://t.co/NFlUTuKIP1  \
# O                          0.000006  0.000006                 0.000006
# B-neutral                  0.000000  0.000000                 0.000000
# I-neutral                  0.000000  0.000000                 0.000000
# B-positive                 0.000000  0.000000                 0.000000
# I-positive                 0.000000  0.000000                 0.000000
# B-negative                 0.000000  0.000000                 0.000000
# I-negative                 0.000000  0.000000                 0.000000
#
#             https://t.co/xlI7t51227  https://t.co/AI0MvxyfPX       UNK
# O                          0.000006                 0.000006  0.000003
# B-neutral                  0.000000                 0.000000  0.000020
# I-neutral                  0.000000                 0.000000  0.000017
# B-positive                 0.000000                 0.000000  0.000136
# I-positive                 0.000000                 0.000000  0.000195
# B-negative                 0.000000                 0.000000  0.000439
# I-negative                 0.000000                 0.000000  0.000997
#
# [7 rows x 42810 columns]

# %%
gen_state('SG/dev.in','SG/dev.p2.out', emission_param_table_UNK_test_SG, unk_list_SG)
# Out:
# Everything O
#
# sounds O
#
# better O
#
# with O
#
# the O
#
# Titanic is tagged as UNK and the this arg_max_y e(Titanic|y) is I-negative
# Titanic I-negative
#
# song I-negative
#
# laa O
#
# . O
#
# Hahaha O
#
# . O
#
# new sentence
# Eat O
#
# time O
#
# ( I-neutral
#
# @ O
#
# Geylang B-neutral
#
# East I-neutral
#
# Market I-neutral
#
# & I-positive
#
# Food I-neutral
#
# Centre I-neutral
#
# in O
#
# Singapore B-neutral
#
# ) I-neutral
#
# https://t.co/NfT0pki59H is tagged as UNK and the this arg_max_y e(https://t.co/NfT0pki59H|y) is I-negative
# https://t.co/NfT0pki59H I-negative
#
# new sentence
# Kinda O
#
# excited O
#
# about O
#
# the O
#
# Godzilla-Kong is tagged as UNK and the this arg_max_y e(Godzilla-Kong|y) is I-negative
# Godzilla-Kong I-negative
#
# film O
#
# series B-neutral
#
# new sentence
# I'm O
#
# at O
#
# Chinatown B-neutral
#
# Street I-neutral
#
# Market I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/ldW8BH3M8l is tagged as UNK and the this arg_max_y e(https://t.co/ldW8BH3M8l|y) is I-negative
# https://t.co/ldW8BH3M8l I-negative
#
# new sentence
# I'm O
#
# at O
#
# Junction I-neutral
#
# 8 I-positive
#
# Shopping I-neutral
#
# Centre I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/xBScjEWswb is tagged as UNK and the this arg_max_y e(https://t.co/xBScjEWswb|y) is I-negative
# https://t.co/xBScjEWswb I-negative
#
# new sentence
# I'm O
#
# at O
#
# Little B-negative
#
# India I-positive
#
# MRT I-neutral
#
# Interchange I-neutral
#
# ( I-neutral
#
# NE7 I-neutral
#
# / O
#
# DT12 I-neutral
#
# ) I-neutral
#
# - O
#
# @sbs_transit B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/7lnoEftSti is tagged as UNK and the this arg_max_y e(https://t.co/7lnoEftSti|y) is I-negative
# https://t.co/7lnoEftSti I-negative
#
# new sentence
# I'm O
#
# at O
#
# agbk's B-neutral
#
# crib I-neutral
#
# https://t.co/Dt2P4XaurE O
#
# new sentence
# I O
#
# Love I-positive
#
# You I-positive
#
# From I-positive
#
# 38.000 I-positive
#
# Feet I-positive
#
# Movie I-positive
#
# ❤ O
#
# ️ O
#
# ️ O
#
# ️ O
#
# ( I-neutral
#
# with O
#
# Dwi B-neutral
#
# at O
#
# @cinema21 B-neutral
#
# ) I-neutral
#
# — O
#
# https://t.co/1Owl7oD4G0 O
#
# new sentence
# I'm O
#
# at O
#
# nex B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/r8038gyX0H is tagged as UNK and the this arg_max_y e(https://t.co/r8038gyX0H|y) is I-negative
# https://t.co/r8038gyX0H I-negative
#
# new sentence
# I'm O
#
# at O
#
# 313 B-neutral
#
# @somerset I-negative
#
# - O
#
# @313atsomerset B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/gwiNUryLCm is tagged as UNK and the this arg_max_y e(https://t.co/gwiNUryLCm|y) is I-negative
# https://t.co/gwiNUryLCm I-negative
#
# new sentence
# Grateful O
#
# to O
#
# God B-positive
#
# . O
#
# @ O
#
# Burlington B-neutral
#
# Square I-neutral
#
# , I-neutral
#
# Bencoolen B-neutral
#
# https://t.co/WzZFwODXW9 O
#
# new sentence
# @Zikryzulfiqar is tagged as UNK and the this arg_max_y e(@Zikryzulfiqar|y) is I-negative
# @Zikryzulfiqar I-negative
#
# @_faizahjnd is tagged as UNK and the this arg_max_y e(@_faizahjnd|y) is I-negative
# @_faizahjnd I-negative
#
# wow O
#
# wow O
#
# zikry is tagged as UNK and the this arg_max_y e(zikry|y) is I-negative
# zikry I-negative
#
# ? O
#
# seriously O
#
# ? O
#
# last O
#
# long O
#
# bro B-negative
#
# ! O
#
# ! O
#
# ! O
#
# hahaaha is tagged as UNK and the this arg_max_y e(hahaaha|y) is I-negative
# hahaaha I-negative
#
# less O
#
# fight O
#
# argue O
#
# , I-neutral
#
# more O
#
# love O
#
# ! O
#
# ! O
#
# ! O
#
# hahahah O
#
# new sentence
# Rudy B-positive
#
# Habibie I-positive
#
# ( I-neutral
#
# at O
#
# @cinema21 B-neutral
#
# ) I-neutral
#
# — O
#
# https://t.co/iljX6norpb O
#
# new sentence
# I'm O
#
# at O
#
# Bus B-neutral
#
# Stop I-neutral
#
# 27159 is tagged as UNK and the this arg_max_y e(27159|y) is I-negative
# 27159 I-negative
#
# ( I-neutral
#
# Blk B-neutral
#
# 924 is tagged as UNK and the this arg_max_y e(924|y) is I-negative
# 924 I-negative
#
# ) I-neutral
#
# https://t.co/Q6UOqi3P6C is tagged as UNK and the this arg_max_y e(https://t.co/Q6UOqi3P6C|y) is I-negative
# https://t.co/Q6UOqi3P6C I-negative
#
# new sentence
# I'm O
#
# at O
#
# ITE B-neutral
#
# College I-neutral
#
# Central I-neutral
#
# - O
#
# @itespore B-neutral
#
# in O
#
# Singapore B-neutral
#
# w O
#
# / O
#
# @inxzclm O
#
# @yining_leh O
#
# @joeluke98 O
#
# @terencenks O
#
# https://t.co/g3lzONNCdL is tagged as UNK and the this arg_max_y e(https://t.co/g3lzONNCdL|y) is I-negative
# https://t.co/g3lzONNCdL I-negative
#
# new sentence
# I'm O
#
# at O
#
# Hospital I-negative
#
# Sultanah I-neutral
#
# Aminah I-neutral
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/2ZwOssC8Qs is tagged as UNK and the this arg_max_y e(https://t.co/2ZwOssC8Qs|y) is I-negative
# https://t.co/2ZwOssC8Qs I-negative
#
# new sentence
# MY O
#
# DADWANTS is tagged as UNK and the this arg_max_y e(DADWANTS|y) is I-negative
# DADWANTS I-negative
#
# TO O
#
# BRING B-neutral
#
# MY O
#
# MUM is tagged as UNK and the this arg_max_y e(MUM|y) is I-negative
# MUM I-negative
#
# FOR O
#
# DINNER is tagged as UNK and the this arg_max_y e(DINNER|y) is I-negative
# DINNER I-negative
#
# AND O
#
# MY O
#
# BROTHER I-positive
#
# IS O
#
# ADDICT is tagged as UNK and the this arg_max_y e(ADDICT|y) is I-negative
# ADDICT I-negative
#
# TO O
#
# GAMES O
#
# AND O
#
# MY O
#
# SISTER is tagged as UNK and the this arg_max_y e(SISTER|y) is I-negative
# SISTER I-negative
#
# IS O
#
# ADDICTED is tagged as UNK and the this arg_max_y e(ADDICTED|y) is I-negative
# ADDICTED I-negative
#
# TO O
#
# TELEGRAM is tagged as UNK and the this arg_max_y e(TELEGRAM|y) is I-negative
# TELEGRAM I-negative
#
# new sentence
# When O
#
# you B-negative
#
# tire is tagged as UNK and the this arg_max_y e(tire|y) is I-negative
# tire I-negative
#
# of I-negative
#
# Raya I-positive
#
# foods O
#
# aka O
#
# Malay B-neutral
#
# cuisine I-neutral
#
# … O
#
# #halaljapanesefood is tagged as UNK and the this arg_max_y e(#halaljapanesefood|y) is I-negative
# #halaljapanesefood I-negative
#
# … O
#
# https://t.co/SbRGh20WPZ is tagged as UNK and the this arg_max_y e(https://t.co/SbRGh20WPZ|y) is I-negative
# https://t.co/SbRGh20WPZ I-negative
#
# new sentence
# Who I-positive
#
# am O
#
# I O
#
# kidding O
#
# , I-neutral
#
# it's O
#
# not O
#
# like O
#
# I O
#
# get O
#
# money B-negative
#
# after B-negative
#
# beating O
#
# other O
#
# Pokemon B-negative
#
# trainers I-neutral
#
# lol O
#
# new sentence
# I'm O
#
# at O
#
# The B-neutral
#
# Seletar B-positive
#
# Mall I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/PX2bVPGBxV is tagged as UNK and the this arg_max_y e(https://t.co/PX2bVPGBxV|y) is I-negative
# https://t.co/PX2bVPGBxV I-negative
#
# new sentence
# PPPP is tagged as UNK and the this arg_max_y e(PPPP|y) is I-negative
# PPPP I-negative
#
# ( I-neutral
#
# @ O
#
# White B-neutral
#
# Horse I-neutral
#
# Ceramic I-neutral
#
# ) I-neutral
#
# https://t.co/SnvyVTFnV4 is tagged as UNK and the this arg_max_y e(https://t.co/SnvyVTFnV4|y) is I-negative
# https://t.co/SnvyVTFnV4 I-negative
#
# new sentence
# I'm O
#
# at O
#
# Econ B-neutral
#
# Medicare is tagged as UNK and the this arg_max_y e(Medicare|y) is I-negative
# Medicare I-negative
#
# Centre I-neutral
#
# @ O
#
# Chai B-neutral
#
# Chee I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/uRImZt0AIy is tagged as UNK and the this arg_max_y e(https://t.co/uRImZt0AIy|y) is I-negative
# https://t.co/uRImZt0AIy I-negative
#
# new sentence
# Boobs is tagged as UNK and the this arg_max_y e(Boobs|y) is I-negative
# Boobs I-negative
#
# day O
#
# ! O
#
# ! O
#
# Aspire is tagged as UNK and the this arg_max_y e(Aspire|y) is I-negative
# Aspire I-negative
#
# to O
#
# grow O
#
# my O
#
# tits O
#
# as O
#
# big B-positive
#
# as O
#
# thit is tagged as UNK and the this arg_max_y e(thit|y) is I-negative
# thit I-negative
#
# thits is tagged as UNK and the this arg_max_y e(thits|y) is I-negative
# thits I-negative
#
# tits O
#
# ( I-neutral
#
# @ O
#
# Anytime B-neutral
#
# Fitness I-neutral
#
# ( I-neutral
#
# Jurong B-neutral
#
# Gateway I-neutral
#
# ) I-neutral
#
# in O
#
# Singapore B-neutral
#
# ) I-neutral
#
# https://t.co/obHRGyhQxA is tagged as UNK and the this arg_max_y e(https://t.co/obHRGyhQxA|y) is I-negative
# https://t.co/obHRGyhQxA I-negative
#
# new sentence
# So O
#
# why O
#
# did O
#
# I O
#
# buy O
#
# the O
#
# billabong is tagged as UNK and the this arg_max_y e(billabong|y) is I-negative
# billabong I-negative
#
# shirt B-positive
#
# again O
#
# ? O
#
# new sentence
# I'm O
#
# at O
#
# Hair I-positive
#
# Joys is tagged as UNK and the this arg_max_y e(Joys|y) is I-negative
# Joys I-negative
#
# Salon I-neutral
#
# https://t.co/zAOi5sThiu is tagged as UNK and the this arg_max_y e(https://t.co/zAOi5sThiu|y) is I-negative
# https://t.co/zAOi5sThiu I-negative
#
# new sentence
# Lol O
#
# wtffff O
#
# I O
#
# should've O
#
# applied O
#
# Smu B-neutral
#
# and O
#
# tried O
#
# my O
#
# luck O
#
# la O
#
# but O
#
# then O
#
# again O
#
# I O
#
# have O
#
# no O
#
# regrets O
#
# choosing O
#
# my O
#
# current O
#
# school B-negative
#
# new sentence
# her B-negative
#
# kiss O
#
# it O
#
# tastes is tagged as UNK and the this arg_max_y e(tastes|y) is I-negative
# tastes I-negative
#
# so O
#
# sweet O
#
# , I-neutral
#
# but O
#
# left O
#
# me O
#
# with O
#
# a O
#
# lethargy is tagged as UNK and the this arg_max_y e(lethargy|y) is I-negative
# lethargy I-negative
#
# new sentence
# Hey O
#
# , I-neutral
#
# I O
#
# just O
#
# started O
#
# using O
#
# Maaii is tagged as UNK and the this arg_max_y e(Maaii|y) is I-negative
# Maaii I-negative
#
# for O
#
# free O
#
# calls O
#
# / O
#
# chat O
#
# and O
#
# it's O
#
# pretty O
#
# awesome O
#
# ! O
#
# Install is tagged as UNK and the this arg_max_y e(Install|y) is I-negative
# Install I-negative
#
# it O
#
# and O
#
# chat O
#
# with O
#
# me O
#
# now O
#
# :-) O
#
# https://t.co/jRrzcmnwG6 is tagged as UNK and the this arg_max_y e(https://t.co/jRrzcmnwG6|y) is I-negative
# https://t.co/jRrzcmnwG6 I-negative
#
# new sentence
# So O
#
# level O
#
# up O
#
# your O
#
# gifts O
#
# and O
#
# make O
#
# donations is tagged as UNK and the this arg_max_y e(donations|y) is I-negative
# donations I-negative
#
# knowing O
#
# our O
#
# new O
#
# charity is tagged as UNK and the this arg_max_y e(charity|y) is I-negative
# charity I-negative
#
# wants O
#
# these O
#
# gifts O
#
# to O
#
# stay O
#
# on O
#
# the O
#
# site I-neutral
#
# . O
#
# new sentence
# Transpay B-positive
#
# wants O
#
# to O
#
# solve O
#
# the O
#
# problem O
#
# of I-negative
#
# payments O
#
# for O
#
# freelancers O
#
# in O
#
# Asia I-neutral
#
# https://t.co/HM3K47Ic1w O
#
# new sentence
# I'm O
#
# at O
#
# Mr B-positive
#
# DIY O
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/6xXWEIJstD is tagged as UNK and the this arg_max_y e(https://t.co/6xXWEIJstD|y) is I-negative
# https://t.co/6xXWEIJstD I-negative
#
# new sentence
# D B-negative
#
# ( I-neutral
#
# @ O
#
# 成记 is tagged as UNK and the this arg_max_y e(成记|y) is I-negative
# 成记 I-negative
#
# Steamed is tagged as UNK and the this arg_max_y e(Steamed|y) is I-negative
# Steamed I-negative
#
# Fish B-neutral
#
# Head I-negative
#
# In I-positive
#
# Hot I-positive
#
# Sauce I-positive
#
# in O
#
# Singapore B-neutral
#
# ) I-neutral
#
# https://t.co/5YLnvzVU8e is tagged as UNK and the this arg_max_y e(https://t.co/5YLnvzVU8e|y) is I-negative
# https://t.co/5YLnvzVU8e I-negative
#
# new sentence
# I'm O
#
# at O
#
# Markaz B-neutral
#
# Boys I-positive
#
# Of I-positive
#
# Straits B-negative
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/e9NAO37v1f is tagged as UNK and the this arg_max_y e(https://t.co/e9NAO37v1f|y) is I-negative
# https://t.co/e9NAO37v1f I-negative
#
# new sentence
# I'm O
#
# at O
#
# Jubilee B-positive
#
# Sq I-neutral
#
# in O
#
# Ang B-neutral
#
# Mo I-neutral
#
# Kio I-neutral
#
# https://t.co/He95hoGlVp O
#
# new sentence
# I'm O
#
# at O
#
# Jurong B-neutral
#
# Point I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/MmCazst0Gv O
#
# new sentence
# Oh I-negative
#
# theres O
#
# masterchef B-negative
#
# tmr O
#
# excites O
#
# new sentence
# @HathwayBrdband B-negative
#
# Money I-neutral
#
# collected O
#
# from O
#
# us O
#
# by I-neutral
#
# False O
#
# promises O
#
# and O
#
# later O
#
# connection I-negative
#
# denied O
#
# . O
#
# No I-positive
#
# refund O
#
# yet O
#
# . O
#
# Clear O
#
# fraud O
#
# ! O
#
# . O
#
# https://t.co/2FROQUXAAL O
#
# new sentence
# #Zfacebook is tagged as UNK and the this arg_max_y e(#Zfacebook|y) is I-negative
# #Zfacebook I-negative
#
# Zayn B-neutral
#
# posted O
#
# this O
#
# . O
#
# Love I-positive
#
# it O
#
# ! O
#
# https://t.co/MXjWB3V5XK is tagged as UNK and the this arg_max_y e(https://t.co/MXjWB3V5XK|y) is I-negative
# https://t.co/MXjWB3V5XK I-negative
#
# new sentence
# I'm O
#
# at O
#
# Bugis B-neutral
#
# Street I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/f1zLcedloL O
#
# new sentence
# Hosting O
#
# for O
#
# Disney B-neutral
#
# at O
#
# Raffles B-neutral
#
# place B-negative
#
# later O
#
# . O
#
# Office I-neutral
#
# worker O
#
# & I-positive
#
# expats O
#
# , I-neutral
#
# please O
#
# be O
#
# nice O
#
# to O
#
# Evalee B-neutral
#
# and O
#
# give O
#
# her B-negative
#
# face B-negative
#
# . O
#
# new sentence
# I'm O
#
# at O
#
# Jem B-neutral
#
# - O
#
# @jemsingapore B-neutral
#
# in O
# Singapore B-neutral
#
# https://t.co/tCWzvQ7cDZ O
#
# new sentence
# I'm O
#
# at O
#
# https://t.co/QuQpzEyMR4 is tagged as UNK and the this arg_max_y e(https://t.co/QuQpzEyMR4|y) is I-negative
# https://t.co/QuQpzEyMR4 I-negative
#
# Singapore B-neutral
#
# in O
#
# Singapore B-neutral
#
# w O
#
# / O
#
# @n_sengheng O
#
# https://t.co/M9I0fR56Tt is tagged as UNK and the this arg_max_y e(https://t.co/M9I0fR56Tt|y) is I-negative
# https://t.co/M9I0fR56Tt I-negative
#
# new sentence
# I'm O
#
# at O
#
# Blazinsky is tagged as UNK and the this arg_max_y e(Blazinsky|y) is I-negative
# Blazinsky I-negative
#
# Barber I-positive
#
# & I-positive
#
# Cafe I-neutral
#
# https://t.co/VRUYZHAElD is tagged as UNK and the this arg_max_y e(https://t.co/VRUYZHAElD|y) is I-negative
# https://t.co/VRUYZHAElD I-negative
#
# new sentence
# Too O
#
# blessed O
#
# for O
#
# today O
#
# . O
#
# So O
#
# much O
#
# fun O
#
# & I-positive
#
# love O
#
# . O
#
# Thank O
#
# you B-negative
#
# Allah B-positive
#
# for O
#
# this O
#
# big B-positive
#
# family B-negative
#
# . O
#
# Alimah is tagged as UNK and the this arg_max_y e(Alimah|y) is I-negative
# Alimah I-negative
#
# & I-positive
#
# Sadi's is tagged as UNK and the this arg_max_y e(Sadi's|y) is I-negative
# Sadi's I-negative
#
# family B-negative
#
# ❤ O
#
# ️ O
#
# ❤ O
#
# ️ O
#
# new sentence
# One I-positive
#
# day O
#
# with O
#
# familyyy is tagged as UNK and the this arg_max_y e(familyyy|y) is I-negative
# familyyy I-negative
#
# ( I-neutral
#
# with O
#
# irwan B-neutral
#
# at O
#
# Taman B-neutral
#
# Oval is tagged as UNK and the this arg_max_y e(Oval|y) is I-negative
# Oval I-negative
#
# Markoni is tagged as UNK and the this arg_max_y e(Markoni|y) is I-negative
# Markoni I-negative
#
# Tarakan B-positive
#
# ) I-neutral
#
# — O
#
# https://t.co/CvcdQ7ms5C is tagged as UNK and the this arg_max_y e(https://t.co/CvcdQ7ms5C|y) is I-negative
# https://t.co/CvcdQ7ms5C I-negative
#
# new sentence
# what O
#
# is O
#
# a O
#
# holiday O
#
# without O
#
# iridescent is tagged as UNK and the this arg_max_y e(iridescent|y) is I-negative
# iridescent I-negative
#
# sunglasses B-neutral
#
# and O
#
# a O
#
# more O
#
# difficult O
#
# than O
#
# necessary is tagged as UNK and the this arg_max_y e(necessary|y) is I-negative
# necessary I-negative
#
# selfie B-positive
#
# ? O
#
# ! O
#
# … O
#
# https://t.co/NVoUhhuaOg is tagged as UNK and the this arg_max_y e(https://t.co/NVoUhhuaOg|y) is I-negative
# https://t.co/NVoUhhuaOg I-negative
#
# new sentence
# why O
#
# is O
#
# Kobe is tagged as UNK and the this arg_max_y e(Kobe|y) is I-negative
# Kobe I-negative
#
# so O
#
# fine O
#
# new sentence
# ... O
#
# ( I-neutral
#
# with O
#
# Ipan is tagged as UNK and the this arg_max_y e(Ipan|y) is I-negative
# Ipan I-negative
#
# at O
#
# X-Treme is tagged as UNK and the this arg_max_y e(X-Treme|y) is I-negative
# X-Treme I-negative
#
# Pool I-neutral
#
# Billyard is tagged as UNK and the this arg_max_y e(Billyard|y) is I-negative
# Billyard I-negative
#
# ) I-neutral
#
# [ O
#
# pic O
#
# ] O
#
# — O
#
# https://t.co/UDtuOGPnRy is tagged as UNK and the this arg_max_y e(https://t.co/UDtuOGPnRy|y) is I-negative
# https://t.co/UDtuOGPnRy I-negative
#
# new sentence
# Hope O
#
# you B-negative
#
# enjoyed O
#
# your O
#
# birthday O
#
# Viknesh B-neutral
#
# ! O
#
# @ O
#
# Bukit I-neutral
#
# Batok I-neutral
#
# HomeTeamNS B-neutral
#
# … O
#
# https://t.co/6WNIJ4ZYQ5 is tagged as UNK and the this arg_max_y e(https://t.co/6WNIJ4ZYQ5|y) is I-negative
# https://t.co/6WNIJ4ZYQ5 I-negative
#
# new sentence
# Having O
#
# old B-negative
#
# town I-neutral
#
# white I-neutral
#
# coffee I-positive
#
# now O
#
# with O
#
# le B-neutral
#
# familia is tagged as UNK and the this arg_max_y e(familia|y) is I-negative
# familia I-negative
#
# :) O
#
# new sentence
# I'm O
#
# at O
#
# SMRT B-neutral
#
# Buses I-neutral
#
# : I-negative
#
# Bus B-neutral
#
# 900 O
#
# - O
#
# @smrt_singapore B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/oJeT0olRR3 is tagged as UNK and the this arg_max_y e(https://t.co/oJeT0olRR3|y) is I-negative
# https://t.co/oJeT0olRR3 I-negative
#
# new sentence
# I'm O
#
# at O
#
# Fuchun B-neutral
#
# Secondary I-negative
#
# School I-negative
#
# in O
#
# Singapore B-neutral
#
# https://t.co/9jiT4G9Bpe is tagged as UNK and the this arg_max_y e(https://t.co/9jiT4G9Bpe|y) is I-negative
# https://t.co/9jiT4G9Bpe I-negative
#
# new sentence
# I'm O
#
# at O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# City I-neutral
#
# Square I-neutral
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/jWY54SjJB2 O
#
# new sentence
# sisssy is tagged as UNK and the this arg_max_y e(sisssy|y) is I-negative
# sisssy I-negative
#
# ✌ O
#
# @ O
#
# Idaten is tagged as UNK and the this arg_max_y e(Idaten|y) is I-negative
# Idaten I-negative
#
# Udon I-neutral
#
# Citylink I-neutral
#
# Mall I-neutral
#
# https://t.co/cTh0qJm9yr is tagged as UNK and the this arg_max_y e(https://t.co/cTh0qJm9yr|y) is I-negative
# https://t.co/cTh0qJm9yr I-negative
#
# new sentence
# Lezatoooozzzzzzzz O
#
# ( I-neutral
#
# with O
#
# Rina B-neutral
#
# and O
#
# Anita B-neutral
#
# at O
#
# Panties B-neutral
#
# Pizza I-neutral
#
# ) I-neutral
#
# [ O
#
# pic O
#
# ] O
#
# — O
#
# https://t.co/Z5lDD7cByP O
#
# new sentence
# if O
#
# Pokemon B-negative
#
# go I-negative
#
# leads O
#
# me O
#
# into O
#
# a O
#
# male O
#
# toilet O
#
# I O
#
# WILL O
#
# GO I-positive
#
# new sentence
# I'm O
#
# at O
#
# Eighteen B-neutral
#
# Chefs I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/JvPvJEsZEL is tagged as UNK and the this arg_max_y e(https://t.co/JvPvJEsZEL|y) is I-negative
# https://t.co/JvPvJEsZEL I-negative
#
# new sentence
# I'm O
#
# at O
#
# Hai B-neutral
#
# Bin I-negative
#
# Prawning I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/7TNfbiP153 is tagged as UNK and the this arg_max_y e(https://t.co/7TNfbiP153|y) is I-negative
# https://t.co/7TNfbiP153 I-negative
#
# new sentence
# Family I-positive
#
# ( I-neutral
#
# with O
#
# Yohanes B-neutral
#
# , I-neutral
#
# Richo B-neutral
#
# , I-neutral
#
# and O
#
# 4 I-neutral
#
# others O
#
# at O
#
# @inulvizta B-neutral
#
# ) I-neutral
#
# [ O
#
# pic O
#
# ] O
#
# — O
#
# https://t.co/MRKiGXhdN5 is tagged as UNK and the this arg_max_y e(https://t.co/MRKiGXhdN5|y) is I-negative
# https://t.co/MRKiGXhdN5 I-negative
#
# new sentence
# Rafizi B-neutral
#
# ~ O
#
# According O
#
# to O
#
# filings O
#
# with O
#
# Bursa B-neutral
#
# Malaysia B-neutral
#
# , I-neutral
#
# THHE O
#
# has O
#
# been O
#
# served O
#
# with O
#
# petitions O
#
# from O
#
# 2 I-positive
#
# foreign O
#
# companies O
#
# this O
#
# month O
#
# to O
#
# be O
#
# wound O
#
# up O
#
# . O
#
# new sentence
# I'm O
#
# at O
#
# BLK I-neutral
#
# NI is tagged as UNK and the this arg_max_y e(NI|y) is I-negative
# NI I-negative
#
# @NYP is tagged as UNK and the this arg_max_y e(@NYP|y) is I-negative
# @NYP I-negative
#
# https://t.co/4cWjzOLaVI is tagged as UNK and the this arg_max_y e(https://t.co/4cWjzOLaVI|y) is I-negative
# https://t.co/4cWjzOLaVI I-negative
#
# new sentence
# @BTS_twt B-neutral
#
# Jin B-neutral
#
# ... O
#
# you B-negative
#
# have O
#
# work O
#
# hard O
#
# for O
#
# today O
#
# ... O
#
# have O
#
# a O
#
# good O
#
# rest O
#
# .. O
#
# ^ O
#
# ^ O
#
# ~ O
#
# ♥ O
#
# ♥ O
#
# ♥ O
#
# new sentence
# I'm O
#
# at O
#
# Fish B-neutral
#
# @ O
#
# Big B-positive
#
# Splash I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/PNZsnXJOdx O
#
# new sentence
# #bearkeryhouse is tagged as UNK and the this arg_max_y e(#bearkeryhouse|y) is I-negative
# #bearkeryhouse I-negative
#
# @ O
#
# Bearkery is tagged as UNK and the this arg_max_y e(Bearkery|y) is I-negative
# Bearkery I-negative
#
# House I-neutral
#
# https://t.co/o7MsCnYisp is tagged as UNK and the this arg_max_y e(https://t.co/o7MsCnYisp|y) is I-negative
# https://t.co/o7MsCnYisp I-negative
#
# new sentence
# With O
#
# Susy is tagged as UNK and the this arg_max_y e(Susy|y) is I-negative
# Susy I-negative
#
# Christine I-neutral
#
# at O
#
# Hang B-neutral
#
# Nadim I-neutral
#
# International I-neutral
#
# Airport I-neutral
#
# ( I-neutral
#
# BTH I-neutral
#
# ) I-neutral
#
# — O
#
# https://t.co/CNPJNOqKOI is tagged as UNK and the this arg_max_y e(https://t.co/CNPJNOqKOI|y) is I-negative
# https://t.co/CNPJNOqKOI I-negative
#
# new sentence
# I'm O
#
# at O
#
# Sushi I-negative
#
# King I-positive
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/OXLjph1s7D O
#
# new sentence
# I'm O
#
# at O
#
# 金味 is tagged as UNK and the this arg_max_y e(金味|y) is I-negative
# 金味 I-negative
#
# 24 I-negative
#
# Hours I-neutral
#
# Coffeeshop I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/qf4GqlUGn1 is tagged as UNK and the this arg_max_y e(https://t.co/qf4GqlUGn1|y) is I-negative
# https://t.co/qf4GqlUGn1 I-negative
#
# new sentence
# luna B-neutral
#
# wining is tagged as UNK and the this arg_max_y e(wining|y) is I-negative
# wining I-negative
#
# is O
#
# so O
#
# adorable O
#
# ! O
#
# ! O
#
# ! O
#
# " I-negative
#
# really O
#
# ? O
#
# me O
#
# ? O
#
# why O
#
# would O
#
# i O
#
# get O
#
# chosen O
#
# ? O
#
# " I-negative
#
# and O
#
# then O
#
# she O
#
# decides is tagged as UNK and the this arg_max_y e(decides|y) is I-negative
# decides I-negative
#
# to O
#
# aegyo is tagged as UNK and the this arg_max_y e(aegyo|y) is I-negative
# aegyo I-negative
#
# with O
#
# " I-negative
#
# oppa O
#
# , I-neutral
#
# thank O
#
# you B-negative
#
# ~ O
#
# " I-negative
#
# im O
#
# - O
#
# new sentence
# I'm O
#
# at O
#
# Novena I-negative
#
# in O
#
# Singapore B-neutral
#
# https://t.co/HNqT4t0YHh is tagged as UNK and the this arg_max_y e(https://t.co/HNqT4t0YHh|y) is I-negative
# https://t.co/HNqT4t0YHh I-negative
#
# new sentence
# Weather is tagged as UNK and the this arg_max_y e(Weather|y) is I-negative
# Weather I-negative
#
# Report is tagged as UNK and the this arg_max_y e(Report|y) is I-negative
# Report I-negative
#
# : I-negative
#
# Satan B-neutral
#
# ' O
#
# s I-positive
#
# Armpit is tagged as UNK and the this arg_max_y e(Armpit|y) is I-negative
# Armpit I-negative
#
# @ O
#
# Marina B-neutral
#
# Barrage I-neutral
#
# https://t.co/qJougPhw3S is tagged as UNK and the this arg_max_y e(https://t.co/qJougPhw3S|y) is I-negative
# https://t.co/qJougPhw3S I-negative
#
# new sentence
# I'm O
#
# at O
#
# ITE B-neutral
#
# College I-neutral
#
# East I-neutral
#
# - O
#
# @itespore B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/hkYceIvpae is tagged as UNK and the this arg_max_y e(https://t.co/hkYceIvpae|y) is I-negative
# https://t.co/hkYceIvpae I-negative
#
# new sentence
# dropped O
#
# mum B-positive
#
# off I-negative
#
# at O
#
# procedure O
#
# , I-neutral
#
# now O
#
# otw O
#
# to O
#
# the O
#
# office O
#
# w O
#
# the O
#
# sounds O
#
# of I-negative
#
# Loreena B-neutral
#
# McKennitt I-neutral
#
# in O
#
# my O
#
# ears O
#
# . O
#
# new sentence
# @mamasan2712 is tagged as UNK and the this arg_max_y e(@mamasan2712|y) is I-negative
# @mamasan2712 I-negative
#
# johor B-neutral
#
# style O
#
# dry O
#
# or O
#
# tourist O
#
# standard O
#
# wet O
#
# wet O
#
# wet O
#
# ? O
#
# new sentence
# Wanna O
#
# watch I-positive
#
# this O
#
# sooo O
#
# BAD is tagged as UNK and the this arg_max_y e(BAD|y) is I-negative
# BAD I-negative
#
# #GhostBusters2016 is tagged as UNK and the this arg_max_y e(#GhostBusters2016|y) is I-negative
# #GhostBusters2016 I-negative
#
# #WhoUgonnaCall is tagged as UNK and the this arg_max_y e(#WhoUgonnaCall|y) is I-negative
# #WhoUgonnaCall I-negative
#
# #ProtonPacks is tagged as UNK and the this arg_max_y e(#ProtonPacks|y) is I-negative
# #ProtonPacks I-negative
#
# #EctoOne is tagged as UNK and the this arg_max_y e(#EctoOne|y) is I-negative
# #EctoOne I-negative
#
# … O
#
# https://t.co/cdz4oXWFn9 is tagged as UNK and the this arg_max_y e(https://t.co/cdz4oXWFn9|y) is I-negative
# https://t.co/cdz4oXWFn9 I-negative
#
# new sentence
# l O
#
# @ O
#
# Police I-negative
#
# Cantonment I-negative
#
# Complex I-negative
#
# https://t.co/ug4XeSIN10 O
#
# new sentence
# Invited is tagged as UNK and the this arg_max_y e(Invited|y) is I-negative
# Invited I-negative
#
# reps O
#
# from O
#
# Taipei B-neutral
#
# ' O
#
# s I-positive
#
# sister B-positive
#
# / O
#
# partner O
#
# cities O
#
# - O
#
# Panama is tagged as UNK and the this arg_max_y e(Panama|y) is I-negative
# Panama I-negative
#
# , I-neutral
#
# Penang B-neutral
#
# , I-neutral
#
# Yokohama is tagged as UNK and the this arg_max_y e(Yokohama|y) is I-negative
# Yokohama I-negative
#
# , I-neutral
#
# Wellington is tagged as UNK and the this arg_max_y e(Wellington|y) is I-negative
# Wellington I-negative
#
# - O
#
# to O
#
# the O
#
# #2017TaipeiUniversiade B-neutral
#
# https://t.co/jCpZ2Pii2P is tagged as UNK and the this arg_max_y e(https://t.co/jCpZ2Pii2P|y) is I-negative
# https://t.co/jCpZ2Pii2P I-negative
#
# new sentence
# GAYYYY O
#
# ... O
#
# NAEUNNIE B-negative
#
# ' O
#
# S B-negative
#
# IN O
#
# GUAM B-negative
#
# NW O
#
# ? O
#
# ! O
#
# ? O
#
# ! O
#
# USA B-negative
#
# ? O
#
# ! O
#
# ? O
#
# ! O
#
# ? O
#
# ! O
#
# new sentence
# watching O
#
# @shanedawson is tagged as UNK and the this arg_max_y e(@shanedawson|y) is I-negative
# @shanedawson I-negative
#
# ' O
#
# s I-positive
#
# conspiracy is tagged as UNK and the this arg_max_y e(conspiracy|y) is I-negative
# conspiracy I-negative
#
# videos O
#
# makes O
#
# me O
#
# so O
#
# fucking O
#
# scared O
#
# to O
#
# go I-negative
#
# to O
#
# amusement is tagged as UNK and the this arg_max_y e(amusement|y) is I-negative
# amusement I-negative
#
# parks is tagged as UNK and the this arg_max_y e(parks|y) is I-negative
# parks I-negative
#
# now O
#
# wtf O
#
# new sentence
# I'm O
#
# at O
#
# Ajisen B-positive
#
# Ramen I-positive
#
# in O
#
# Singapore B-neutral
#
# https://t.co/ZlplrHyFex is tagged as UNK and the this arg_max_y e(https://t.co/ZlplrHyFex|y) is I-negative
# https://t.co/ZlplrHyFex I-negative
#
# new sentence
# I'm O
#
# at O
#
# Hospital I-negative
#
# Sultanah I-neutral
#
# Aminah I-neutral
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/cy3xgKxD3P is tagged as UNK and the this arg_max_y e(https://t.co/cy3xgKxD3P|y) is I-negative
# https://t.co/cy3xgKxD3P I-negative
#
# new sentence
# I'm O
#
# at O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# City I-neutral
#
# Square I-neutral
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/V5WQw9596E O
#
# new sentence
# I'm O
#
# at O
#
# nex B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/gkKnmSR535 is tagged as UNK and the this arg_max_y e(https://t.co/gkKnmSR535|y) is I-negative
# https://t.co/gkKnmSR535 I-negative
#
# new sentence
# I'm O
#
# at O
#
# Nusa B-neutral
# Height I-positive
#
# Apartment I-neutral
#
# w O
#
# / O
#
# @nrszlinx O
#
# https://t.co/6R4PX2KQ6o is tagged as UNK and the this arg_max_y e(https://t.co/6R4PX2KQ6o|y) is I-negative
# https://t.co/6R4PX2KQ6o I-negative
#
# new sentence
# regram B-negative
#
# moraglovesjesusAmennnn is tagged as UNK and the this arg_max_y e(moraglovesjesusAmennnn|y) is I-negative
# moraglovesjesusAmennnn I-negative
#
# @ O
#
# Active B-neutral
#
# Life I-neutral
#
# Center I-positive
#
# https://t.co/hUsKosrNJd is tagged as UNK and the this arg_max_y e(https://t.co/hUsKosrNJd|y) is I-negative
# https://t.co/hUsKosrNJd I-negative
#
# new sentence
# Love-hate is tagged as UNK and the this arg_max_y e(Love-hate|y) is I-negative
# Love-hate I-negative
#
# relationship B-negative
#
# with O
#
# this O
#
# one I-negative
#
# . O
#
# @ O
#
# Johor B-neutral
#
# https://t.co/b1AlCZtzWA is tagged as UNK and the this arg_max_y e(https://t.co/b1AlCZtzWA|y) is I-negative
# https://t.co/b1AlCZtzWA I-negative
#
# new sentence
# Well I-positive
#
# well O
#
# well O
#
# a O
#
# desperate O
#
# one I-negative
#
# aren't O
#
# you B-negative
#
# ? O
#
# new sentence
# Creativity is tagged as UNK and the this arg_max_y e(Creativity|y) is I-negative
# Creativity I-negative
#
# should O
#
# extend is tagged as UNK and the this arg_max_y e(extend|y) is I-negative
# extend I-negative
#
# to O
#
# people B-negative
#
# beyond O
#
# this O
#
# room I-positive
#
# ; O
#
# it O
#
# starts O
#
# from O
#
# the O
#
# bottom I-positive
#
# up O
#
# - O
#
# Dr B-neutral
#
# van I-neutral
#
# Breda I-neutral
#
# #NewFrontiers B-neutral
#
# #FutureEconomy O
#
# new sentence
# I'm O
#
# at O
#
# VivoCity B-neutral
#
# in O
#
# Singapore B-neutral
#
# w O
#
# / O
#
# @xinyi0606 is tagged as UNK and the this arg_max_y e(@xinyi0606|y) is I-negative
# @xinyi0606 I-negative
#
# https://t.co/UFqazKbpfD is tagged as UNK and the this arg_max_y e(https://t.co/UFqazKbpfD|y) is I-negative
# https://t.co/UFqazKbpfD I-negative
#
# new sentence
# I'm O
#
# at O
#
# Brix is tagged as UNK and the this arg_max_y e(Brix|y) is I-negative
# Brix I-negative
#
# in O
#
# Singapore B-neutral
#
# https://t.co/yBi41NwJGb is tagged as UNK and the this arg_max_y e(https://t.co/yBi41NwJGb|y) is I-negative
# https://t.co/yBi41NwJGb I-negative
#
# new sentence
# I'm O
#
# at O
#
# Outram B-neutral
#
# Park I-neutral
#
# MRT I-neutral
#
# Interchange I-neutral
#
# ( I-neutral
#
# EW16 I-neutral
#
# / O
#
# NE3 I-neutral
#
# ) I-neutral
#
# - O
#
# @smrt_singapore B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/D3AtvGnBIX is tagged as UNK and the this arg_max_y e(https://t.co/D3AtvGnBIX|y) is I-negative
# https://t.co/D3AtvGnBIX I-negative
#
# new sentence
# I'm O
#
# at O
#
# Singapore B-neutral
#
# @ChangiAirport B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/VyYwHieabA O
#
# new sentence
# I'm O
#
# at O
#
# McDonald's B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/2H0l29Vh3s O
#
# new sentence
# Twitter B-negative
#
# is O
#
# a O
#
# tool I-neutral
#
# for O
#
# distilling is tagged as UNK and the this arg_max_y e(distilling|y) is I-negative
# distilling I-negative
#
# understanding O
#
# of I-negative
#
# the O
#
# world O
#
# into O
#
# the O
#
# mostdigestible is tagged as UNK and the this arg_max_y e(mostdigestible|y) is I-negative
# mostdigestible I-negative
#
# format is tagged as UNK and the this arg_max_y e(format|y) is I-negative
# format I-negative
#
# possible O
#
# . O
#
# ~ O
#
# @JoshConstine is tagged as UNK and the this arg_max_y e(@JoshConstine|y) is I-negative
# @JoshConstine I-negative
#
# new sentence
# Checking is tagged as UNK and the this arg_max_y e(Checking|y) is I-negative
# Checking I-negative
#
# my O
#
# email O
#
# every O
#
# 20mins is tagged as UNK and the this arg_max_y e(20mins|y) is I-negative
# 20mins I-negative
#
# is O
#
# stressful O
#
# ! O
#
# new sentence
# You're O
#
# the O
#
# only O
#
# thing O
#
# I O
#
# wanna O
#
# touch O
#
# ... O
#
# @ O
#
# National B-neutral
#
# Gallery I-negative
#
# Singapore B-neutral
#
# https://t.co/feZDQHOmTZ is tagged as UNK and the this arg_max_y e(https://t.co/feZDQHOmTZ|y) is I-negative
# https://t.co/feZDQHOmTZ I-negative
#
# new sentence
# I'm O
#
# at O
#
# Bus B-neutral
#
# Stop I-neutral
#
# 77139 is tagged as UNK and the this arg_max_y e(77139|y) is I-negative
# 77139 I-negative
#
# ( I-neutral
#
# Blk B-neutral
#
# 582 is tagged as UNK and the this arg_max_y e(582|y) is I-negative
# 582 I-negative
#
# ) I-neutral
#
# in O
#
# Pasir B-neutral
#
# Ris I-neutral
#
# , I-neutral
#
# Singapore B-neutral
#
# https://t.co/uJtg6OnMDb is tagged as UNK and the this arg_max_y e(https://t.co/uJtg6OnMDb|y) is I-negative
# https://t.co/uJtg6OnMDb I-negative
#
# new sentence
# Finally O
#
# ( I-neutral
#
# @ O
#
# Shanice's is tagged as UNK and the this arg_max_y e(Shanice's|y) is I-negative
# Shanice's I-negative
#
# Cribbb I-neutral
#
# in O
#
# Ang B-neutral
#
# Mo I-neutral
#
# Kio I-neutral
#
# ) I-neutral
#
# https://t.co/T8yErpNYJ0 is tagged as UNK and the this arg_max_y e(https://t.co/T8yErpNYJ0|y) is I-negative
# https://t.co/T8yErpNYJ0 I-negative
#
# new sentence
# I'm O
#
# at O
#
# KESH'S is tagged as UNK and the this arg_max_y e(KESH'S|y) is I-negative
# KESH'S I-negative
#
# CRIB O
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/na1VKdRJrT is tagged as UNK and the this arg_max_y e(https://t.co/na1VKdRJrT|y) is I-negative
# https://t.co/na1VKdRJrT I-negative
#
# new sentence
# Y O
#
# not O
#
# kan I-positive
#
# .. O
#
# been O
#
# a O
#
# months O
#
# plus O
#
# not O
#
# being O
#
# here O
#
# ( I-neutral
#
# @ O
#
# Crescent I-neutral
#
# Clinic I-negative
#
# & I-positive
#
# Surgery I-negative
#
# ) I-neutral
#
# https://t.co/gVrsQipZdc O
#
# new sentence
# Just O
#
# posted O
#
# a O
#
# photo O
#
# @ O
#
# Marina B-neutral
#
# Bay I-positive
#
# Singapore B-neutral
#
# https://t.co/ypQhNQGQK5 is tagged as UNK and the this arg_max_y e(https://t.co/ypQhNQGQK5|y) is I-negative
# https://t.co/ypQhNQGQK5 I-negative
#
# new sentence
# I'm O
#
# at O
#
# Terminal I-neutral
#
# 2 I-positive
#
# Departure I-positive
#
# Hall I-neutral
#
# - O
#
# @fansofchangi O
#
# in O
#
# Singapore B-neutral
#
# https://t.co/3yzo8DGbao is tagged as UNK and the this arg_max_y e(https://t.co/3yzo8DGbao|y) is I-negative
# https://t.co/3yzo8DGbao I-negative
#
# new sentence
# Hanging O
#
# with O
#
# the O
#
# aussie B-neutral
#
# kid B-negative
#
# ( I-neutral
#
# @ O
#
# ION B-neutral
#
# Orchard B-neutral
#
# in O
#
# Singapore B-neutral
#
# ) I-neutral
#
# https://t.co/I8KgIonEyo O
#
# new sentence
# You I-positive
#
# did O
#
# your O
#
# best O
#
# , I-neutral
#
# salute is tagged as UNK and the this arg_max_y e(salute|y) is I-negative
# salute I-negative
#
# Cr7 is tagged as UNK and the this arg_max_y e(Cr7|y) is I-negative
# Cr7 I-negative
#
# new sentence
# Taka's is tagged as UNK and the this arg_max_y e(Taka's|y) is I-negative
# Taka's I-negative
#
# counter O
#
# have O
#
# this O
#
# medicated O
#
# oil O
#
# , I-neutral
#
# kuih B-positive
#
# raya I-negative
#
# . O
#
# But O
#
# Tangs B-neutral
#
# vivo B-neutral
#
# still O
#
# the O
#
# best O
#
# ah B-positive
#
# new sentence
# I'm O
#
# at O
#
# Yishun B-neutral
#
# MRT I-neutral
#
# Station I-neutral
#
# ( I-neutral
#
# NS13 I-neutral
#
# ) I-neutral
#
# - O
#
# @smrt_singapore B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/ThnOTegjry O
#
# new sentence
# I'm O
#
# at O
#
# Peace B-neutral
#
# Centre I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/UAELwlz5Et O
#
# new sentence
# I'm O
#
# at O
#
# Bedok B-neutral
#
# MRT I-neutral
#
# Station I-neutral
#
# ( I-neutral
#
# EW5 I-neutral
#
# ) I-neutral
#
# - O
#
# @smrt_singapore B-neutral
#
# in O
#
# Singapore B-neutral
#
# w O
#
# / O
#
# @brandonneo B-neutral
#
# https://t.co/j9FDz2Enrw is tagged as UNK and the this arg_max_y e(https://t.co/j9FDz2Enrw|y) is I-negative
# https://t.co/j9FDz2Enrw I-negative
#
# new sentence
# dd O
#
# ( I-neutral
#
# with O
#
# Robby is tagged as UNK and the this arg_max_y e(Robby|y) is I-negative
# Robby I-negative
#
# and O
#
# Fryska is tagged as UNK and the this arg_max_y e(Fryska|y) is I-negative
# Fryska I-negative
#
# at O
#
# RM B-positive
#
# Goyang is tagged as UNK and the this arg_max_y e(Goyang|y) is I-negative
# Goyang I-negative
#
# lidah O
#
# ) I-neutral
#
# [ O
#
# pic O
#
# ] O
#
# — O
#
# https://t.co/hr29QgZzvZ is tagged as UNK and the this arg_max_y e(https://t.co/hr29QgZzvZ|y) is I-negative
# https://t.co/hr29QgZzvZ I-negative
#
# new sentence
# I'm O
#
# at O
#
# Yew B-neutral
#
# Tee I-neutral
#
# MRT I-neutral
#
# Station I-neutral
#
# ( I-neutral
#
# NS5 I-neutral
#
# ) I-neutral
#
# - O
#
# @smrt_singapore B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/9at3sYiXDb is tagged as UNK and the this arg_max_y e(https://t.co/9at3sYiXDb|y) is I-negative
# https://t.co/9at3sYiXDb I-negative
#
# new sentence
# I'm O
#
# at O
#
# Anchorvale B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/TvOeLZMG98 O
#
# new sentence
# happenstancecafe is tagged as UNK and the this arg_max_y e(happenstancecafe|y) is I-negative
# happenstancecafe I-negative
#
# #ThaiMilkTeaCheesecake is tagged as UNK and the this arg_max_y e(#ThaiMilkTeaCheesecake|y) is I-negative
# #ThaiMilkTeaCheesecake I-negative
#
# $ O
#
# 6.50 O
#
# ( I-neutral
#
# per O
#
# slice O
#
# ) I-neutral
#
# @ O
#
# … O
#
# https://t.co/FUiwFcKZtf is tagged as UNK and the this arg_max_y e(https://t.co/FUiwFcKZtf|y) is I-negative
# https://t.co/FUiwFcKZtf I-negative
#
# new sentence
# I'm O
#
# at O
#
# Singapore B-neutral
#
# City I-neutral
#
# https://t.co/bNuphRPoxU is tagged as UNK and the this arg_max_y e(https://t.co/bNuphRPoxU|y) is I-negative
# https://t.co/bNuphRPoxU I-negative
#
# new sentence
# A I-positive
#
# wonderful O
#
# MNF O
#
# raya I-negative
#
# @ O
#
# Straits B-negative
#
# View I-positive
#
# , I-neutral
#
# Johore I-positive
#
# https://t.co/4eOtBpy0ct O
#
# new sentence
# I'm O
#
# at O
#
# Little B-negative
#
# India I-positive
#
# in O
#
# Singapore B-neutral
#
# https://t.co/X7UJ1Ogq27 is tagged as UNK and the this arg_max_y e(https://t.co/X7UJ1Ogq27|y) is I-negative
# https://t.co/X7UJ1Ogq27 I-negative
#
# new sentence
# I'm O
#
# at O
#
# Darts I-neutral
#
# Legend I-neutral
#
# https://t.co/kNvXx4W3nK is tagged as UNK and the this arg_max_y e(https://t.co/kNvXx4W3nK|y) is I-negative
# https://t.co/kNvXx4W3nK I-negative
#
# new sentence
# Me I-positive
#
# : I-negative
#
# " I-negative
#
# Bleach is tagged as UNK and the this arg_max_y e(Bleach|y) is I-negative
# Bleach I-negative
#
# have O
#
# eaten O
#
# my O
#
# brains O
#
# " I-negative
#
# Phoebe is tagged as UNK and the this arg_max_y e(Phoebe|y) is I-negative
# Phoebe I-negative
#
# : I-negative
#
# " I-negative
#
# Bleach is tagged as UNK and the this arg_max_y e(Bleach|y) is I-negative
# Bleach I-negative
#
# somemore O
#
# " I-negative
#
# new sentence
# I'm O
#
# at O
#
# UB B-neutral
#
# . O
#
# One I-positive
#
# in O
#
# Singapore B-neutral
#
# https://t.co/fEeTPRp1Qe O
#
# new sentence
# Oh I-negative
#
# , I-neutral
#
# lo O
#
# and O
#
# behold is tagged as UNK and the this arg_max_y e(behold|y) is I-negative
# behold I-negative
#
# , I-neutral
#
# Pixar is tagged as UNK and the this arg_max_y e(Pixar|y) is I-negative
# Pixar I-negative
#
# is O
#
# releasing O
#
# a O
#
# string is tagged as UNK and the this arg_max_y e(string|y) is I-negative
# string I-negative
#
# of I-negative
#
# sequels O
#
# in O
#
# the O
#
# next O
#
# few O
#
# years O
#
# . O
#
# If O
#
# they're O
#
# anything O
#
# like O
#
# #FindingDory B-negative
#
# , I-neutral
#
# no O
#
# thanks O
#
# . O
#
# new sentence
# I O
#
# finally O
#
# figured is tagged as UNK and the this arg_max_y e(figured|y) is I-negative
# figured I-negative
#
# out O
#
# what's O
#
# wrong O
#
# @lukehopewell is tagged as UNK and the this arg_max_y e(@lukehopewell|y) is I-negative
# @lukehopewell I-negative
#
# , I-neutral
#
# moments O
#
# is O
#
# missing O
#
# from O
#
# my O
#
# Twitter B-negative
#
# app I-positive
#
# #sadinsingapore is tagged as UNK and the this arg_max_y e(#sadinsingapore|y) is I-negative
# #sadinsingapore I-negative
#
# new sentence
# Syawal B-neutral
#
# Day I-positive
#
# 5 I-negative
#
# . O
#
# Let's O
#
# go I-negative
#
# . O
#
# #eid2016 O
#
# #ootd O
#
# @ O
#
# Yishun B-neutral
#
# Ring I-neutral
#
# Rd I-neutral
#
# https://t.co/p9V4zjFP2M is tagged as UNK and the this arg_max_y e(https://t.co/p9V4zjFP2M|y) is I-negative
# https://t.co/p9V4zjFP2M I-negative
#
# new sentence
# I'm O
#
# at O
#
# Tolido's B-positive
#
# Espresso I-positive
#
# Nook I-positive
#
# in O
#
# Rochor B-neutral
#
# , I-neutral
#
# Singapore B-neutral
#
# https://t.co/6dezDCL7lG is tagged as UNK and the this arg_max_y e(https://t.co/6dezDCL7lG|y) is I-negative
# https://t.co/6dezDCL7lG I-negative
#
# new sentence
# This O
#
# DHL B-negative
#
# scam O
#
# has O
#
# been O
#
# calling O
#
# every O
#
# single O
#
# deskphone is tagged as UNK and the this arg_max_y e(deskphone|y) is I-negative
# deskphone I-negative
#
# in O
#
# my O
#
# office O
#
# . O
#
# Freaking is tagged as UNK and the this arg_max_y e(Freaking|y) is I-negative
# Freaking I-negative
#
# annoying O
#
# ah B-positive
#
# new sentence
# I O
#
# miss O
#
# you B-negative
#
# but O
#
# i O
#
# hate O
#
# you B-negative
#
# ma O
#
# girll is tagged as UNK and the this arg_max_y e(girll|y) is I-negative
# girll I-negative
#
# @ O
#
# Etnic B-neutral
#
# Cafe I-neutral
#
# Jalan B-negative
#
# Sengkawit is tagged as UNK and the this arg_max_y e(Sengkawit|y) is I-negative
# Sengkawit I-negative
#
# Gang I-neutral
#
# Niaga is tagged as UNK and the this arg_max_y e(Niaga|y) is I-negative
# Niaga I-negative
#
# https://t.co/MJtlY1kqsK is tagged as UNK and the this arg_max_y e(https://t.co/MJtlY1kqsK|y) is I-negative
# https://t.co/MJtlY1kqsK I-negative
#
# new sentence
# @yeolindy_ O
#
# @billytwj is tagged as UNK and the this arg_max_y e(@billytwj|y) is I-negative
# @billytwj I-negative
#
# backup O
#
# to O
#
# google B-positive
#
# drive I-negative
#
# also O
#
# can O
#
# ! O
#
# ! O
#
# ! O
#
# new sentence
# this O
#
# game B-positive
#
# is O
#
# taking O
#
# over O
#
# my O
#
# life O
#
# . O
#
# first O
#
# it O
#
# was O
#
# tsum is tagged as UNK and the this arg_max_y e(tsum|y) is I-negative
# tsum I-negative
#
# tsum is tagged as UNK and the this arg_max_y e(tsum|y) is I-negative
# tsum I-negative
#
# and O
#
# now O
#
# this O
#
# . O
#
# I O
#
# swear O
#
# to O
#
# god B-positive
#
# these O
#
# disney B-positive
#
# games I-neutral
#
# are O
#
# addictive O
#
# . O
#
# new sentence
# Just O
#
# posted O
#
# a O
#
# photo O
#
# @ O
#
# Merlion B-neutral
#
# ( I-neutral
#
# The B-neutral
#
# Statue I-positive
#
# of I-negative
#
# Mermaid-Lion I-positive
#
# ) I-neutral
#
# , I-neutral
#
# Marina B-neutral
#
# Bay I-positive
#
# , I-neutral
#
# Singapore B-neutral
#
# https://t.co/lIE30INdv6 is tagged as UNK and the this arg_max_y e(https://t.co/lIE30INdv6|y) is I-negative
# https://t.co/lIE30INdv6 I-negative
#
# new sentence
# When O
#
# #pegoretti is tagged as UNK and the this arg_max_y e(#pegoretti|y) is I-negative
# #pegoretti I-negative
#
# met O
#
# #lynskey is tagged as UNK and the this arg_max_y e(#lynskey|y) is I-negative
# #lynskey I-negative
#
# and O
#
# Indy B-neutral
#
# with O
#
# coolspirits is tagged as UNK and the this arg_max_y e(coolspirits|y) is I-negative
# coolspirits I-negative
#
# and O
#
# Adrian B-neutral
#
# @ O
#
# Sixth I-neutral
#
# Avenue I-neutral
#
# , I-neutral
#
# Singapor B-neutral
#
# e I-neutral
#
# https://t.co/l2ylPfYcS4 is tagged as UNK and the this arg_max_y e(https://t.co/l2ylPfYcS4|y) is I-negative
# https://t.co/l2ylPfYcS4 I-negative
#
# new sentence
# Just O
#
# posted O
#
# a O
#
# photo O
#
# @ O
#
# Barelang B-positive
#
# Brige is tagged as UNK and the this arg_max_y e(Brige|y) is I-negative
# Brige I-negative
#
# Batam I-positive
#
# - O
#
# Indonesia I-neutral
#
# https://t.co/vlTgl5zBci is tagged as UNK and the this arg_max_y e(https://t.co/vlTgl5zBci|y) is I-negative
# https://t.co/vlTgl5zBci I-negative
#
# new sentence
# J16 is tagged as UNK and the this arg_max_y e(J16|y) is I-negative
# J16 I-negative
#
# invest O
#
# with O
#
# D15 is tagged as UNK and the this arg_max_y e(D15|y) is I-negative
# D15 I-negative
#
# { O
#
# 25/6 is tagged as UNK and the this arg_max_y e(25/6|y) is I-negative
# 25/6 I-negative
#
# / O
#
# 2016 I-positive
#
# } O
#
# @ O
#
# Home I-negative
#
# Team B-negative
#
# Academy I-neutral
#
# https://t.co/mDioWkilYm is tagged as UNK and the this arg_max_y e(https://t.co/mDioWkilYm|y) is I-negative
# https://t.co/mDioWkilYm I-negative
#
# new sentence
# I'm O
#
# at O
#
# Hougang B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/aEQnWizDbm is tagged as UNK and the this arg_max_y e(https://t.co/aEQnWizDbm|y) is I-negative
# https://t.co/aEQnWizDbm I-negative
#
# new sentence
# With O
#
# belly I-positive
#
# at O
#
# Ice I-positive
#
# factory I-neutral
#
# — O
#
# https://t.co/3GeV7QzXbv is tagged as UNK and the this arg_max_y e(https://t.co/3GeV7QzXbv|y) is I-negative
# https://t.co/3GeV7QzXbv I-negative
#
# new sentence
# I'm O
#
# at O
#
# Restauran B-neutral
#
# Tasek I-negative
#
# Curry I-neutral
#
# House I-neutral
#
# in O
#
# Masai B-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/7SJXT4K5Iw is tagged as UNK and the this arg_max_y e(https://t.co/7SJXT4K5Iw|y) is I-negative
# https://t.co/7SJXT4K5Iw I-negative
#
# new sentence
# Squad I-positive
#
# ! O
#
# #Goals is tagged as UNK and the this arg_max_y e(#Goals|y) is I-negative
# #Goals I-negative
#
# @ O
#
# Universal B-positive
#
# Studios I-positive
#
# Singapore B-neutral
#
# https://t.co/PFbqIVn3R6 is tagged as UNK and the this arg_max_y e(https://t.co/PFbqIVn3R6|y) is I-negative
# https://t.co/PFbqIVn3R6 I-negative
#
# new sentence
# All O
#
# the O
#
# best O
#
# to O
#
# #FRA B-positive
#
# for O
#
# tonight's O
#
# #Euro2016Final B-positive
#
# #EURO2016 B-positive
#
# @equipedefrance is tagged as UNK and the this arg_max_y e(@equipedefrance|y) is I-negative
# @equipedefrance I-negative
#
# Bonne is tagged as UNK and the this arg_max_y e(Bonne|y) is I-negative
# Bonne I-negative
#
# chance O
#
# ! O
#
# ! O
#
# ! O
#
# new sentence
# I'm O
#
# at O
#
# Club I-positive
#
# Luxi I-neutral
#
# https://t.co/qTHJjlZBvL is tagged as UNK and the this arg_max_y e(https://t.co/qTHJjlZBvL|y) is I-negative
# https://t.co/qTHJjlZBvL I-negative
#
# new sentence
# rr O
#
# ( I-neutral
#
# at O
#
# VivoCity B-neutral
#
# ) I-neutral
#
# [ O
#
# pic O
#
# ] O
#
# — O
#
# https://t.co/4o2RedOmrD O
#
# new sentence
# I'm O
#
# at O
#
# Jurong B-neutral
#
# Point I-neutral
#
# in O
#
# Singapore B-neutral
#
# w O
#
# / O
#
# @xuantinggg O
#
# https://t.co/hlX0cIzO3v is tagged as UNK and the this arg_max_y e(https://t.co/hlX0cIzO3v|y) is I-negative
# https://t.co/hlX0cIzO3v I-negative
#
# new sentence
# luna B-neutral
#
# wining is tagged as UNK and the this arg_max_y e(wining|y) is I-negative
# wining I-negative
#
# is O
#
# so O
#
# adorable O
#
# ! O
#
# ! O
#
# ! O
#
# " I-negative
#
# really O
#
# ? O
#
# me O
#
# ? O
#
# why O
#
# would O
#
# i O
#
# get O
#
# chosen O
#
# ? O
#
# " I-negative
#
# and O
#
# then O
#
# she O
#
# decides is tagged as UNK and the this arg_max_y e(decides|y) is I-negative
# decides I-negative
#
# to O
# aegyo is tagged as UNK and the this arg_max_y e(aegyo|y) is I-negative
# aegyo I-negative
#
# with O
#
# " I-negative
#
# oppa O
#
# , I-neutral
#
# thank O
#
# you B-negative
#
# ~ O
#
# " I-negative
#
# im O
#
# - O
#
# new sentence
# I'm O
#
# at O
#
# McDonald's B-neutral
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# w O
#
# / O
#
# @reqzy_ O
#
# https://t.co/PC8zzQLUAr is tagged as UNK and the this arg_max_y e(https://t.co/PC8zzQLUAr|y) is I-negative
# https://t.co/PC8zzQLUAr I-negative
#
# new sentence
# Wow O
#
# having O
#
# flu O
#
# while O
#
# using O
#
# bedak is tagged as UNK and the this arg_max_y e(bedak|y) is I-negative
# bedak I-negative
#
# sejuk is tagged as UNK and the this arg_max_y e(sejuk|y) is I-negative
# sejuk I-negative
#
# is O
#
# prolly O
#
# a O
#
# plus O
#
# point O
#
# cos O
#
# i O
#
# dont O
#
# have O
#
# to O
#
# smell O
#
# the O
#
# unpleasant O
#
# scent O
#
# hahahaha O
#
# new sentence
# @freegavino is tagged as UNK and the this arg_max_y e(@freegavino|y) is I-negative
# @freegavino I-negative
#
# would O
#
# you B-negative
#
# marry O
#
# him O
#
# in O
#
# skyrim is tagged as UNK and the this arg_max_y e(skyrim|y) is I-negative
# skyrim I-negative
#
# new sentence
# I'm O
#
# at O
#
# Restoran B-neutral
#
# Aliff I-neutral
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/AwoCkJjooT is tagged as UNK and the this arg_max_y e(https://t.co/AwoCkJjooT|y) is I-negative
# https://t.co/AwoCkJjooT I-negative
#
# new sentence
# I'm O
#
# at O
#
# Dynac B-neutral
#
# Engineering I-negative
#
# Fabrication I-neutral
#
# Workshop I-positive
#
# in O
#
# Tg B-neutral
#
# Langsat I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/nPyPFv0vbI O
#
# new sentence
# We're O
#
# #hiring O
#
# ! O
#
# Click O
#
# to O
#
# apply O
#
# : I-negative
#
# Assistant I-neutral
#
# Manager I-positive
#
# - O
#
# https://t.co/5w1WNYLwr7 is tagged as UNK and the this arg_max_y e(https://t.co/5w1WNYLwr7|y) is I-negative
# https://t.co/5w1WNYLwr7 I-negative
#
# #Job O
#
# #Accounting O
#
# #Singapore B-neutral
#
# #Jobs O
#
# #CareerArc O
#
# new sentence
# I'm O
#
# at O
#
# Eunos B-neutral
#
# MRT I-neutral
#
# Station I-neutral
#
# ( I-neutral
#
# EW7 I-neutral
#
# ) I-neutral
#
# - O
#
# @smrt_singapore B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/W73nUncZlf is tagged as UNK and the this arg_max_y e(https://t.co/W73nUncZlf|y) is I-negative
# https://t.co/W73nUncZlf I-negative
#
# new sentence
# #flowerdome B-neutral
#
# #gardensbythebay B-neutral
#
# @ O
#
# Flower B-neutral
#
# Dome I-neutral
#
# , I-neutral
#
# Gardens B-neutral
#
# by I-neutral
#
# the O
#
# Bay I-positive
#
# https://t.co/UPuSnvUiLl is tagged as UNK and the this arg_max_y e(https://t.co/UPuSnvUiLl|y) is I-negative
# https://t.co/UPuSnvUiLl I-negative
#
# new sentence
# Yesterday O
#
# big B-positive
#
# portion O
#
# of I-negative
#
# Japanese I-positive
#
# Fried I-negative
#
# Curry I-neutral
#
# Chicken I-negative
#
# Rice I-neutral
#
# for O
#
# … O
#
# https://t.co/31eODWnTgG is tagged as UNK and the this arg_max_y e(https://t.co/31eODWnTgG|y) is I-negative
# https://t.co/31eODWnTgG I-negative
#
# new sentence
# Thanks O
#
# for O
#
# making O
#
# me O
#
# go I-negative
#
# to O
#
# a O
#
# band O
#
# concert I-positive
#
# alone O
#
# for O
#
# the O
#
# first O
#
# time O
#
# . O
#
# @ O
#
# Singapore B-neutral
#
# Conference I-positive
#
# Hall I-neutral
#
# https://t.co/fX6a6L6qam is tagged as UNK and the this arg_max_y e(https://t.co/fX6a6L6qam|y) is I-negative
# https://t.co/fX6a6L6qam I-negative
#
# new sentence
# I'm O
#
# at O
#
# 93 I-positive
#
# Tuas B-negative
#
# Bay I-positive
#
# drive I-negative
#
# https://t.co/ZJLCyojE6K is tagged as UNK and the this arg_max_y e(https://t.co/ZJLCyojE6K|y) is I-negative
# https://t.co/ZJLCyojE6K I-negative
#
# new sentence
# I'm O
#
# at O
#
# Prince's B-neutral
#
# Club I-positive
#
# https://t.co/Sfv3ES7Dqu O
#
# new sentence
# Come O
#
# on O
#
# , I-neutral
#
# I O
#
# need O
#
# to O
#
# strike O
#
# a O
#
# 4D B-neutral
#
# now O
#
# hahaha O
#
# new sentence
# Tune O
#
# in O
#
# to O
#
# Bollyone B-neutral
#
# HD I-neutral
#
# if O
#
# you B-negative
#
# bored O
#
# with O
#
# Dilwale B-neutral
#
# https://t.co/X9rTRwr8s6 O
#
# new sentence
# I O
#
# am O
#
# out O
#
# of I-negative
#
# the O
#
# Yong I-positive
#
# Ma I-positive
#
# Plastic is tagged as UNK and the this arg_max_y e(Plastic|y) is I-negative
# Plastic I-negative
#
# SDN is tagged as UNK and the this arg_max_y e(SDN|y) is I-negative
# SDN I-negative
#
# BHD I-neutral
#
# . O
#
# Because B-neutral
#
# not O
#
# good O
#
# . O
#
# Without O
#
# proper O
#
# notice O
#
# in O
#
# company B-positive
#
# . O
#
# new sentence
# spencer is tagged as UNK and the this arg_max_y e(spencer|y) is I-negative
# spencer I-negative
#
# burnt O
#
# down O
#
# carly is tagged as UNK and the this arg_max_y e(carly|y) is I-negative
# carly I-negative
#
# s I-positive
#
# room I-positive
#
# trying O
#
# to O
#
# build O
#
# this O
#
# lmao O
#
# https://t.co/FuTwmSXfGU is tagged as UNK and the this arg_max_y e(https://t.co/FuTwmSXfGU|y) is I-negative
# https://t.co/FuTwmSXfGU I-negative
#
# new sentence
# I'm O
#
# at O
#
# Tampines B-neutral
#
# MRT I-neutral
#
# Station I-neutral
#
# ( I-neutral
#
# EW2 I-neutral
#
# / O
#
# DT32 I-neutral
#
# ) I-neutral
#
# - O
#
# @smrt_singapore B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/SmTMimuWSD is tagged as UNK and the this arg_max_y e(https://t.co/SmTMimuWSD|y) is I-negative
# https://t.co/SmTMimuWSD I-negative
#
# new sentence
# Convo is tagged as UNK and the this arg_max_y e(Convo|y) is I-negative
# Convo I-negative
#
# btwn is tagged as UNK and the this arg_max_y e(btwn|y) is I-negative
# btwn I-negative
#
# ophy is tagged as UNK and the this arg_max_y e(ophy|y) is I-negative
# ophy I-negative
#
# , I-neutral
#
# Dan B-negative
#
# and O
#
# I O
#
# : I-negative
#
# Them is tagged as UNK and the this arg_max_y e(Them|y) is I-negative
# Them I-negative
#
# : I-negative
#
# what O
#
# if O
#
# we O
#
# lived O
#
# ...
#
# recommend O
#
# anyone O
#
# for O
#
# this O
#
# #job O
#
# ? O
#
# https://t.co/rfpGQSKrAR is tagged as UNK and the this arg_max_y e(https://t.co/rfpGQSKrAR|y) is I-negative
# https://t.co/rfpGQSKrAR I-negative
#
# #Engineering O
#
# #Singapore B-neutral
#
# , I-neutral
#
# SINGAPORE B-negative
#
# #Hiring O
#
# new sentence
# I'm O
#
# at O
#
# Vatos B-neutral
#
# Urban I-neutral
#
# Tacos I-neutral
#
# https://t.co/gdjqhqxTk5 is tagged as UNK and the this arg_max_y e(https://t.co/gdjqhqxTk5|y) is I-negative
# https://t.co/gdjqhqxTk5 I-negative
#
# new sentence
# Bila B-negative
#
# byk is tagged as UNK and the this arg_max_y e(byk|y) is I-negative
# byk I-negative
#
# sgt is tagged as UNK and the this arg_max_y e(sgt|y) is I-negative
# sgt I-negative
#
# pending is tagged as UNK and the this arg_max_y e(pending|y) is I-negative
# pending I-negative
#
# meeting B-negative
#
# the O
#
# ladies O
#
# . O
#
# Usrah is tagged as UNK and the this arg_max_y e(Usrah|y) is I-negative
# Usrah I-negative
#
# meeting B-negative
#
# . O
#
# Class B-positive
#
# and O
#
# stuffs O
#
# . O
#
# Allāh B-neutral
#
# packed O
#
# nyee is tagged as UNK and the this arg_max_y e(nyee|y) is I-negative
# nyee I-negative
#
# new sentence
# I'm O
#
# at O
#
# Junction I-neutral
#
# 8 I-positive
#
# Shopping I-neutral
#
# Centre I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/cGMKWAPaVK is tagged as UNK and the this arg_max_y e(https://t.co/cGMKWAPaVK|y) is I-negative
# https://t.co/cGMKWAPaVK I-negative
#
# new sentence
# I'm O
#
# at O
#
# Woodlands B-neutral
#
# Old I-negative
#
# Check O
#
# Point I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/VVY12lFKBX is tagged as UNK and the this arg_max_y e(https://t.co/VVY12lFKBX|y) is I-negative
# https://t.co/VVY12lFKBX I-negative
#
# new sentence
# With O
#
# girlfriends O
#
# ( I-neutral
#
# @ O
#
# Sushi I-negative
#
# King I-positive
#
# in O
#
# Skudai B-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# Bahru I-neutral
#
# ) I-neutral
#
# https://t.co/wA7dGZNCri is tagged as UNK and the this arg_max_y e(https://t.co/wA7dGZNCri|y) is I-negative
# https://t.co/wA7dGZNCri I-negative
#
# new sentence
# I'm O
#
# at O
#
# AEON B-neutral
#
# Bukit I-neutral
#
# Indah I-neutral
#
# Shopping I-neutral
#
# Centre I-neutral
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/WezEGs4oJ2 is tagged as UNK and the this arg_max_y e(https://t.co/WezEGs4oJ2|y) is I-negative
# https://t.co/WezEGs4oJ2 I-negative
#
# new sentence
# Superb is tagged as UNK and the this arg_max_y e(Superb|y) is I-negative
# Superb I-negative
#
# restaurant I-neutral
#
# wei I-positive
#
# . O
#
# ( I-neutral
#
# @ O
#
# Long O
#
# Beach I-positive
#
# Seafood I-neutral
#
# Restaurant I-neutral
#
# in O
#
# Singapore B-neutral
#
# ) I-neutral
#
# https://t.co/8qOipbYgpl is tagged as UNK and the this arg_max_y e(https://t.co/8qOipbYgpl|y) is I-negative
# https://t.co/8qOipbYgpl I-negative
#
# new sentence
# @Trump_Videos is tagged as UNK and the this arg_max_y e(@Trump_Videos|y) is I-negative
# @Trump_Videos I-negative
#
# @HillaryClinton B-negative
#
# What I-positive
#
# is O
#
# life O
#
# to O
#
# become O
#
# when O
#
# these O
#
# people B-negative
#
# reach O
#
# 20 O
#
# % O
#
# of I-negative
#
# the O
#
# population O
#
# ? O
#
# Pig I-neutral
#
# SOBAMA is tagged as UNK and the this arg_max_y e(SOBAMA|y) is I-negative
# SOBAMA I-negative
#
# will O
#
# be O
#
# dead O
#
# & I-positive
#
# cursed O
#
# forever O
#
# new sentence
# #InternetFriendPositivity is tagged as UNK and the this arg_max_y e(#InternetFriendPositivity|y) is I-negative
# #InternetFriendPositivity I-negative
#
# US B-negative
#
# dog O
#
# out O
#
# of I-negative
#
# south B-neutral
#
# china B-negative
#
# sea O
#
# . O
#
# ISIS B-negative
#
# will O
#
# make O
#
# next O
#
# 911 O
#
# to O
#
# US B-negative
#
# . O
#
# — O
#
# — O
#
# To O
#
# USA B-negative
#
# DOG B-neutral
#
# https://t.co/lqBQcXizm3 is tagged as UNK and the this arg_max_y e(https://t.co/lqBQcXizm3|y) is I-negative
# https://t.co/lqBQcXizm3 I-negative
#
# new sentence
# We O
#
# are O
#
# the O
#
# show I-negative
#
# bag I-positive
#
# sponsors O
#
# at O
#
# @WaterWeekSG B-positive
#
# . O
#
# Visit O
#
# us O
#
# at O
#
# booth B-neutral
#
# no O
#
# . O
#
# B2 I-neutral
#
# - O
#
# H30 I-neutral
#
# to O
#
# meet O
#
# our O
#
# GRP B-neutral
#
# / O
#
# FRP is tagged as UNK and the this arg_max_y e(FRP|y) is I-negative
# FRP I-negative
#
# experts O
#
# . O
#
# #SIWW2016 B-positive
#
# https://t.co/SbivpsezPP is tagged as UNK and the this arg_max_y e(https://t.co/SbivpsezPP|y) is I-negative
# https://t.co/SbivpsezPP I-negative
#
# new sentence
# I'm O
#
# at O
#
# Eastpoint B-neutral
#
# Mall I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/de7RxoILFG is tagged as UNK and the this arg_max_y e(https://t.co/de7RxoILFG|y) is I-negative
# https://t.co/de7RxoILFG I-negative
#
# new sentence
# I'm O
#
# at O
#
# @ZoukSingapore B-neutral
#
# in O
#
# Singapore B-neutral
#
# w O
#
# / O
#
# @lxcifur_ is tagged as UNK and the this arg_max_y e(@lxcifur_|y) is I-negative
# @lxcifur_ I-negative
#
# https://t.co/qVdLjqbF4g is tagged as UNK and the this arg_max_y e(https://t.co/qVdLjqbF4g|y) is I-negative
# https://t.co/qVdLjqbF4g I-negative
#
# new sentence
# #pathdaily O
#
# ( I-neutral
#
# at O
#
# Juwata B-neutral
#
# International I-neutral
#
# Airport I-neutral
#
# ( I-neutral
#
# TRK I-positive
#
# ) I-neutral
#
# ) I-neutral
#
# [ O
#
# pic O
#
# ] O
#
# — O
#
# https://t.co/tnMn2awX3S is tagged as UNK and the this arg_max_y e(https://t.co/tnMn2awX3S|y) is I-negative
# https://t.co/tnMn2awX3S I-negative
#
# new sentence
# With O
#
# Siti B-positive
#
# , I-neutral
#
# Yulia is tagged as UNK and the this arg_max_y e(Yulia|y) is I-negative
# Yulia I-negative
#
# , I-neutral
#
# and O
#
# 3 I-negative
#
# others O
#
# at O
#
# @kfcindonesia B-neutral
#
# — O
#
# https://t.co/bbTKlCPlYk is tagged as UNK and the this arg_max_y e(https://t.co/bbTKlCPlYk|y) is I-negative
# https://t.co/bbTKlCPlYk I-negative
#
# new sentence
# I'm O
#
# at O
#
# JDT B-neutral
#
# CAFE I-neutral
#
# https://t.co/XOm82nJJ1y is tagged as UNK and the this arg_max_y e(https://t.co/XOm82nJJ1y|y) is I-negative
# https://t.co/XOm82nJJ1y I-negative
#
# new sentence
# Wish O
# you B-negative
#
# speedy is tagged as UNK and the this arg_max_y e(speedy|y) is I-negative
# speedy I-negative
#
# recovery O
#
# , I-neutral
#
# my O
#
# love O
#
# . O
#
# @ O
#
# Singapore B-neutral
#
# General I-negative
#
# Hospital I-negative
#
# https://t.co/TfmNdrpxQl is tagged as UNK and the this arg_max_y e(https://t.co/TfmNdrpxQl|y) is I-negative
# https://t.co/TfmNdrpxQl I-negative
#
# new sentence
# I'm O
#
# at O
#
# Hougang B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/Rgnw6XJHOW is tagged as UNK and the this arg_max_y e(https://t.co/Rgnw6XJHOW|y) is I-negative
# https://t.co/Rgnw6XJHOW I-negative
#
# new sentence
# Owner O
#
# of I-negative
#
# the O
#
# whisky B-positive
#
# house B-negative
#
# today O
#
# :) O
#
# @ O
#
# Singapore B-neutral
#
# Changi B-neutral
#
# International I-neutral
#
# … O
#
# https://t.co/2BAUlKQyHE O
#
# new sentence
# Slaughterhouse B-neutral
#
# / O
#
# / O
#
# Monsters is tagged as UNK and the this arg_max_y e(Monsters|y) is I-negative
# Monsters I-negative
#
# In I-positive
#
# My O
#
# Head I-negative
#
# new sentence
# I'm O
#
# at O
#
# National B-neutral
#
# University I-neutral
#
# Hospital I-negative
#
# ( I-neutral
#
# NUH B-positive
#
# ) I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/FeU7Ordn9y is tagged as UNK and the this arg_max_y e(https://t.co/FeU7Ordn9y|y) is I-negative
# https://t.co/FeU7Ordn9y I-negative
#
# new sentence
# I'm O
#
# at O
#
# Blk B-neutral
#
# 232 is tagged as UNK and the this arg_max_y e(232|y) is I-negative
# 232 I-negative
#
# Pending B-neutral
#
# Road I-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/QlzNGk41Wl is tagged as UNK and the this arg_max_y e(https://t.co/QlzNGk41Wl|y) is I-negative
# https://t.co/QlzNGk41Wl I-negative
#
# new sentence
# time O
#
# to O
#
# repack O
#
# luggagee O
#
# ( I-neutral
#
# @ O
#
# 我的家 O
#
# in O
#
# pasir B-negative
#
# ris I-negative
#
# , I-neutral
#
# singapore B-negative
#
# ) I-neutral
#
# https://t.co/tQujchPoru O
#
# new sentence
# I'm O
#
# at O
#
# Hougang B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/NHSARG9PVF is tagged as UNK and the this arg_max_y e(https://t.co/NHSARG9PVF|y) is I-negative
# https://t.co/NHSARG9PVF I-negative
#
# new sentence
# So O
#
# heartbreaking O
#
# to O
#
# see O
#
# liquid B-neutral
#
# getting O
#
# crushed O
#
# . O
#
# new sentence
# I'm O
#
# at O
#
# RHB B-neutral
#
# Bank I-negative
#
# in O
#
# Johor B-neutral
#
# Bahru I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# https://t.co/YkSrF4kpWn O
#
# new sentence
# In I-positive
#
# Jesus B-positive
#
# name B-positive
#
# , I-neutral
#
# we O
#
# prayAmenn is tagged as UNK and the this arg_max_y e(prayAmenn|y) is I-negative
# prayAmenn I-negative
#
# #ALDUBImagineYouAndMe B-positive
#
# https://t.co/0hUDKbGg7y is tagged as UNK and the this arg_max_y e(https://t.co/0hUDKbGg7y|y) is I-negative
# https://t.co/0hUDKbGg7y I-negative
#
# new sentence
# I'm O
#
# at O
#
# Woodlands B-neutral
#
# MRT I-neutral
#
# Station I-neutral
#
# ( I-neutral
#
# NS9 I-neutral
#
# ) I-neutral
#
# - O
#
# @smrt_singapore B-neutral
#
# in O
#
# Singapore B-neutral
#
# https://t.co/0XSUrg8P8o is tagged as UNK and the this arg_max_y e(https://t.co/0XSUrg8P8o|y) is I-negative
# https://t.co/0XSUrg8P8o I-negative
#
# new sentence
# I'm O
#
# at O
#
# Blk B-neutral
#
# 645 I-neutral
#
# Ang B-neutral
#
# Mo I-neutral
#
# Kio I-neutral
#
# Avenue I-neutral
#
# 6 I-negative
#
# in O
#
# Singapore B-neutral
#
# https://t.co/5ArlGuOhhU is tagged as UNK and the this arg_max_y e(https://t.co/5ArlGuOhhU|y) is I-negative
# https://t.co/5ArlGuOhhU I-negative
#
# new sentence
# school B-negative
#
# just O
#
# reopened O
#
# , I-neutral
#
# life O
#
# getting O
#
# better O
#
# everyday O
#
# . O
#
# @ O
#
# Ngee B-neutral
#
# Ann I-neutral
#
# … O
#
# https://t.co/gFODhSaFIx is tagged as UNK and the this arg_max_y e(https://t.co/gFODhSaFIx|y) is I-negative
# https://t.co/gFODhSaFIx I-negative
#
# new sentence
# Still O
#
# can't O
#
# get O
#
# enough O
#
# of I-negative
#
# down O
#
# by I-neutral
#
# marian is tagged as UNK and the this arg_max_y e(marian|y) is I-negative
# marian I-negative
#
# hill I-neutral
#
# new sentence
# Come O
#
# back O
#
# ( I-neutral
#
# at O
#
# Hang B-neutral
#
# Nadim I-neutral
#
# International I-neutral
#
# Airport I-neutral
#
# ( I-neutral
#
# BTH I-neutral
#
# ) I-neutral
#
# ) I-neutral
#
# — O
#
# https://t.co/hz49SeW0tt is tagged as UNK and the this arg_max_y e(https://t.co/hz49SeW0tt|y) is I-negative
# https://t.co/hz49SeW0tt I-negative
#
# new sentence
# Join O
#
# the O
#
# The B-neutral
#
# Procter I-positive
#
# & I-positive
#
# Gamble I-positive
#
# Company I-positive
#
# team I-positive
#
# ! O
#
# See I-positive
#
# our O
#
# latest O
#
# #job O
#
# opening O
#
# here O
#
# : I-negative
#
# https://t.co/i4JKEzB2R9 is tagged as UNK and the this arg_max_y e(https://t.co/i4JKEzB2R9|y) is I-negative
# https://t.co/i4JKEzB2R9 I-negative
#
# #Engineering O
#
# #Singapore B-neutral
#
# #Veterans O
#
# new sentence
# Ermmmmm O
#
# ... O
#
# @ O
#
# Inspire B-neutral
#
# Mind I-neutral
#
# Academy I-neutral
#
# https://t.co/WfxpPbnvcT O
#
# new sentence
# I'm O
#
# at O
#
# Bishan B-negative
#
# Community I-positive
#
# Club I-positive
#
# in O
#
# Singapore B-neutral
#
# https://t.co/thUhg2Bo43 is tagged as UNK and the this arg_max_y e(https://t.co/thUhg2Bo43|y) is I-negative
# https://t.co/thUhg2Bo43 I-negative
#
# new sentence
# Can O
#
# somebody O
#
# pls O
#
# teman is tagged as UNK and the this arg_max_y e(teman|y) is I-negative
# teman I-negative
#
# me O
#
# watch I-positive
#
# salman is tagged as UNK and the this arg_max_y e(salman|y) is I-negative
# salman I-negative
#
# khan I-positive
#
# ' O
#
# s I-positive
#
# Sultan I-positive
#
# new O
#
# movie I-positive
#
# plsss is tagged as UNK and the this arg_max_y e(plsss|y) is I-negative
# plsss I-negative
#
# new sentence
# I'm O
#
# at O
#
# Club I-positive
#
# Icon I-neutral
#
# 2 I-positive
#
# https://t.co/portDfMbOo is tagged as UNK and the this arg_max_y e(https://t.co/portDfMbOo|y) is I-negative
# https://t.co/portDfMbOo I-negative
#
# new sentence
# John B-negative
#
# linker I-neutral
#
# calling O
#
# out O
#
# the O
#
# Domin B-neutral
#
# 8tor I-neutral
#
# new sentence
# Tk is tagged as UNK and the this arg_max_y e(Tk|y) is I-negative
# Tk I-negative
#
# suke is tagged as UNK and the this arg_max_y e(suke|y) is I-negative
# suke I-negative
#
# ah B-positive
#
# morning O
#
# rush O
#
# in O
#
# the O
#
# train B-negative
#
# new sentence
# I O
#
# feel O
#
# like O
#
# MC B-neutral
#
# tomorrow O
#
# . O
#
# But O
#
# cannot O
#
# , I-neutral
#
# Dr B-neutral
#
# Goh is tagged as UNK and the this arg_max_y e(Goh|y) is I-negative
# Goh I-negative
#
# wouldn't O
#
# be O
#
# so O
#
# pleased O
#
# . O
#
# new sentence
# @aidaidani O
#
# his O
#
# families O
#
# waited O
#
# for O
#
# 4 I-neutral
#
# hours O
#
# for O
#
# the O
#
# socso B-neutral
#
# people B-negative
#
# . O
#
# I'm O
#
# sorry O
#
# his O
#
# body B-negative
#
# was O
#
# left O
#
# on O
#
# the O
#
# cold B-neutral
#
# floor O
#
# . O
#
# But O
#
# its O
#
# just O
#
# a O
#
# dead O
#
# body B-negative
#
# . O
#
# new sentence
# This O
#
# #job O
#
# might O
#
# be O
#
# a O
#
# great O
#
# fit O
#
# for O
#
# you B-negative
#
# : I-negative
#
# Human is tagged as UNK and the this arg_max_y e(Human|y) is I-negative
# Human I-negative
#
# Resources is tagged as UNK and the this arg_max_y e(Resources|y) is I-negative
# Resources I-negative
#
# Business I-negative
#
# Partner O
#
# - O
#
# APJ I-neutral
#
# Region I-neutral
#
# - O
#
# https://t.co/3lgcJr7EPi is tagged as UNK and the this arg_max_y e(https://t.co/3lgcJr7EPi|y) is I-negative
# https://t.co/3lgcJr7EPi I-negative
#
# #IT O
#
# #Singapore B-neutral
#
# #Hiring O
#
# new sentence
# I'm O
#
# at O
#
# Changi B-neutral
#
# Airport I-neutral
#
# Terminal I-neutral
#
# 3 I-negative
#
# in O
#
# Singapore B-neutral
#
# https://t.co/xw7QLdd4NB is tagged as UNK and the this arg_max_y e(https://t.co/xw7QLdd4NB|y) is I-negative
# https://t.co/xw7QLdd4NB I-negative
#
# new sentence
# i-scream is tagged as UNK and the this arg_max_y e(i-scream|y) is I-negative
# i-scream I-negative
#
# datee is tagged as UNK and the this arg_max_y e(datee|y) is I-negative
# datee I-negative
#
# ✨ O
#
# @ O
#
# Swensen's B-positive
#
# @ O
#
# ION B-neutral
#
# Orchard B-neutral
#
# https://t.co/lNepQvsFLD is tagged as UNK and the this arg_max_y e(https://t.co/lNepQvsFLD|y) is I-negative
# https://t.co/lNepQvsFLD I-negative
#
# new sentence
# I'm O
#
# at O
#
# SAFRA B-neutral
#
# Yishun B-neutral
#
# Country I-neutral
#
# Club I-positive
#
# in O
#
# Singapore B-neutral
#
# w O
#
# / O
#
# @harold_lasial B-neutral
#
# https://t.co/Vny4oDUK0s is tagged as UNK and the this arg_max_y e(https://t.co/Vny4oDUK0s|y) is I-negative
# https://t.co/Vny4oDUK0s I-negative
#
# new sentence
# @NikitaluvCR7 O
#
# Happy O
#
# birthday O
#
# Nikki B-positive
#
# , I-neutral
#
# Hope O
#
# you B-negative
#
# had O
#
# a O
#
# good O
#
# birthday O
#
# ! O
#
# ! O
#
# ! O
#
# I O
#
# look O
#
# forward O
#
# to O
#
# seeing O
#
# you B-negative
#
# around O
#
# always O
#
# . O
#
# new sentence
# i O
#
# love O
#
# watching O
#
# kylie B-positive
#
# jenner's is tagged as UNK and the this arg_max_y e(jenner's|y) is I-negative
# jenner's I-negative
#
# sc I-positive
#
# new sentence
# Zoom B-positive
#
# in O
#
# on O
#
# one I-negative
#
# quadrant is tagged as UNK and the this arg_max_y e(quadrant|y) is I-negative
# quadrant I-negative
#
# . O
#
# My O
#
# parcheesi is tagged as UNK and the this arg_max_y e(parcheesi|y) is I-negative
# parcheesi I-negative
#
# set I-positive
#
# did O
#
# not O
#
# look O
#
# like O
#
# this O
#
# . O
#
# #Singapore B-neutral
#
# #art O
#
# @ O
#
# ACM B-neutral
#
# ( I-neutral
#
# Asian B-positive
#
# … O
#
# https://t.co/kA7aygJOsx is tagged as UNK and the this arg_max_y e(https://t.co/kA7aygJOsx|y) is I-negative
# https://t.co/kA7aygJOsx I-negative
#
# new sentence
# Free B-neutral
#
# wine O
#
# so O
#
# bottoms is tagged as UNK and the this arg_max_y e(bottoms|y) is I-negative
# bottoms I-negative
#
# up O
#
# @ O
#
# Suntec B-neutral
#
# Singapore B-neutral
#
# Convention I-positive
#
# & I-positive
#
# Exhibition I-neutral
#
# Centre I-neutral
#
# https://t.co/zXYzLPJo1Y is tagged as UNK and the this arg_max_y e(https://t.co/zXYzLPJo1Y|y) is I-negative
# https://t.co/zXYzLPJo1Y I-negative
#
# new sentence
# emmmm O
#
# ( I-neutral
#
# @ O
#
# Department B-neutral
#
# Of I-positive
#
# Design I-neutral
#
# and O
#
# Visual I-neutral
#
# Communication I-neutral
#
# in O
#
# Pasir B-neutral
#
# Gudang I-neutral
#
# , I-neutral
#
# Johor B-neutral
#
# Bharu I-neutral
#
# ) I-neutral
#
# https://t.co/Gz4IRvsjPj O
#
# new sentence
# we're O
#
# kinda O
#
# made O
#
# for O
#
# each O
#
# other O
#
# because O
#
# we O
#
# are O
#
# probably O
#
# the O
#
# only O
#
# ones O
#
# with O
#
# kurung I-neutral
#
# with O
#
# berms is tagged as UNK and the this arg_max_y e(berms|y) is I-negative
# berms I-negative
#
# & I-positive
#
# amp I-positive
#
# ; O
#
# kebaya is tagged as UNK and the this arg_max_y e(kebaya|y) is I-negative
# kebaya I-negative
#
# with O
#
# nike B-neutral
#
# https://t.co/qdp5Yvjgax is tagged as UNK and the this arg_max_y e(https://t.co/qdp5Yvjgax|y) is I-negative
# https://t.co/qdp5Yvjgax I-negative
#
# new sentence
# Where's O
#
# the O
#
# butter O
#
# ? O
#
# @ O
#
# Butter B-positive
#
# My O
#
# Buns is tagged as UNK and the this arg_max_y e(Buns|y) is I-negative
# Buns I-negative
#
# https://t.co/dHZb2tnGgd is tagged as UNK and the this arg_max_y e(https://t.co/dHZb2tnGgd|y) is I-negative
# https://t.co/dHZb2tnGgd I-negative
#
# new sentence

# %%
! python EvalScript/evalResult.py SG/dev.out SG/dev.p2.out
# Out:
# #Entity in gold data: 4301
# #Entity in prediction: 12237
#
# #Correct Entity : 2386
# Entity  precision: 0.1950
# Entity  recall: 0.5548
# Entity  F: 0.2885
#
# #Correct Sentiment : 1531
# Sentiment  precision: 0.1251
# Sentiment  recall: 0.3560
# Sentiment  F: 0.1851
